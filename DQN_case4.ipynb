# %%
# !pip install axelrod
# Out:
# Collecting axelrod
#   Downloading axelrod-4.13.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.1.1)
# Requirement already satisfied: dask>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (2024.12.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2025.3.2)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.0.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from axelrod) (6.0.2)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (1.15.3)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (0.12.1)
# Requirement already satisfied: tqdm>=4.39.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.7.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (1.1.21)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.9.2->axelrod) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->axelrod) (1.17.0)
# Downloading axelrod-4.13.1-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: axelrod
# Successfully installed axelrod-4.13.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from collections import deque
import axelrod as axl
from axelrod.action import Action
C, D = Action.C, Action.D

# %%
# Reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
# IPD Environment
class IPDEnv:
    def __init__(self, opponent, history_len=10, max_turns=100):
        self.opponent = opponent
        self.history_len = history_len
        self.max_turns = max_turns
        self.reset()

    def reset(self):
        self.agent = axl.Player()
        self.opponent.reset()
        self.agent_history = []
        self.opp_history = []
        self.turn = 0
        return self._get_state()

    def _get_state(self):
        padded_agent = [0] * (self.history_len - len(self.agent_history)) + self.agent_history[-self.history_len:]
        padded_opp = [0] * (self.history_len - len(self.opp_history)) + self.opp_history[-self.history_len:]
        return torch.tensor(padded_agent + padded_opp, dtype=torch.float32)

    def step(self, action):
        agent_action = C if action == 0 else D
        opp_action = self.opponent.strategy(self.agent)

        # Record moves in the agent's and oponnents history
        self.agent.history.append(agent_action, opp_action)
        self.opponent.history.append(opp_action, agent_action)

        # Also update the raw binary history for state vector
        self.agent_history.append(0 if agent_action == C else 1)
        self.opp_history.append(0 if opp_action == C else 1)

        payoff_matrix = {
            (C, C): (3, 3),
            (C, D): (0, 5),
            (D, C): (5, 0),
            (D, D): (1, 1)
        }

        reward, _ = payoff_matrix[(agent_action, opp_action)]
        self.turn += 1
        done = self.turn >= self.max_turns

        return self._get_state(), reward, done

# %%
# DQN Network with CNN and Replay Buffer
class DQNCNN(nn.Module):
    def __init__(self, input_channels=2, seq_len=10, output_dim=2):
        super(DQNCNN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv1d(in_channels=input_channels, out_channels=16, kernel_size=3, padding=1),  # (B, 2, 10) → (B, 16, 10)
            nn.ReLU(),
            nn.Conv1d(16, 32, kernel_size=3, padding=1),  # (B, 32, 10)
            nn.ReLU(),
            nn.Flatten()  # → (B, 320)
        )

        self.fc = nn.Sequential(
            nn.Linear(32 * seq_len, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        x = x.view(x.size(0), 2, -1)  # Reshape from (B, 20) → (B, 2, 10)
        x = self.conv(x)
        return self.fc(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(state, dtype=torch.float32),
            torch.tensor(action, dtype=torch.int64),
            torch.tensor(reward, dtype=torch.float32),
            torch.tensor(next_state, dtype=torch.float32),
            torch.tensor(done, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)

# %%
# Training Setup
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
lr = 1e-3
batch_size = 64
num_episodes = 1000

epsilon_decay = (epsilon_min / epsilon) ** (1 / (num_episodes * 0.9))
print(f"Epsilon decay: {epsilon_decay:.9f}")


policy_net = DQNCNN(input_channels=2, seq_len=10, output_dim=2)
target_net = DQNCNN(input_channels=2, seq_len=10, output_dim=2)

target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=lr)
replay_buffer = ReplayBuffer(10000)

def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.randint(0, 1)
    with torch.no_grad():
        return policy_net(state.unsqueeze(0)).argmax().item()
# Out:
# Epsilon decay: 0.996676942

# %%
# Opponent pool
opponent_pool = [
    # Group 1: Exploitable & Naive
    axl.CyclerCCCCCD(),
    axl.EasyGo(),
    axl.Alternator(),

    # Group 2: Punishing/Retaliatory & Reactive
    axl.Grudger(),
    axl.ForgivingTitForTat(),
    axl.HardTitForTat(),

    # Group 3: Stochastic & Noisy
    axl.Gambler(),
    axl.SoftJoss(),
    axl.StochasticWSLS(),

    # Group 4: Deceptive & Pattern-Based
    axl.WinStayLoseShift(),
    axl.TitFor2Tats(),
    axl.FoolMeOnce()
]

# Define rewards for plotting and evaluation
Total_reward = 0
avg_rewards = []


# Best till now
for episode in range(num_episodes):
    opponent = random.choice(opponent_pool)          # 🆕 random opponent
    env = IPDEnv(opponent)                           # 🆕 new environment with that opponent
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = select_action(state, epsilon)
        next_state, reward, done = env.step(action)
        replay_buffer.push(state.numpy(), action, reward, next_state.numpy(), done)
        state = next_state
        total_reward += reward

        if len(replay_buffer) >= batch_size:
            s, a, r, s2, d = replay_buffer.sample(batch_size)
            q_vals = policy_net(s).gather(1, a.unsqueeze(1)).squeeze()
            next_q_vals = target_net(s2).max(1)[0]
            target = r + gamma * next_q_vals * (1 - d)
            loss = nn.MSELoss()(q_vals, target.detach())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    if episode % 10 == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    avg_rewards.append(total_reward)
    print(f"Episode {episode},Opponent: {type(opponent).__name__}, Reward: {total_reward:.2f}, Epsilon: {epsilon:.2f}")


    if episode % 100 == 0:
        print(f"Episode {episode}, Avg Reward: {total_reward:.2f}, Epsilon: {epsilon:.2f}")



torch.save(policy_net.state_dict(), "dqn_policy.pth")

# Plot reward curve
plt.plot(avg_rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward per Episode")
plt.title("Learning Curve")
plt.grid(True)
plt.show()

pd.Series(avg_rewards).rolling(50).mean().plot()
# Out:
# Episode 0,Opponent: TitFor2Tats, Reward: 295.00, Epsilon: 1.00
# Episode 0, Avg Reward: 295.00, Epsilon: 1.00
# Episode 1,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.99
# Episode 2,Opponent: Grudger, Reward: 54.00, Epsilon: 0.99
# Episode 3,Opponent: CyclerCCCCCD, Reward: 341.00, Epsilon: 0.99
# Episode 4,Opponent: Grudger, Reward: 62.00, Epsilon: 0.98
# Episode 5,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.98
# Episode 6,Opponent: WinStayLoseShift, Reward: 221.00, Epsilon: 0.98
# Episode 7,Opponent: WinStayLoseShift, Reward: 236.00, Epsilon: 0.97
# Episode 8,Opponent: EasyGo, Reward: 405.00, Epsilon: 0.97
# Episode 9,Opponent: Gambler, Reward: 238.00, Epsilon: 0.97
# Episode 10,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.96
# Episode 11,Opponent: EasyGo, Reward: 393.00, Epsilon: 0.96
# Episode 12,Opponent: CyclerCCCCCD, Reward: 337.00, Epsilon: 0.96
# Episode 13,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.95
# Episode 14,Opponent: Grudger, Reward: 55.00, Epsilon: 0.95
# Episode 15,Opponent: SoftJoss, Reward: 396.00, Epsilon: 0.95
# Episode 16,Opponent: Gambler, Reward: 238.00, Epsilon: 0.94
# Episode 17,Opponent: Gambler, Reward: 223.00, Epsilon: 0.94
# Episode 18,Opponent: EasyGo, Reward: 371.00, Epsilon: 0.94
# Episode 19,Opponent: ForgivingTitForTat, Reward: 229.00, Epsilon: 0.94
# Episode 20,Opponent: TitFor2Tats, Reward: 332.00, Epsilon: 0.93
# Episode 21,Opponent: SoftJoss, Reward: 392.00, Epsilon: 0.93
# Episode 22,Opponent: TitFor2Tats, Reward: 326.00, Epsilon: 0.93
# Episode 23,Opponent: Alternator, Reward: 220.00, Epsilon: 0.92
# Episode 24,Opponent: HardTitForTat, Reward: 97.00, Epsilon: 0.92
# Episode 25,Opponent: EasyGo, Reward: 414.00, Epsilon: 0.92
# Episode 26,Opponent: EasyGo, Reward: 422.00, Epsilon: 0.91
# Episode 27,Opponent: EasyGo, Reward: 411.00, Epsilon: 0.91
# Episode 28,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.91
# Episode 29,Opponent: ForgivingTitForTat, Reward: 233.00, Epsilon: 0.90
# Episode 30,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.90
# Episode 31,Opponent: ForgivingTitForTat, Reward: 229.00, Epsilon: 0.90
# Episode 32,Opponent: EasyGo, Reward: 428.00, Epsilon: 0.90
# Episode 33,Opponent: CyclerCCCCCD, Reward: 364.00, Epsilon: 0.89
# Episode 34,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.89
# Episode 35,Opponent: Gambler, Reward: 230.00, Epsilon: 0.89
# Episode 36,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.88
# Episode 37,Opponent: ForgivingTitForTat, Reward: 228.00, Epsilon: 0.88
# Episode 38,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.88
# Episode 39,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.88
# Episode 40,Opponent: EasyGo, Reward: 407.00, Epsilon: 0.87
# Episode 41,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.87
# Episode 42,Opponent: Alternator, Reward: 225.00, Epsilon: 0.87
# Episode 43,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.86
# Episode 44,Opponent: Grudger, Reward: 52.00, Epsilon: 0.86
# Episode 45,Opponent: TitFor2Tats, Reward: 295.00, Epsilon: 0.86
# Episode 46,Opponent: HardTitForTat, Reward: 95.00, Epsilon: 0.86
# Episode 47,Opponent: TitFor2Tats, Reward: 286.00, Epsilon: 0.85
# Episode 48,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.85
# Episode 49,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.85
# Episode 50,Opponent: HardTitForTat, Reward: 80.00, Epsilon: 0.84
# Episode 51,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.84
# Episode 52,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.84
# Episode 53,Opponent: EasyGo, Reward: 418.00, Epsilon: 0.84
# Episode 54,Opponent: ForgivingTitForTat, Reward: 234.00, Epsilon: 0.83
# Episode 55,Opponent: Grudger, Reward: 58.00, Epsilon: 0.83
# Episode 56,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.83
# Episode 57,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.82
# Episode 58,Opponent: TitFor2Tats, Reward: 275.00, Epsilon: 0.82
# Episode 59,Opponent: Alternator, Reward: 240.00, Epsilon: 0.82
# Episode 60,Opponent: EasyGo, Reward: 402.00, Epsilon: 0.82
# Episode 61,Opponent: Alternator, Reward: 230.00, Epsilon: 0.81
# Episode 62,Opponent: Alternator, Reward: 238.00, Epsilon: 0.81
# Episode 63,Opponent: Gambler, Reward: 240.00, Epsilon: 0.81
# Episode 64,Opponent: Gambler, Reward: 224.00, Epsilon: 0.81
# Episode 65,Opponent: EasyGo, Reward: 420.00, Epsilon: 0.80
# Episode 66,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.80
# Episode 67,Opponent: Alternator, Reward: 215.00, Epsilon: 0.80
# Episode 68,Opponent: SoftJoss, Reward: 426.00, Epsilon: 0.79
# Episode 69,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.79
# Episode 70,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.79
# Episode 71,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.79
# Episode 72,Opponent: FoolMeOnce, Reward: 63.00, Epsilon: 0.78
# Episode 73,Opponent: Gambler, Reward: 224.00, Epsilon: 0.78
# Episode 74,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.78
# Episode 75,Opponent: SoftJoss, Reward: 404.00, Epsilon: 0.78
# Episode 76,Opponent: HardTitForTat, Reward: 88.00, Epsilon: 0.77
# Episode 77,Opponent: ForgivingTitForTat, Reward: 243.00, Epsilon: 0.77
# Episode 78,Opponent: TitFor2Tats, Reward: 334.00, Epsilon: 0.77
# Episode 79,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.77
# Episode 80,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.76
# Episode 81,Opponent: Gambler, Reward: 247.00, Epsilon: 0.76
# Episode 82,Opponent: Grudger, Reward: 62.00, Epsilon: 0.76
# Episode 83,Opponent: HardTitForTat, Reward: 78.00, Epsilon: 0.76
# Episode 84,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.75
# Episode 85,Opponent: Gambler, Reward: 240.00, Epsilon: 0.75
# Episode 86,Opponent: FoolMeOnce, Reward: 69.00, Epsilon: 0.75
# Episode 87,Opponent: Gambler, Reward: 240.00, Epsilon: 0.75
# Episode 88,Opponent: EasyGo, Reward: 422.00, Epsilon: 0.74
# Episode 89,Opponent: Gambler, Reward: 256.00, Epsilon: 0.74
# Episode 90,Opponent: Grudger, Reward: 57.00, Epsilon: 0.74
# Episode 91,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.74
# Episode 92,Opponent: Gambler, Reward: 244.00, Epsilon: 0.73
# Episode 93,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.73
# Episode 94,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.73
# Episode 95,Opponent: StochasticWSLS, Reward: 404.00, Epsilon: 0.73
# Episode 96,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.72
# Episode 97,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.72
# Episode 98,Opponent: FoolMeOnce, Reward: 77.00, Epsilon: 0.72
# Episode 99,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.72
# Episode 100,Opponent: Gambler, Reward: 249.00, Epsilon: 0.71
# Episode 100, Avg Reward: 249.00, Epsilon: 0.71
# Episode 101,Opponent: CyclerCCCCCD, Reward: 377.00, Epsilon: 0.71
# Episode 102,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.71
# Episode 103,Opponent: FoolMeOnce, Reward: 73.00, Epsilon: 0.71
# Episode 104,Opponent: Gambler, Reward: 241.00, Epsilon: 0.71
# Episode 105,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.70
# Episode 106,Opponent: SoftJoss, Reward: 426.00, Epsilon: 0.70
# Episode 107,Opponent: WinStayLoseShift, Reward: 215.00, Epsilon: 0.70
# Episode 108,Opponent: FoolMeOnce, Reward: 72.00, Epsilon: 0.70
# Episode 109,Opponent: Grudger, Reward: 57.00, Epsilon: 0.69
# Episode 110,Opponent: HardTitForTat, Reward: 82.00, Epsilon: 0.69
# Episode 111,Opponent: EasyGo, Reward: 436.00, Epsilon: 0.69
# Episode 112,Opponent: HardTitForTat, Reward: 90.00, Epsilon: 0.69
# Episode 113,Opponent: EasyGo, Reward: 433.00, Epsilon: 0.68
# Episode 114,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.68
# Episode 115,Opponent: HardTitForTat, Reward: 69.00, Epsilon: 0.68
# Episode 116,Opponent: TitFor2Tats, Reward: 313.00, Epsilon: 0.68
# Episode 117,Opponent: HardTitForTat, Reward: 69.00, Epsilon: 0.68
# Episode 118,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.67
# Episode 119,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.67
# Episode 120,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.67
# Episode 121,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.67
# Episode 122,Opponent: Grudger, Reward: 63.00, Epsilon: 0.66
# Episode 123,Opponent: FoolMeOnce, Reward: 72.00, Epsilon: 0.66
# Episode 124,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.66
# Episode 125,Opponent: Alternator, Reward: 245.00, Epsilon: 0.66
# Episode 126,Opponent: FoolMeOnce, Reward: 72.00, Epsilon: 0.66
# Episode 127,Opponent: HardTitForTat, Reward: 91.00, Epsilon: 0.65
# Episode 128,Opponent: Alternator, Reward: 258.00, Epsilon: 0.65
# Episode 129,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.65
# Episode 130,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.65
# Episode 131,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.64
# Episode 132,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.64
# Episode 133,Opponent: StochasticWSLS, Reward: 424.00, Epsilon: 0.64
# Episode 134,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.64
# Episode 135,Opponent: Grudger, Reward: 65.00, Epsilon: 0.64
# Episode 136,Opponent: Alternator, Reward: 240.00, Epsilon: 0.63
# Episode 137,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.63
# Episode 138,Opponent: Alternator, Reward: 238.00, Epsilon: 0.63
# Episode 139,Opponent: TitFor2Tats, Reward: 327.00, Epsilon: 0.63
# Episode 140,Opponent: Grudger, Reward: 65.00, Epsilon: 0.63
# Episode 141,Opponent: HardTitForTat, Reward: 81.00, Epsilon: 0.62
# Episode 142,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.62
# Episode 143,Opponent: TitFor2Tats, Reward: 317.00, Epsilon: 0.62
# Episode 144,Opponent: Gambler, Reward: 237.00, Epsilon: 0.62
# Episode 145,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.62
# Episode 146,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.61
# Episode 147,Opponent: Gambler, Reward: 251.00, Epsilon: 0.61
# Episode 148,Opponent: CyclerCCCCCD, Reward: 365.00, Epsilon: 0.61
# Episode 149,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.61
# Episode 150,Opponent: Gambler, Reward: 238.00, Epsilon: 0.60
# Episode 151,Opponent: ForgivingTitForTat, Reward: 249.00, Epsilon: 0.60
# Episode 152,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.60
# Episode 153,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.60
# Episode 154,Opponent: Grudger, Reward: 64.00, Epsilon: 0.60
# Episode 155,Opponent: Gambler, Reward: 254.00, Epsilon: 0.59
# Episode 156,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.59
# Episode 157,Opponent: HardTitForTat, Reward: 138.00, Epsilon: 0.59
# Episode 158,Opponent: FoolMeOnce, Reward: 70.00, Epsilon: 0.59
# Episode 159,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.59
# Episode 160,Opponent: Alternator, Reward: 242.00, Epsilon: 0.59
# Episode 161,Opponent: Grudger, Reward: 56.00, Epsilon: 0.58
# Episode 162,Opponent: WinStayLoseShift, Reward: 225.00, Epsilon: 0.58
# Episode 163,Opponent: Gambler, Reward: 257.00, Epsilon: 0.58
# Episode 164,Opponent: WinStayLoseShift, Reward: 212.00, Epsilon: 0.58
# Episode 165,Opponent: Alternator, Reward: 241.00, Epsilon: 0.58
# Episode 166,Opponent: Gambler, Reward: 260.00, Epsilon: 0.57
# Episode 167,Opponent: HardTitForTat, Reward: 143.00, Epsilon: 0.57
# Episode 168,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.57
# Episode 169,Opponent: HardTitForTat, Reward: 129.00, Epsilon: 0.57
# Episode 170,Opponent: Gambler, Reward: 255.00, Epsilon: 0.57
# Episode 171,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.56
# Episode 172,Opponent: CyclerCCCCCD, Reward: 345.00, Epsilon: 0.56
# Episode 173,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.56
# Episode 174,Opponent: WinStayLoseShift, Reward: 242.00, Epsilon: 0.56
# Episode 175,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.56
# Episode 176,Opponent: Gambler, Reward: 253.00, Epsilon: 0.55
# Episode 177,Opponent: HardTitForTat, Reward: 137.00, Epsilon: 0.55
# Episode 178,Opponent: TitFor2Tats, Reward: 328.00, Epsilon: 0.55
# Episode 179,Opponent: HardTitForTat, Reward: 101.00, Epsilon: 0.55
# Episode 180,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.55
# Episode 181,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.55
# Episode 182,Opponent: EasyGo, Reward: 424.00, Epsilon: 0.54
# Episode 183,Opponent: Grudger, Reward: 52.00, Epsilon: 0.54
# Episode 184,Opponent: ForgivingTitForTat, Reward: 236.00, Epsilon: 0.54
# Episode 185,Opponent: HardTitForTat, Reward: 109.00, Epsilon: 0.54
# Episode 186,Opponent: CyclerCCCCCD, Reward: 347.00, Epsilon: 0.54
# Episode 187,Opponent: Alternator, Reward: 251.00, Epsilon: 0.53
# Episode 188,Opponent: Alternator, Reward: 255.00, Epsilon: 0.53
# Episode 189,Opponent: Grudger, Reward: 49.00, Epsilon: 0.53
# Episode 190,Opponent: ForgivingTitForTat, Reward: 262.00, Epsilon: 0.53
# Episode 191,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.53
# Episode 192,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.53
# Episode 193,Opponent: EasyGo, Reward: 440.00, Epsilon: 0.52
# Episode 194,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.52
# Episode 195,Opponent: Gambler, Reward: 269.00, Epsilon: 0.52
# Episode 196,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.52
# Episode 197,Opponent: Grudger, Reward: 47.00, Epsilon: 0.52
# Episode 198,Opponent: ForgivingTitForTat, Reward: 262.00, Epsilon: 0.52
# Episode 199,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.51
# Episode 200,Opponent: HardTitForTat, Reward: 170.00, Epsilon: 0.51
# Episode 200, Avg Reward: 170.00, Epsilon: 0.51
# Episode 201,Opponent: Grudger, Reward: 31.00, Epsilon: 0.51
# Episode 202,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.51
# Episode 203,Opponent: Grudger, Reward: 42.00, Epsilon: 0.51
# Episode 204,Opponent: Grudger, Reward: 50.00, Epsilon: 0.51
# Episode 205,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.50
# Episode 206,Opponent: HardTitForTat, Reward: 156.00, Epsilon: 0.50
# Episode 207,Opponent: ForgivingTitForTat, Reward: 257.00, Epsilon: 0.50
# Episode 208,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.50
# Episode 209,Opponent: Alternator, Reward: 251.00, Epsilon: 0.50
# Episode 210,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.50
# Episode 211,Opponent: TitFor2Tats, Reward: 323.00, Epsilon: 0.49
# Episode 212,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.49
# Episode 213,Opponent: HardTitForTat, Reward: 136.00, Epsilon: 0.49
# Episode 214,Opponent: HardTitForTat, Reward: 140.00, Epsilon: 0.49
# Episode 215,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.49
# Episode 216,Opponent: FoolMeOnce, Reward: 48.00, Epsilon: 0.49
# Episode 217,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.48
# Episode 218,Opponent: TitFor2Tats, Reward: 324.00, Epsilon: 0.48
# Episode 219,Opponent: HardTitForTat, Reward: 144.00, Epsilon: 0.48
# Episode 220,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.48
# Episode 221,Opponent: WinStayLoseShift, Reward: 266.00, Epsilon: 0.48
# Episode 222,Opponent: Alternator, Reward: 239.00, Epsilon: 0.48
# Episode 223,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.47
# Episode 224,Opponent: HardTitForTat, Reward: 158.00, Epsilon: 0.47
# Episode 225,Opponent: ForgivingTitForTat, Reward: 269.00, Epsilon: 0.47
# Episode 226,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.47
# Episode 227,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.47
# Episode 228,Opponent: Alternator, Reward: 240.00, Epsilon: 0.47
# Episode 229,Opponent: ForgivingTitForTat, Reward: 260.00, Epsilon: 0.47
# Episode 230,Opponent: Grudger, Reward: 39.00, Epsilon: 0.46
# Episode 231,Opponent: FoolMeOnce, Reward: 45.00, Epsilon: 0.46
# Episode 232,Opponent: WinStayLoseShift, Reward: 218.00, Epsilon: 0.46
# Episode 233,Opponent: Gambler, Reward: 257.00, Epsilon: 0.46
# Episode 234,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.46
# Episode 235,Opponent: HardTitForTat, Reward: 139.00, Epsilon: 0.46
# Episode 236,Opponent: FoolMeOnce, Reward: 38.00, Epsilon: 0.45
# Episode 237,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.45
# Episode 238,Opponent: CyclerCCCCCD, Reward: 342.00, Epsilon: 0.45
# Episode 239,Opponent: TitFor2Tats, Reward: 325.00, Epsilon: 0.45
# Episode 240,Opponent: CyclerCCCCCD, Reward: 364.00, Epsilon: 0.45
# Episode 241,Opponent: HardTitForTat, Reward: 208.00, Epsilon: 0.45
# Episode 242,Opponent: Grudger, Reward: 46.00, Epsilon: 0.45
# Episode 243,Opponent: CyclerCCCCCD, Reward: 356.00, Epsilon: 0.44
# Episode 244,Opponent: Gambler, Reward: 267.00, Epsilon: 0.44
# Episode 245,Opponent: Alternator, Reward: 209.00, Epsilon: 0.44
# Episode 246,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.44
# Episode 247,Opponent: EasyGo, Reward: 452.00, Epsilon: 0.44
# Episode 248,Opponent: Gambler, Reward: 265.00, Epsilon: 0.44
# Episode 249,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.44
# Episode 250,Opponent: EasyGo, Reward: 423.00, Epsilon: 0.43
# Episode 251,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.43
# Episode 252,Opponent: EasyGo, Reward: 443.00, Epsilon: 0.43
# Episode 253,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.43
# Episode 254,Opponent: WinStayLoseShift, Reward: 219.00, Epsilon: 0.43
# Episode 255,Opponent: EasyGo, Reward: 434.00, Epsilon: 0.43
# Episode 256,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.43
# Episode 257,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.42
# Episode 258,Opponent: Alternator, Reward: 226.00, Epsilon: 0.42
# Episode 259,Opponent: WinStayLoseShift, Reward: 228.00, Epsilon: 0.42
# Episode 260,Opponent: ForgivingTitForTat, Reward: 269.00, Epsilon: 0.42
# Episode 261,Opponent: EasyGo, Reward: 387.00, Epsilon: 0.42
# Episode 262,Opponent: Gambler, Reward: 276.00, Epsilon: 0.42
# Episode 263,Opponent: TitFor2Tats, Reward: 335.00, Epsilon: 0.42
# Episode 264,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.41
# Episode 265,Opponent: Gambler, Reward: 266.00, Epsilon: 0.41
# Episode 266,Opponent: HardTitForTat, Reward: 173.00, Epsilon: 0.41
# Episode 267,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.41
# Episode 268,Opponent: EasyGo, Reward: 409.00, Epsilon: 0.41
# Episode 269,Opponent: TitFor2Tats, Reward: 325.00, Epsilon: 0.41
# Episode 270,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.41
# Episode 271,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.40
# Episode 272,Opponent: Gambler, Reward: 265.00, Epsilon: 0.40
# Episode 273,Opponent: CyclerCCCCCD, Reward: 365.00, Epsilon: 0.40
# Episode 274,Opponent: Grudger, Reward: 34.00, Epsilon: 0.40
# Episode 275,Opponent: SoftJoss, Reward: 386.00, Epsilon: 0.40
# Episode 276,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.40
# Episode 277,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.40
# Episode 278,Opponent: Gambler, Reward: 252.00, Epsilon: 0.40
# Episode 279,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.39
# Episode 280,Opponent: EasyGo, Reward: 425.00, Epsilon: 0.39
# Episode 281,Opponent: HardTitForTat, Reward: 173.00, Epsilon: 0.39
# Episode 282,Opponent: Grudger, Reward: 92.00, Epsilon: 0.39
# Episode 283,Opponent: EasyGo, Reward: 424.00, Epsilon: 0.39
# Episode 284,Opponent: Alternator, Reward: 229.00, Epsilon: 0.39
# Episode 285,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.39
# Episode 286,Opponent: WinStayLoseShift, Reward: 246.00, Epsilon: 0.38
# Episode 287,Opponent: Alternator, Reward: 239.00, Epsilon: 0.38
# Episode 288,Opponent: EasyGo, Reward: 452.00, Epsilon: 0.38
# Episode 289,Opponent: Alternator, Reward: 224.00, Epsilon: 0.38
# Episode 290,Opponent: WinStayLoseShift, Reward: 251.00, Epsilon: 0.38
# Episode 291,Opponent: EasyGo, Reward: 455.00, Epsilon: 0.38
# Episode 292,Opponent: HardTitForTat, Reward: 202.00, Epsilon: 0.38
# Episode 293,Opponent: SoftJoss, Reward: 472.00, Epsilon: 0.38
# Episode 294,Opponent: Gambler, Reward: 261.00, Epsilon: 0.37
# Episode 295,Opponent: FoolMeOnce, Reward: 42.00, Epsilon: 0.37
# Episode 296,Opponent: CyclerCCCCCD, Reward: 362.00, Epsilon: 0.37
# Episode 297,Opponent: Gambler, Reward: 271.00, Epsilon: 0.37
# Episode 298,Opponent: StochasticWSLS, Reward: 454.00, Epsilon: 0.37
# Episode 299,Opponent: Gambler, Reward: 258.00, Epsilon: 0.37
# Episode 300,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.37
# Episode 300, Avg Reward: 357.00, Epsilon: 0.37
# Episode 301,Opponent: Alternator, Reward: 223.00, Epsilon: 0.37
# Episode 302,Opponent: Alternator, Reward: 228.00, Epsilon: 0.36
# Episode 303,Opponent: SoftJoss, Reward: 426.00, Epsilon: 0.36
# Episode 304,Opponent: Alternator, Reward: 233.00, Epsilon: 0.36
# Episode 305,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.36
# Episode 306,Opponent: Grudger, Reward: 32.00, Epsilon: 0.36
# Episode 307,Opponent: EasyGo, Reward: 434.00, Epsilon: 0.36
# Episode 308,Opponent: Alternator, Reward: 246.00, Epsilon: 0.36
# Episode 309,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.36
# Episode 310,Opponent: Alternator, Reward: 239.00, Epsilon: 0.36
# Episode 311,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.35
# Episode 312,Opponent: ForgivingTitForTat, Reward: 243.00, Epsilon: 0.35
# Episode 313,Opponent: TitFor2Tats, Reward: 321.00, Epsilon: 0.35
# Episode 314,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.35
# Episode 315,Opponent: Grudger, Reward: 29.00, Epsilon: 0.35
# Episode 316,Opponent: TitFor2Tats, Reward: 318.00, Epsilon: 0.35
# Episode 317,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.35
# Episode 318,Opponent: Alternator, Reward: 235.00, Epsilon: 0.35
# Episode 319,Opponent: HardTitForTat, Reward: 180.00, Epsilon: 0.34
# Episode 320,Opponent: EasyGo, Reward: 454.00, Epsilon: 0.34
# Episode 321,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.34
# Episode 322,Opponent: Grudger, Reward: 30.00, Epsilon: 0.34
# Episode 323,Opponent: Gambler, Reward: 260.00, Epsilon: 0.34
# Episode 324,Opponent: EasyGo, Reward: 415.00, Epsilon: 0.34
# Episode 325,Opponent: ForgivingTitForTat, Reward: 252.00, Epsilon: 0.34
# Episode 326,Opponent: ForgivingTitForTat, Reward: 251.00, Epsilon: 0.34
# Episode 327,Opponent: ForgivingTitForTat, Reward: 258.00, Epsilon: 0.34
# Episode 328,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.33
# Episode 329,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.33
# Episode 330,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.33
# Episode 331,Opponent: TitFor2Tats, Reward: 328.00, Epsilon: 0.33
# Episode 332,Opponent: CyclerCCCCCD, Reward: 349.00, Epsilon: 0.33
# Episode 333,Opponent: HardTitForTat, Reward: 151.00, Epsilon: 0.33
# Episode 334,Opponent: Alternator, Reward: 229.00, Epsilon: 0.33
# Episode 335,Opponent: Grudger, Reward: 74.00, Epsilon: 0.33
# Episode 336,Opponent: ForgivingTitForTat, Reward: 256.00, Epsilon: 0.33
# Episode 337,Opponent: Gambler, Reward: 261.00, Epsilon: 0.32
# Episode 338,Opponent: CyclerCCCCCD, Reward: 342.00, Epsilon: 0.32
# Episode 339,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.32
# Episode 340,Opponent: HardTitForTat, Reward: 131.00, Epsilon: 0.32
# Episode 341,Opponent: FoolMeOnce, Reward: 61.00, Epsilon: 0.32
# Episode 342,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.32
# Episode 343,Opponent: Alternator, Reward: 224.00, Epsilon: 0.32
# Episode 344,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.32
# Episode 345,Opponent: Gambler, Reward: 245.00, Epsilon: 0.32
# Episode 346,Opponent: ForgivingTitForTat, Reward: 231.00, Epsilon: 0.32
# Episode 347,Opponent: HardTitForTat, Reward: 133.00, Epsilon: 0.31
# Episode 348,Opponent: Grudger, Reward: 95.00, Epsilon: 0.31
# Episode 349,Opponent: Alternator, Reward: 232.00, Epsilon: 0.31
# Episode 350,Opponent: EasyGo, Reward: 444.00, Epsilon: 0.31
# Episode 351,Opponent: Gambler, Reward: 219.00, Epsilon: 0.31
# Episode 352,Opponent: EasyGo, Reward: 443.00, Epsilon: 0.31
# Episode 353,Opponent: ForgivingTitForTat, Reward: 218.00, Epsilon: 0.31
# Episode 354,Opponent: Grudger, Reward: 52.00, Epsilon: 0.31
# Episode 355,Opponent: Gambler, Reward: 267.00, Epsilon: 0.31
# Episode 356,Opponent: ForgivingTitForTat, Reward: 251.00, Epsilon: 0.30
# Episode 357,Opponent: Alternator, Reward: 222.00, Epsilon: 0.30
# Episode 358,Opponent: TitFor2Tats, Reward: 328.00, Epsilon: 0.30
# Episode 359,Opponent: StochasticWSLS, Reward: 458.00, Epsilon: 0.30
# Episode 360,Opponent: Gambler, Reward: 231.00, Epsilon: 0.30
# Episode 361,Opponent: EasyGo, Reward: 450.00, Epsilon: 0.30
# Episode 362,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.30
# Episode 363,Opponent: Alternator, Reward: 233.00, Epsilon: 0.30
# Episode 364,Opponent: Grudger, Reward: 83.00, Epsilon: 0.30
# Episode 365,Opponent: Alternator, Reward: 249.00, Epsilon: 0.30
# Episode 366,Opponent: SoftJoss, Reward: 390.00, Epsilon: 0.29
# Episode 367,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.29
# Episode 368,Opponent: StochasticWSLS, Reward: 438.00, Epsilon: 0.29
# Episode 369,Opponent: SoftJoss, Reward: 454.00, Epsilon: 0.29
# Episode 370,Opponent: HardTitForTat, Reward: 152.00, Epsilon: 0.29
# Episode 371,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.29
# Episode 372,Opponent: Alternator, Reward: 225.00, Epsilon: 0.29
# Episode 373,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.29
# Episode 374,Opponent: WinStayLoseShift, Reward: 266.00, Epsilon: 0.29
# Episode 375,Opponent: StochasticWSLS, Reward: 420.00, Epsilon: 0.29
# Episode 376,Opponent: EasyGo, Reward: 423.00, Epsilon: 0.29
# Episode 377,Opponent: FoolMeOnce, Reward: 85.00, Epsilon: 0.28
# Episode 378,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.28
# Episode 379,Opponent: EasyGo, Reward: 420.00, Epsilon: 0.28
# Episode 380,Opponent: EasyGo, Reward: 431.00, Epsilon: 0.28
# Episode 381,Opponent: SoftJoss, Reward: 454.00, Epsilon: 0.28
# Episode 382,Opponent: Grudger, Reward: 33.00, Epsilon: 0.28
# Episode 383,Opponent: SoftJoss, Reward: 454.00, Epsilon: 0.28
# Episode 384,Opponent: SoftJoss, Reward: 450.00, Epsilon: 0.28
# Episode 385,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.28
# Episode 386,Opponent: WinStayLoseShift, Reward: 275.00, Epsilon: 0.28
# Episode 387,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.27
# Episode 388,Opponent: Gambler, Reward: 233.00, Epsilon: 0.27
# Episode 389,Opponent: TitFor2Tats, Reward: 345.00, Epsilon: 0.27
# Episode 390,Opponent: CyclerCCCCCD, Reward: 375.00, Epsilon: 0.27
# Episode 391,Opponent: FoolMeOnce, Reward: 81.00, Epsilon: 0.27
# Episode 392,Opponent: ForgivingTitForTat, Reward: 248.00, Epsilon: 0.27
# Episode 393,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.27
# Episode 394,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.27
# Episode 395,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.27
# Episode 396,Opponent: FoolMeOnce, Reward: 69.00, Epsilon: 0.27
# Episode 397,Opponent: ForgivingTitForTat, Reward: 241.00, Epsilon: 0.27
# Episode 398,Opponent: FoolMeOnce, Reward: 61.00, Epsilon: 0.26
# Episode 399,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.26
# Episode 400,Opponent: HardTitForTat, Reward: 191.00, Epsilon: 0.26
# Episode 400, Avg Reward: 191.00, Epsilon: 0.26
# Episode 401,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.26
# Episode 402,Opponent: ForgivingTitForTat, Reward: 231.00, Epsilon: 0.26
# Episode 403,Opponent: ForgivingTitForTat, Reward: 241.00, Epsilon: 0.26
# Episode 404,Opponent: EasyGo, Reward: 414.00, Epsilon: 0.26
# Episode 405,Opponent: HardTitForTat, Reward: 172.00, Epsilon: 0.26
# Episode 406,Opponent: Grudger, Reward: 81.00, Epsilon: 0.26
# Episode 407,Opponent: Gambler, Reward: 251.00, Epsilon: 0.26
# Episode 408,Opponent: Alternator, Reward: 230.00, Epsilon: 0.26
# Episode 409,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.26
# Episode 410,Opponent: HardTitForTat, Reward: 124.00, Epsilon: 0.25
# Episode 411,Opponent: Alternator, Reward: 219.00, Epsilon: 0.25
# Episode 412,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.25
# Episode 413,Opponent: SoftJoss, Reward: 388.00, Epsilon: 0.25
# Episode 414,Opponent: EasyGo, Reward: 417.00, Epsilon: 0.25
# Episode 415,Opponent: WinStayLoseShift, Reward: 260.00, Epsilon: 0.25
# Episode 416,Opponent: ForgivingTitForTat, Reward: 248.00, Epsilon: 0.25
# Episode 417,Opponent: TitFor2Tats, Reward: 339.00, Epsilon: 0.25
# Episode 418,Opponent: HardTitForTat, Reward: 226.00, Epsilon: 0.25
# Episode 419,Opponent: WinStayLoseShift, Reward: 249.00, Epsilon: 0.25
# Episode 420,Opponent: Alternator, Reward: 222.00, Epsilon: 0.25
# Episode 421,Opponent: StochasticWSLS, Reward: 444.00, Epsilon: 0.25
# Episode 422,Opponent: FoolMeOnce, Reward: 94.00, Epsilon: 0.24
# Episode 423,Opponent: Grudger, Reward: 75.00, Epsilon: 0.24
# Episode 424,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.24
# Episode 425,Opponent: FoolMeOnce, Reward: 69.00, Epsilon: 0.24
# Episode 426,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.24
# Episode 427,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.24
# Episode 428,Opponent: WinStayLoseShift, Reward: 269.00, Epsilon: 0.24
# Episode 429,Opponent: Grudger, Reward: 82.00, Epsilon: 0.24
# Episode 430,Opponent: HardTitForTat, Reward: 107.00, Epsilon: 0.24
# Episode 431,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.24
# Episode 432,Opponent: Grudger, Reward: 75.00, Epsilon: 0.24
# Episode 433,Opponent: FoolMeOnce, Reward: 78.00, Epsilon: 0.24
# Episode 434,Opponent: Grudger, Reward: 75.00, Epsilon: 0.24
# Episode 435,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.23
# Episode 436,Opponent: Gambler, Reward: 240.00, Epsilon: 0.23
# Episode 437,Opponent: Gambler, Reward: 233.00, Epsilon: 0.23
# Episode 438,Opponent: HardTitForTat, Reward: 183.00, Epsilon: 0.23
# Episode 439,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.23
# Episode 440,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.23
# Episode 441,Opponent: Gambler, Reward: 239.00, Epsilon: 0.23
# Episode 442,Opponent: Grudger, Reward: 65.00, Epsilon: 0.23
# Episode 443,Opponent: FoolMeOnce, Reward: 78.00, Epsilon: 0.23
# Episode 444,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.23
# Episode 445,Opponent: WinStayLoseShift, Reward: 263.00, Epsilon: 0.23
# Episode 446,Opponent: EasyGo, Reward: 402.00, Epsilon: 0.23
# Episode 447,Opponent: ForgivingTitForTat, Reward: 243.00, Epsilon: 0.23
# Episode 448,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.22
# Episode 449,Opponent: Gambler, Reward: 255.00, Epsilon: 0.22
# Episode 450,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.22
# Episode 451,Opponent: SoftJoss, Reward: 380.00, Epsilon: 0.22
# Episode 452,Opponent: StochasticWSLS, Reward: 386.00, Epsilon: 0.22
# Episode 453,Opponent: Alternator, Reward: 244.00, Epsilon: 0.22
# Episode 454,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.22
# Episode 455,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.22
# Episode 456,Opponent: Alternator, Reward: 242.00, Epsilon: 0.22
# Episode 457,Opponent: TitFor2Tats, Reward: 356.00, Epsilon: 0.22
# Episode 458,Opponent: HardTitForTat, Reward: 199.00, Epsilon: 0.22
# Episode 459,Opponent: HardTitForTat, Reward: 154.00, Epsilon: 0.22
# Episode 460,Opponent: HardTitForTat, Reward: 152.00, Epsilon: 0.22
# Episode 461,Opponent: Grudger, Reward: 85.00, Epsilon: 0.21
# Episode 462,Opponent: FoolMeOnce, Reward: 112.00, Epsilon: 0.21
# Episode 463,Opponent: EasyGo, Reward: 414.00, Epsilon: 0.21
# Episode 464,Opponent: Alternator, Reward: 242.00, Epsilon: 0.21
# Episode 465,Opponent: HardTitForTat, Reward: 107.00, Epsilon: 0.21
# Episode 466,Opponent: HardTitForTat, Reward: 119.00, Epsilon: 0.21
# Episode 467,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.21
# Episode 468,Opponent: CyclerCCCCCD, Reward: 372.00, Epsilon: 0.21
# Episode 469,Opponent: FoolMeOnce, Reward: 109.00, Epsilon: 0.21
# Episode 470,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.21
# Episode 471,Opponent: Alternator, Reward: 244.00, Epsilon: 0.21
# Episode 472,Opponent: Grudger, Reward: 94.00, Epsilon: 0.21
# Episode 473,Opponent: HardTitForTat, Reward: 223.00, Epsilon: 0.21
# Episode 474,Opponent: EasyGo, Reward: 394.00, Epsilon: 0.21
# Episode 475,Opponent: Gambler, Reward: 244.00, Epsilon: 0.21
# Episode 476,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.20
# Episode 477,Opponent: HardTitForTat, Reward: 163.00, Epsilon: 0.20
# Episode 478,Opponent: WinStayLoseShift, Reward: 249.00, Epsilon: 0.20
# Episode 479,Opponent: Grudger, Reward: 101.00, Epsilon: 0.20
# Episode 480,Opponent: FoolMeOnce, Reward: 123.00, Epsilon: 0.20
# Episode 481,Opponent: FoolMeOnce, Reward: 142.00, Epsilon: 0.20
# Episode 482,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.20
# Episode 483,Opponent: Grudger, Reward: 104.00, Epsilon: 0.20
# Episode 484,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.20
# Episode 485,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.20
# Episode 486,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.20
# Episode 487,Opponent: EasyGo, Reward: 397.00, Epsilon: 0.20
# Episode 488,Opponent: EasyGo, Reward: 415.00, Epsilon: 0.20
# Episode 489,Opponent: EasyGo, Reward: 419.00, Epsilon: 0.20
# Episode 490,Opponent: StochasticWSLS, Reward: 448.00, Epsilon: 0.20
# Episode 491,Opponent: ForgivingTitForTat, Reward: 179.00, Epsilon: 0.19
# Episode 492,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.19
# Episode 493,Opponent: StochasticWSLS, Reward: 456.00, Epsilon: 0.19
# Episode 494,Opponent: EasyGo, Reward: 453.00, Epsilon: 0.19
# Episode 495,Opponent: CyclerCCCCCD, Reward: 358.00, Epsilon: 0.19
# Episode 496,Opponent: HardTitForTat, Reward: 100.00, Epsilon: 0.19
# Episode 497,Opponent: Gambler, Reward: 155.00, Epsilon: 0.19
# Episode 498,Opponent: Grudger, Reward: 96.00, Epsilon: 0.19
# Episode 499,Opponent: Gambler, Reward: 129.00, Epsilon: 0.19
# Episode 500,Opponent: Grudger, Reward: 86.00, Epsilon: 0.19
# Episode 500, Avg Reward: 86.00, Epsilon: 0.19
# Episode 501,Opponent: HardTitForTat, Reward: 200.00, Epsilon: 0.19
# Episode 502,Opponent: Grudger, Reward: 98.00, Epsilon: 0.19
# Episode 503,Opponent: EasyGo, Reward: 404.00, Epsilon: 0.19
# Episode 504,Opponent: HardTitForTat, Reward: 239.00, Epsilon: 0.19
# Episode 505,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.19
# Episode 506,Opponent: WinStayLoseShift, Reward: 269.00, Epsilon: 0.18
# Episode 507,Opponent: HardTitForTat, Reward: 196.00, Epsilon: 0.18
# Episode 508,Opponent: CyclerCCCCCD, Reward: 363.00, Epsilon: 0.18
# Episode 509,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.18
# Episode 510,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.18
# Episode 511,Opponent: Grudger, Reward: 125.00, Epsilon: 0.18
# Episode 512,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.18
# Episode 513,Opponent: TitFor2Tats, Reward: 290.00, Epsilon: 0.18
# Episode 514,Opponent: CyclerCCCCCD, Reward: 348.00, Epsilon: 0.18
# Episode 515,Opponent: ForgivingTitForTat, Reward: 214.00, Epsilon: 0.18
# Episode 516,Opponent: TitFor2Tats, Reward: 317.00, Epsilon: 0.18
# Episode 517,Opponent: Gambler, Reward: 270.00, Epsilon: 0.18
# Episode 518,Opponent: FoolMeOnce, Reward: 82.00, Epsilon: 0.18
# Episode 519,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.18
# Episode 520,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.18
# Episode 521,Opponent: CyclerCCCCCD, Reward: 358.00, Epsilon: 0.18
# Episode 522,Opponent: Alternator, Reward: 265.00, Epsilon: 0.18
# Episode 523,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.17
# Episode 524,Opponent: EasyGo, Reward: 413.00, Epsilon: 0.17
# Episode 525,Opponent: TitFor2Tats, Reward: 321.00, Epsilon: 0.17
# Episode 526,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.17
# Episode 527,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.17
# Episode 528,Opponent: Gambler, Reward: 188.00, Epsilon: 0.17
# Episode 529,Opponent: Gambler, Reward: 215.00, Epsilon: 0.17
# Episode 530,Opponent: TitFor2Tats, Reward: 330.00, Epsilon: 0.17
# Episode 531,Opponent: EasyGo, Reward: 434.00, Epsilon: 0.17
# Episode 532,Opponent: WinStayLoseShift, Reward: 260.00, Epsilon: 0.17
# Episode 533,Opponent: StochasticWSLS, Reward: 400.00, Epsilon: 0.17
# Episode 534,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.17
# Episode 535,Opponent: HardTitForTat, Reward: 270.00, Epsilon: 0.17
# Episode 536,Opponent: EasyGo, Reward: 421.00, Epsilon: 0.17
# Episode 537,Opponent: HardTitForTat, Reward: 187.00, Epsilon: 0.17
# Episode 538,Opponent: SoftJoss, Reward: 402.00, Epsilon: 0.17
# Episode 539,Opponent: CyclerCCCCCD, Reward: 339.00, Epsilon: 0.17
# Episode 540,Opponent: HardTitForTat, Reward: 257.00, Epsilon: 0.17
# Episode 541,Opponent: FoolMeOnce, Reward: 89.00, Epsilon: 0.16
# Episode 542,Opponent: WinStayLoseShift, Reward: 251.00, Epsilon: 0.16
# Episode 543,Opponent: CyclerCCCCCD, Reward: 344.00, Epsilon: 0.16
# Episode 544,Opponent: Gambler, Reward: 254.00, Epsilon: 0.16
# Episode 545,Opponent: ForgivingTitForTat, Reward: 269.00, Epsilon: 0.16
# Episode 546,Opponent: TitFor2Tats, Reward: 341.00, Epsilon: 0.16
# Episode 547,Opponent: HardTitForTat, Reward: 235.00, Epsilon: 0.16
# Episode 548,Opponent: TitFor2Tats, Reward: 333.00, Epsilon: 0.16
# Episode 549,Opponent: Grudger, Reward: 56.00, Epsilon: 0.16
# Episode 550,Opponent: StochasticWSLS, Reward: 422.00, Epsilon: 0.16
# Episode 551,Opponent: Grudger, Reward: 45.00, Epsilon: 0.16
# Episode 552,Opponent: HardTitForTat, Reward: 247.00, Epsilon: 0.16
# Episode 553,Opponent: HardTitForTat, Reward: 249.00, Epsilon: 0.16
# Episode 554,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.16
# Episode 555,Opponent: CyclerCCCCCD, Reward: 336.00, Epsilon: 0.16
# Episode 556,Opponent: TitFor2Tats, Reward: 339.00, Epsilon: 0.16
# Episode 557,Opponent: EasyGo, Reward: 379.00, Epsilon: 0.16
# Episode 558,Opponent: EasyGo, Reward: 385.00, Epsilon: 0.16
# Episode 559,Opponent: ForgivingTitForTat, Reward: 272.00, Epsilon: 0.16
# Episode 560,Opponent: FoolMeOnce, Reward: 52.00, Epsilon: 0.15
# Episode 561,Opponent: HardTitForTat, Reward: 266.00, Epsilon: 0.15
# Episode 562,Opponent: Grudger, Reward: 75.00, Epsilon: 0.15
# Episode 563,Opponent: TitFor2Tats, Reward: 350.00, Epsilon: 0.15
# Episode 564,Opponent: EasyGo, Reward: 423.00, Epsilon: 0.15
# Episode 565,Opponent: HardTitForTat, Reward: 271.00, Epsilon: 0.15
# Episode 566,Opponent: StochasticWSLS, Reward: 382.00, Epsilon: 0.15
# Episode 567,Opponent: StochasticWSLS, Reward: 356.00, Epsilon: 0.15
# Episode 568,Opponent: Grudger, Reward: 46.00, Epsilon: 0.15
# Episode 569,Opponent: ForgivingTitForTat, Reward: 229.00, Epsilon: 0.15
# Episode 570,Opponent: HardTitForTat, Reward: 241.00, Epsilon: 0.15
# Episode 571,Opponent: TitFor2Tats, Reward: 343.00, Epsilon: 0.15
# Episode 572,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.15
# Episode 573,Opponent: EasyGo, Reward: 407.00, Epsilon: 0.15
# Episode 574,Opponent: Gambler, Reward: 212.00, Epsilon: 0.15
# Episode 575,Opponent: Alternator, Reward: 245.00, Epsilon: 0.15
# Episode 576,Opponent: WinStayLoseShift, Reward: 252.00, Epsilon: 0.15
# Episode 577,Opponent: HardTitForTat, Reward: 249.00, Epsilon: 0.15
# Episode 578,Opponent: Alternator, Reward: 225.00, Epsilon: 0.15
# Episode 579,Opponent: Alternator, Reward: 246.00, Epsilon: 0.15
# Episode 580,Opponent: Gambler, Reward: 228.00, Epsilon: 0.14
# Episode 581,Opponent: StochasticWSLS, Reward: 446.00, Epsilon: 0.14
# Episode 582,Opponent: Alternator, Reward: 228.00, Epsilon: 0.14
# Episode 583,Opponent: Grudger, Reward: 63.00, Epsilon: 0.14
# Episode 584,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.14
# Episode 585,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.14
# Episode 586,Opponent: CyclerCCCCCD, Reward: 375.00, Epsilon: 0.14
# Episode 587,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.14
# Episode 588,Opponent: ForgivingTitForTat, Reward: 224.00, Epsilon: 0.14
# Episode 589,Opponent: FoolMeOnce, Reward: 77.00, Epsilon: 0.14
# Episode 590,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.14
# Episode 591,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.14
# Episode 592,Opponent: CyclerCCCCCD, Reward: 344.00, Epsilon: 0.14
# Episode 593,Opponent: HardTitForTat, Reward: 238.00, Epsilon: 0.14
# Episode 594,Opponent: Gambler, Reward: 277.00, Epsilon: 0.14
# Episode 595,Opponent: FoolMeOnce, Reward: 67.00, Epsilon: 0.14
# Episode 596,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.14
# Episode 597,Opponent: ForgivingTitForTat, Reward: 272.00, Epsilon: 0.14
# Episode 598,Opponent: CyclerCCCCCD, Reward: 342.00, Epsilon: 0.14
# Episode 599,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.14
# Episode 600,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.14
# Episode 600, Avg Reward: 319.00, Epsilon: 0.14
# Episode 601,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.13
# Episode 602,Opponent: WinStayLoseShift, Reward: 221.00, Epsilon: 0.13
# Episode 603,Opponent: CyclerCCCCCD, Reward: 355.00, Epsilon: 0.13
# Episode 604,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.13
# Episode 605,Opponent: Grudger, Reward: 56.00, Epsilon: 0.13
# Episode 606,Opponent: EasyGo, Reward: 408.00, Epsilon: 0.13
# Episode 607,Opponent: HardTitForTat, Reward: 200.00, Epsilon: 0.13
# Episode 608,Opponent: WinStayLoseShift, Reward: 252.00, Epsilon: 0.13
# Episode 609,Opponent: Alternator, Reward: 227.00, Epsilon: 0.13
# Episode 610,Opponent: Alternator, Reward: 231.00, Epsilon: 0.13
# Episode 611,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.13
# Episode 612,Opponent: ForgivingTitForTat, Reward: 229.00, Epsilon: 0.13
# Episode 613,Opponent: Alternator, Reward: 237.00, Epsilon: 0.13
# Episode 614,Opponent: EasyGo, Reward: 423.00, Epsilon: 0.13
# Episode 615,Opponent: EasyGo, Reward: 425.00, Epsilon: 0.13
# Episode 616,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.13
# Episode 617,Opponent: FoolMeOnce, Reward: 87.00, Epsilon: 0.13
# Episode 618,Opponent: WinStayLoseShift, Reward: 234.00, Epsilon: 0.13
# Episode 619,Opponent: TitFor2Tats, Reward: 311.00, Epsilon: 0.13
# Episode 620,Opponent: EasyGo, Reward: 463.00, Epsilon: 0.13
# Episode 621,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.13
# Episode 622,Opponent: StochasticWSLS, Reward: 422.00, Epsilon: 0.13
# Episode 623,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.13
# Episode 624,Opponent: Alternator, Reward: 237.00, Epsilon: 0.12
# Episode 625,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.12
# Episode 626,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.12
# Episode 627,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.12
# Episode 628,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.12
# Episode 629,Opponent: WinStayLoseShift, Reward: 212.00, Epsilon: 0.12
# Episode 630,Opponent: Grudger, Reward: 59.00, Epsilon: 0.12
# Episode 631,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.12
# Episode 632,Opponent: Alternator, Reward: 244.00, Epsilon: 0.12
# Episode 633,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.12
# Episode 634,Opponent: Alternator, Reward: 247.00, Epsilon: 0.12
# Episode 635,Opponent: Gambler, Reward: 247.00, Epsilon: 0.12
# Episode 636,Opponent: CyclerCCCCCD, Reward: 356.00, Epsilon: 0.12
# Episode 637,Opponent: WinStayLoseShift, Reward: 245.00, Epsilon: 0.12
# Episode 638,Opponent: Alternator, Reward: 246.00, Epsilon: 0.12
# Episode 639,Opponent: FoolMeOnce, Reward: 39.00, Epsilon: 0.12
# Episode 640,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.12
# Episode 641,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.12
# Episode 642,Opponent: ForgivingTitForTat, Reward: 233.00, Epsilon: 0.12
# Episode 643,Opponent: Grudger, Reward: 73.00, Epsilon: 0.12
# Episode 644,Opponent: EasyGo, Reward: 480.00, Epsilon: 0.12
# Episode 645,Opponent: Alternator, Reward: 267.00, Epsilon: 0.12
# Episode 646,Opponent: Gambler, Reward: 230.00, Epsilon: 0.12
# Episode 647,Opponent: ForgivingTitForTat, Reward: 232.00, Epsilon: 0.12
# Episode 648,Opponent: StochasticWSLS, Reward: 472.00, Epsilon: 0.12
# Episode 649,Opponent: EasyGo, Reward: 474.00, Epsilon: 0.11
# Episode 650,Opponent: FoolMeOnce, Reward: 70.00, Epsilon: 0.11
# Episode 651,Opponent: CyclerCCCCCD, Reward: 394.00, Epsilon: 0.11
# Episode 652,Opponent: Alternator, Reward: 278.00, Epsilon: 0.11
# Episode 653,Opponent: WinStayLoseShift, Reward: 302.00, Epsilon: 0.11
# Episode 654,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.11
# Episode 655,Opponent: CyclerCCCCCD, Reward: 377.00, Epsilon: 0.11
# Episode 656,Opponent: FoolMeOnce, Reward: 62.00, Epsilon: 0.11
# Episode 657,Opponent: FoolMeOnce, Reward: 79.00, Epsilon: 0.11
# Episode 658,Opponent: StochasticWSLS, Reward: 500.00, Epsilon: 0.11
# Episode 659,Opponent: HardTitForTat, Reward: 164.00, Epsilon: 0.11
# Episode 660,Opponent: TitFor2Tats, Reward: 297.00, Epsilon: 0.11
# Episode 661,Opponent: ForgivingTitForTat, Reward: 229.00, Epsilon: 0.11
# Episode 662,Opponent: FoolMeOnce, Reward: 101.00, Epsilon: 0.11
# Episode 663,Opponent: StochasticWSLS, Reward: 470.00, Epsilon: 0.11
# Episode 664,Opponent: Gambler, Reward: 257.00, Epsilon: 0.11
# Episode 665,Opponent: HardTitForTat, Reward: 266.00, Epsilon: 0.11
# Episode 666,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.11
# Episode 667,Opponent: EasyGo, Reward: 447.00, Epsilon: 0.11
# Episode 668,Opponent: Gambler, Reward: 274.00, Epsilon: 0.11
# Episode 669,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.11
# Episode 670,Opponent: CyclerCCCCCD, Reward: 364.00, Epsilon: 0.11
# Episode 671,Opponent: WinStayLoseShift, Reward: 245.00, Epsilon: 0.11
# Episode 672,Opponent: Grudger, Reward: 80.00, Epsilon: 0.11
# Episode 673,Opponent: EasyGo, Reward: 435.00, Epsilon: 0.11
# Episode 674,Opponent: Grudger, Reward: 109.00, Epsilon: 0.11
# Episode 675,Opponent: HardTitForTat, Reward: 230.00, Epsilon: 0.11
# Episode 676,Opponent: SoftJoss, Reward: 376.00, Epsilon: 0.11
# Episode 677,Opponent: SoftJoss, Reward: 344.00, Epsilon: 0.10
# Episode 678,Opponent: Gambler, Reward: 258.00, Epsilon: 0.10
# Episode 679,Opponent: HardTitForTat, Reward: 284.00, Epsilon: 0.10
# Episode 680,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.10
# Episode 681,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.10
# Episode 682,Opponent: HardTitForTat, Reward: 229.00, Epsilon: 0.10
# Episode 683,Opponent: Alternator, Reward: 291.00, Epsilon: 0.10
# Episode 684,Opponent: FoolMeOnce, Reward: 75.00, Epsilon: 0.10
# Episode 685,Opponent: Grudger, Reward: 71.00, Epsilon: 0.10
# Episode 686,Opponent: SoftJoss, Reward: 490.00, Epsilon: 0.10
# Episode 687,Opponent: CyclerCCCCCD, Reward: 385.00, Epsilon: 0.10
# Episode 688,Opponent: EasyGo, Reward: 476.00, Epsilon: 0.10
# Episode 689,Opponent: CyclerCCCCCD, Reward: 406.00, Epsilon: 0.10
# Episode 690,Opponent: FoolMeOnce, Reward: 85.00, Epsilon: 0.10
# Episode 691,Opponent: StochasticWSLS, Reward: 478.00, Epsilon: 0.10
# Episode 692,Opponent: CyclerCCCCCD, Reward: 394.00, Epsilon: 0.10
# Episode 693,Opponent: CyclerCCCCCD, Reward: 372.00, Epsilon: 0.10
# Episode 694,Opponent: EasyGo, Reward: 476.00, Epsilon: 0.10
# Episode 695,Opponent: SoftJoss, Reward: 476.00, Epsilon: 0.10
# Episode 696,Opponent: Alternator, Reward: 296.00, Epsilon: 0.10
# Episode 697,Opponent: ForgivingTitForTat, Reward: 197.00, Epsilon: 0.10
# Episode 698,Opponent: Grudger, Reward: 60.00, Epsilon: 0.10
# Episode 699,Opponent: ForgivingTitForTat, Reward: 212.00, Epsilon: 0.10
# Episode 700,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.10
# Episode 700, Avg Reward: 462.00, Epsilon: 0.10
# Episode 701,Opponent: FoolMeOnce, Reward: 90.00, Epsilon: 0.10
# Episode 702,Opponent: Grudger, Reward: 144.00, Epsilon: 0.10
# Episode 703,Opponent: Gambler, Reward: 220.00, Epsilon: 0.10
# Episode 704,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.10
# Episode 705,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.10
# Episode 706,Opponent: CyclerCCCCCD, Reward: 354.00, Epsilon: 0.10
# Episode 707,Opponent: ForgivingTitForTat, Reward: 253.00, Epsilon: 0.09
# Episode 708,Opponent: FoolMeOnce, Reward: 63.00, Epsilon: 0.09
# Episode 709,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.09
# Episode 710,Opponent: SoftJoss, Reward: 416.00, Epsilon: 0.09
# Episode 711,Opponent: HardTitForTat, Reward: 227.00, Epsilon: 0.09
# Episode 712,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.09
# Episode 713,Opponent: SoftJoss, Reward: 396.00, Epsilon: 0.09
# Episode 714,Opponent: Grudger, Reward: 122.00, Epsilon: 0.09
# Episode 715,Opponent: WinStayLoseShift, Reward: 285.00, Epsilon: 0.09
# Episode 716,Opponent: ForgivingTitForTat, Reward: 201.00, Epsilon: 0.09
# Episode 717,Opponent: FoolMeOnce, Reward: 159.00, Epsilon: 0.09
# Episode 718,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.09
# Episode 719,Opponent: Alternator, Reward: 278.00, Epsilon: 0.09
# Episode 720,Opponent: ForgivingTitForTat, Reward: 215.00, Epsilon: 0.09
# Episode 721,Opponent: HardTitForTat, Reward: 241.00, Epsilon: 0.09
# Episode 722,Opponent: StochasticWSLS, Reward: 346.00, Epsilon: 0.09
# Episode 723,Opponent: HardTitForTat, Reward: 171.00, Epsilon: 0.09
# Episode 724,Opponent: Alternator, Reward: 284.00, Epsilon: 0.09
# Episode 725,Opponent: Grudger, Reward: 93.00, Epsilon: 0.09
# Episode 726,Opponent: CyclerCCCCCD, Reward: 328.00, Epsilon: 0.09
# Episode 727,Opponent: Alternator, Reward: 277.00, Epsilon: 0.09
# Episode 728,Opponent: Alternator, Reward: 278.00, Epsilon: 0.09
# Episode 729,Opponent: SoftJoss, Reward: 374.00, Epsilon: 0.09
# Episode 730,Opponent: EasyGo, Reward: 371.00, Epsilon: 0.09
# Episode 731,Opponent: EasyGo, Reward: 387.00, Epsilon: 0.09
# Episode 732,Opponent: CyclerCCCCCD, Reward: 347.00, Epsilon: 0.09
# Episode 733,Opponent: Grudger, Reward: 160.00, Epsilon: 0.09
# Episode 734,Opponent: TitFor2Tats, Reward: 311.00, Epsilon: 0.09
# Episode 735,Opponent: FoolMeOnce, Reward: 105.00, Epsilon: 0.09
# Episode 736,Opponent: FoolMeOnce, Reward: 91.00, Epsilon: 0.09
# Episode 737,Opponent: HardTitForTat, Reward: 250.00, Epsilon: 0.09
# ...
# Episode 755,Opponent: SoftJoss, Reward: 398.00, Epsilon: 0.08
# Episode 756,Opponent: CyclerCCCCCD, Reward: 355.00, Epsilon: 0.08
# Episode 757,Opponent: Alternator, Reward: 272.00, Epsilon: 0.08
# Episode 758,Opponent: CyclerCCCCCD, Reward: 355.00, Epsilon: 0.08
# Episode 759,Opponent: WinStayLoseShift, Reward: 293.00, Epsilon: 0.08
# Episode 760,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.08
# Episode 761,Opponent: WinStayLoseShift, Reward: 288.00, Epsilon: 0.08
# Episode 762,Opponent: StochasticWSLS, Reward: 460.00, Epsilon: 0.08
# Episode 763,Opponent: Grudger, Reward: 107.00, Epsilon: 0.08
# Episode 764,Opponent: EasyGo, Reward: 488.00, Epsilon: 0.08
# Episode 765,Opponent: TitFor2Tats, Reward: 290.00, Epsilon: 0.08
# Episode 766,Opponent: ForgivingTitForTat, Reward: 252.00, Epsilon: 0.08
# Episode 767,Opponent: SoftJoss, Reward: 474.00, Epsilon: 0.08
# Episode 768,Opponent: ForgivingTitForTat, Reward: 293.00, Epsilon: 0.08
# Episode 769,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.08
# Episode 770,Opponent: Alternator, Reward: 266.00, Epsilon: 0.08
# Episode 771,Opponent: TitFor2Tats, Reward: 298.00, Epsilon: 0.08
# Episode 772,Opponent: Alternator, Reward: 243.00, Epsilon: 0.08
# Episode 773,Opponent: WinStayLoseShift, Reward: 296.00, Epsilon: 0.08
# Episode 774,Opponent: Alternator, Reward: 252.00, Epsilon: 0.08
# Episode 775,Opponent: FoolMeOnce, Reward: 38.00, Epsilon: 0.08
# Episode 776,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.08
# Episode 777,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.08
# Episode 778,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.07
# Episode 779,Opponent: StochasticWSLS, Reward: 494.00, Epsilon: 0.07
# Episode 780,Opponent: StochasticWSLS, Reward: 494.00, Epsilon: 0.07
# Episode 781,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.07
# Episode 782,Opponent: HardTitForTat, Reward: 231.00, Epsilon: 0.07
# Episode 783,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.07
# Episode 784,Opponent: TitFor2Tats, Reward: 326.00, Epsilon: 0.07
# Episode 785,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.07
# Episode 786,Opponent: StochasticWSLS, Reward: 500.00, Epsilon: 0.07
# Episode 787,Opponent: Grudger, Reward: 37.00, Epsilon: 0.07
# Episode 788,Opponent: EasyGo, Reward: 462.00, Epsilon: 0.07
# Episode 789,Opponent: EasyGo, Reward: 474.00, Epsilon: 0.07
# Episode 790,Opponent: FoolMeOnce, Reward: 55.00, Epsilon: 0.07
# Episode 791,Opponent: SoftJoss, Reward: 494.00, Epsilon: 0.07
# Episode 792,Opponent: Alternator, Reward: 299.00, Epsilon: 0.07
# Episode 793,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.07
# Episode 794,Opponent: SoftJoss, Reward: 484.00, Epsilon: 0.07
# Episode 795,Opponent: Grudger, Reward: 44.00, Epsilon: 0.07
# Episode 796,Opponent: FoolMeOnce, Reward: 51.00, Epsilon: 0.07
# Episode 797,Opponent: FoolMeOnce, Reward: 42.00, Epsilon: 0.07
# Episode 798,Opponent: Grudger, Reward: 51.00, Epsilon: 0.07
# Episode 799,Opponent: Gambler, Reward: 230.00, Epsilon: 0.07
# Episode 800,Opponent: StochasticWSLS, Reward: 496.00, Epsilon: 0.07
# Episode 800, Avg Reward: 496.00, Epsilon: 0.07
# Episode 801,Opponent: Alternator, Reward: 264.00, Epsilon: 0.07
# Episode 802,Opponent: Grudger, Reward: 69.00, Epsilon: 0.07
# Episode 803,Opponent: ForgivingTitForTat, Reward: 261.00, Epsilon: 0.07
# Episode 804,Opponent: SoftJoss, Reward: 484.00, Epsilon: 0.07
# Episode 805,Opponent: Gambler, Reward: 289.00, Epsilon: 0.07
# Episode 806,Opponent: EasyGo, Reward: 458.00, Epsilon: 0.07
# Episode 807,Opponent: Gambler, Reward: 277.00, Epsilon: 0.07
# Episode 808,Opponent: Alternator, Reward: 283.00, Epsilon: 0.07
# Episode 809,Opponent: Gambler, Reward: 268.00, Epsilon: 0.07
# Episode 810,Opponent: SoftJoss, Reward: 416.00, Epsilon: 0.07
# Episode 811,Opponent: Gambler, Reward: 227.00, Epsilon: 0.07
# Episode 812,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.07
# Episode 813,Opponent: StochasticWSLS, Reward: 374.00, Epsilon: 0.07
# Episode 814,Opponent: HardTitForTat, Reward: 180.00, Epsilon: 0.07
# Episode 815,Opponent: Gambler, Reward: 271.00, Epsilon: 0.07
# Episode 816,Opponent: HardTitForTat, Reward: 162.00, Epsilon: 0.07
# Episode 817,Opponent: Gambler, Reward: 239.00, Epsilon: 0.07
# Episode 818,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.07
# Episode 819,Opponent: SoftJoss, Reward: 484.00, Epsilon: 0.07
# Episode 820,Opponent: ForgivingTitForTat, Reward: 243.00, Epsilon: 0.07
# Episode 821,Opponent: Gambler, Reward: 247.00, Epsilon: 0.06
# Episode 822,Opponent: HardTitForTat, Reward: 225.00, Epsilon: 0.06
# Episode 823,Opponent: ForgivingTitForTat, Reward: 289.00, Epsilon: 0.06
# Episode 824,Opponent: FoolMeOnce, Reward: 56.00, Epsilon: 0.06
# Episode 825,Opponent: CyclerCCCCCD, Reward: 339.00, Epsilon: 0.06
# Episode 826,Opponent: Gambler, Reward: 292.00, Epsilon: 0.06
# Episode 827,Opponent: StochasticWSLS, Reward: 462.00, Epsilon: 0.06
# Episode 828,Opponent: HardTitForTat, Reward: 210.00, Epsilon: 0.06
# Episode 829,Opponent: HardTitForTat, Reward: 227.00, Epsilon: 0.06
# Episode 830,Opponent: EasyGo, Reward: 456.00, Epsilon: 0.06
# Episode 831,Opponent: TitFor2Tats, Reward: 308.00, Epsilon: 0.06
# Episode 832,Opponent: Grudger, Reward: 109.00, Epsilon: 0.06
# Episode 833,Opponent: CyclerCCCCCD, Reward: 322.00, Epsilon: 0.06
# Episode 834,Opponent: Gambler, Reward: 280.00, Epsilon: 0.06
# Episode 835,Opponent: HardTitForTat, Reward: 277.00, Epsilon: 0.06
# Episode 836,Opponent: ForgivingTitForTat, Reward: 281.00, Epsilon: 0.06
# Episode 837,Opponent: Alternator, Reward: 272.00, Epsilon: 0.06
# Episode 838,Opponent: HardTitForTat, Reward: 275.00, Epsilon: 0.06
# Episode 839,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.06
# Episode 840,Opponent: SoftJoss, Reward: 416.00, Epsilon: 0.06
# Episode 841,Opponent: TitFor2Tats, Reward: 349.00, Epsilon: 0.06
# Episode 842,Opponent: FoolMeOnce, Reward: 79.00, Epsilon: 0.06
# Episode 843,Opponent: EasyGo, Reward: 440.00, Epsilon: 0.06
# Episode 844,Opponent: Grudger, Reward: 35.00, Epsilon: 0.06
# Episode 845,Opponent: CyclerCCCCCD, Reward: 332.00, Epsilon: 0.06
# Episode 846,Opponent: EasyGo, Reward: 462.00, Epsilon: 0.06
# Episode 847,Opponent: StochasticWSLS, Reward: 474.00, Epsilon: 0.06
# Episode 848,Opponent: FoolMeOnce, Reward: 176.00, Epsilon: 0.06
# Episode 849,Opponent: ForgivingTitForTat, Reward: 282.00, Epsilon: 0.06
# Episode 850,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.06
# Episode 851,Opponent: FoolMeOnce, Reward: 144.00, Epsilon: 0.06
# Episode 852,Opponent: EasyGo, Reward: 454.00, Epsilon: 0.06
# Episode 853,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.06
# Episode 854,Opponent: FoolMeOnce, Reward: 98.00, Epsilon: 0.06
# Episode 855,Opponent: StochasticWSLS, Reward: 484.00, Epsilon: 0.06
# Episode 856,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.06
# Episode 857,Opponent: CyclerCCCCCD, Reward: 346.00, Epsilon: 0.06
# Episode 858,Opponent: WinStayLoseShift, Reward: 297.00, Epsilon: 0.06
# Episode 859,Opponent: FoolMeOnce, Reward: 70.00, Epsilon: 0.06
# Episode 860,Opponent: ForgivingTitForTat, Reward: 270.00, Epsilon: 0.06
# Episode 861,Opponent: WinStayLoseShift, Reward: 299.00, Epsilon: 0.06
# Episode 862,Opponent: WinStayLoseShift, Reward: 297.00, Epsilon: 0.06
# Episode 863,Opponent: EasyGo, Reward: 456.00, Epsilon: 0.06
# Episode 864,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.06
# Episode 865,Opponent: TitFor2Tats, Reward: 342.00, Epsilon: 0.06
# Episode 866,Opponent: Grudger, Reward: 49.00, Epsilon: 0.06
# Episode 867,Opponent: Grudger, Reward: 49.00, Epsilon: 0.06
# Episode 868,Opponent: Grudger, Reward: 43.00, Epsilon: 0.06
# Episode 869,Opponent: Grudger, Reward: 47.00, Epsilon: 0.06
# Episode 870,Opponent: Gambler, Reward: 261.00, Epsilon: 0.06
# Episode 871,Opponent: Grudger, Reward: 43.00, Epsilon: 0.05
# Episode 872,Opponent: StochasticWSLS, Reward: 452.00, Epsilon: 0.05
# Episode 873,Opponent: Alternator, Reward: 251.00, Epsilon: 0.05
# Episode 874,Opponent: WinStayLoseShift, Reward: 276.00, Epsilon: 0.05
# Episode 875,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.05
# Episode 876,Opponent: ForgivingTitForTat, Reward: 296.00, Epsilon: 0.05
# Episode 877,Opponent: TitFor2Tats, Reward: 317.00, Epsilon: 0.05
# Episode 878,Opponent: HardTitForTat, Reward: 289.00, Epsilon: 0.05
# Episode 879,Opponent: EasyGo, Reward: 444.00, Epsilon: 0.05
# Episode 880,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.05
# Episode 881,Opponent: EasyGo, Reward: 446.00, Epsilon: 0.05
# Episode 882,Opponent: HardTitForTat, Reward: 291.00, Epsilon: 0.05
# Episode 883,Opponent: TitFor2Tats, Reward: 338.00, Epsilon: 0.05
# Episode 884,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.05
# Episode 885,Opponent: Grudger, Reward: 96.00, Epsilon: 0.05
# Episode 886,Opponent: CyclerCCCCCD, Reward: 315.00, Epsilon: 0.05
# Episode 887,Opponent: Gambler, Reward: 294.00, Epsilon: 0.05
# Episode 888,Opponent: StochasticWSLS, Reward: 368.00, Epsilon: 0.05
# Episode 889,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.05
# Episode 890,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.05
# Episode 891,Opponent: CyclerCCCCCD, Reward: 337.00, Epsilon: 0.05
# Episode 892,Opponent: WinStayLoseShift, Reward: 285.00, Epsilon: 0.05
# Episode 893,Opponent: Gambler, Reward: 298.00, Epsilon: 0.05
# Episode 894,Opponent: WinStayLoseShift, Reward: 300.00, Epsilon: 0.05
# Episode 895,Opponent: Grudger, Reward: 236.00, Epsilon: 0.05
# Episode 896,Opponent: CyclerCCCCCD, Reward: 336.00, Epsilon: 0.05
# Episode 897,Opponent: TitFor2Tats, Reward: 335.00, Epsilon: 0.05
# Episode 898,Opponent: FoolMeOnce, Reward: 91.00, Epsilon: 0.05
# Episode 899,Opponent: Grudger, Reward: 164.00, Epsilon: 0.05
# Episode 900,Opponent: CyclerCCCCCD, Reward: 346.00, Epsilon: 0.05
# Episode 900, Avg Reward: 346.00, Epsilon: 0.05
# Episode 901,Opponent: ForgivingTitForTat, Reward: 300.00, Epsilon: 0.05
# Episode 902,Opponent: SoftJoss, Reward: 392.00, Epsilon: 0.05
# Episode 903,Opponent: Gambler, Reward: 281.00, Epsilon: 0.05
# Episode 904,Opponent: WinStayLoseShift, Reward: 276.00, Epsilon: 0.05
# Episode 905,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.05
# Episode 906,Opponent: StochasticWSLS, Reward: 404.00, Epsilon: 0.05
# Episode 907,Opponent: FoolMeOnce, Reward: 173.00, Epsilon: 0.05
# Episode 908,Opponent: StochasticWSLS, Reward: 390.00, Epsilon: 0.05
# Episode 909,Opponent: SoftJoss, Reward: 426.00, Epsilon: 0.05
# Episode 910,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.05
# Episode 911,Opponent: Gambler, Reward: 282.00, Epsilon: 0.05
# Episode 912,Opponent: SoftJoss, Reward: 324.00, Epsilon: 0.05
# Episode 913,Opponent: EasyGo, Reward: 361.00, Epsilon: 0.05
# Episode 914,Opponent: TitFor2Tats, Reward: 362.00, Epsilon: 0.05
# Episode 915,Opponent: Grudger, Reward: 88.00, Epsilon: 0.05
# Episode 916,Opponent: TitFor2Tats, Reward: 332.00, Epsilon: 0.05
# Episode 917,Opponent: StochasticWSLS, Reward: 358.00, Epsilon: 0.05
# Episode 918,Opponent: Alternator, Reward: 256.00, Epsilon: 0.05
# Episode 919,Opponent: EasyGo, Reward: 360.00, Epsilon: 0.05
# Episode 920,Opponent: Gambler, Reward: 287.00, Epsilon: 0.05
# Episode 921,Opponent: EasyGo, Reward: 380.00, Epsilon: 0.05
# Episode 922,Opponent: HardTitForTat, Reward: 184.00, Epsilon: 0.05
# Episode 923,Opponent: EasyGo, Reward: 466.00, Epsilon: 0.05
# Episode 924,Opponent: Alternator, Reward: 268.00, Epsilon: 0.05
# Episode 925,Opponent: SoftJoss, Reward: 458.00, Epsilon: 0.05
# Episode 926,Opponent: Alternator, Reward: 245.00, Epsilon: 0.05
# Episode 927,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.05
# Episode 928,Opponent: FoolMeOnce, Reward: 44.00, Epsilon: 0.05
# Episode 929,Opponent: SoftJoss, Reward: 460.00, Epsilon: 0.05
# Episode 930,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.05
# Episode 931,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.05
# Episode 932,Opponent: ForgivingTitForTat, Reward: 290.00, Epsilon: 0.05
# Episode 933,Opponent: Grudger, Reward: 73.00, Epsilon: 0.05
# Episode 934,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.05
# Episode 935,Opponent: ForgivingTitForTat, Reward: 259.00, Epsilon: 0.05
# Episode 936,Opponent: StochasticWSLS, Reward: 470.00, Epsilon: 0.05
# Episode 937,Opponent: CyclerCCCCCD, Reward: 354.00, Epsilon: 0.05
# Episode 938,Opponent: HardTitForTat, Reward: 162.00, Epsilon: 0.05
# Episode 939,Opponent: Grudger, Reward: 65.00, Epsilon: 0.05
# Episode 940,Opponent: FoolMeOnce, Reward: 45.00, Epsilon: 0.05
# Episode 941,Opponent: FoolMeOnce, Reward: 53.00, Epsilon: 0.05
# Episode 942,Opponent: WinStayLoseShift, Reward: 219.00, Epsilon: 0.05
# Episode 943,Opponent: StochasticWSLS, Reward: 366.00, Epsilon: 0.05
# Episode 944,Opponent: ForgivingTitForTat, Reward: 282.00, Epsilon: 0.05
# Episode 945,Opponent: HardTitForTat, Reward: 200.00, Epsilon: 0.05
# Episode 946,Opponent: StochasticWSLS, Reward: 354.00, Epsilon: 0.05
# Episode 947,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.05
# Episode 948,Opponent: WinStayLoseShift, Reward: 192.00, Epsilon: 0.05
# Episode 949,Opponent: Alternator, Reward: 247.00, Epsilon: 0.05
# Episode 950,Opponent: ForgivingTitForTat, Reward: 284.00, Epsilon: 0.05
# Episode 951,Opponent: EasyGo, Reward: 358.00, Epsilon: 0.05
# Episode 952,Opponent: Gambler, Reward: 270.00, Epsilon: 0.05
# Episode 953,Opponent: CyclerCCCCCD, Reward: 347.00, Epsilon: 0.05
# Episode 954,Opponent: ForgivingTitForTat, Reward: 275.00, Epsilon: 0.05
# Episode 955,Opponent: StochasticWSLS, Reward: 372.00, Epsilon: 0.05
# Episode 956,Opponent: Gambler, Reward: 264.00, Epsilon: 0.05
# Episode 957,Opponent: HardTitForTat, Reward: 247.00, Epsilon: 0.05
# Episode 958,Opponent: CyclerCCCCCD, Reward: 358.00, Epsilon: 0.05
# Episode 959,Opponent: SoftJoss, Reward: 478.00, Epsilon: 0.05
# Episode 960,Opponent: TitFor2Tats, Reward: 340.00, Epsilon: 0.05
# Episode 961,Opponent: CyclerCCCCCD, Reward: 365.00, Epsilon: 0.05
# Episode 962,Opponent: SoftJoss, Reward: 488.00, Epsilon: 0.05
# Episode 963,Opponent: WinStayLoseShift, Reward: 227.00, Epsilon: 0.05
# Episode 964,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.05
# Episode 965,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.05
# Episode 966,Opponent: Grudger, Reward: 171.00, Epsilon: 0.05
# Episode 967,Opponent: CyclerCCCCCD, Reward: 370.00, Epsilon: 0.05
# Episode 968,Opponent: Gambler, Reward: 292.00, Epsilon: 0.05
# Episode 969,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.05
# Episode 970,Opponent: Gambler, Reward: 285.00, Epsilon: 0.05
# Episode 971,Opponent: TitFor2Tats, Reward: 338.00, Epsilon: 0.05
# Episode 972,Opponent: Alternator, Reward: 204.00, Epsilon: 0.05
# Episode 973,Opponent: Gambler, Reward: 284.00, Epsilon: 0.05
# Episode 974,Opponent: SoftJoss, Reward: 328.00, Epsilon: 0.05
# Episode 975,Opponent: SoftJoss, Reward: 450.00, Epsilon: 0.05
# Episode 976,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.05
# Episode 977,Opponent: Grudger, Reward: 61.00, Epsilon: 0.05
# Episode 978,Opponent: Grudger, Reward: 248.00, Epsilon: 0.05
# Episode 979,Opponent: EasyGo, Reward: 474.00, Epsilon: 0.05
# Episode 980,Opponent: Gambler, Reward: 292.00, Epsilon: 0.05
# Episode 981,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.05
# Episode 982,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.05
# Episode 983,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.05
# Episode 984,Opponent: TitFor2Tats, Reward: 317.00, Epsilon: 0.05
# Episode 985,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.05
# Episode 986,Opponent: FoolMeOnce, Reward: 72.00, Epsilon: 0.05
# Episode 987,Opponent: WinStayLoseShift, Reward: 242.00, Epsilon: 0.05
# Episode 988,Opponent: Grudger, Reward: 300.00, Epsilon: 0.05
# Episode 989,Opponent: Alternator, Reward: 182.00, Epsilon: 0.05
# Episode 990,Opponent: FoolMeOnce, Reward: 300.00, Epsilon: 0.05
# Episode 991,Opponent: Grudger, Reward: 75.00, Epsilon: 0.05
# Episode 992,Opponent: TitFor2Tats, Reward: 302.00, Epsilon: 0.05
# Episode 993,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.05
# Episode 994,Opponent: Alternator, Reward: 286.00, Epsilon: 0.05
# Episode 995,Opponent: EasyGo, Reward: 476.00, Epsilon: 0.05
# Episode 996,Opponent: FoolMeOnce, Reward: 62.00, Epsilon: 0.05
# Episode 997,Opponent: StochasticWSLS, Reward: 480.00, Epsilon: 0.05
# Episode 998,Opponent: Grudger, Reward: 84.00, Epsilon: 0.05
# Episode 999,Opponent: ForgivingTitForTat, Reward: 287.00, Epsilon: 0.05
# <Axes: >

# %%
# === RL Wrapper for Axelrod Tournament ===
import axelrod as axl
import torch
from axelrod.action import Action
import numpy as np
from collections import defaultdict
from statistics import mean

C, D = Action.C, Action.D

class RLWrapper(axl.Player):
    name = "RL Agent"

    def __init__(self, policy_net, history_len=10):
        super().__init__()
        self.policy_net = policy_net
        self.history_len = history_len

    def strategy(self, opponent):
        padded_self = [0] * (self.history_len - len(self.history)) + [
            0 if action == C else 1 for action in self.history[-self.history_len:]
        ]
        padded_opp = [0] * (self.history_len - len(opponent.history)) + [
            0 if action == C else 1 for action in opponent.history[-self.history_len:]
        ]
        state = torch.tensor(padded_self + padded_opp, dtype=torch.float32)
        with torch.no_grad():
            action_index = self.policy_net(state.unsqueeze(0)).argmax().item()
        return C if action_index == 0 else D

    def __repr__(self):
        return self.name


policy_net1 = DQNCNN(input_channels=2, seq_len=10, output_dim=2)
policy_net1.load_state_dict(torch.load("dqn_policy.pth"))
policy_net1.eval()

policy_net2 = DQNCNN(input_channels=2, seq_len=10, output_dim=2)
policy_net2.load_state_dict(torch.load("dqn_policy.pth"))
policy_net2.eval()

strategies = [
    axl.Defector(),
    axl.Cooperator(),
    axl.TitForTat(),
    axl.SuspiciousTitForTat(),
    RLWrapper(policy_net1),
    axl.FirstByJoss(),
    axl.StochasticCooperator(),
    axl.Calculator(),
    axl.BackStabber(),
    axl.MathConstantHunter(),
    axl.SneakyTitForTat(),
    axl.Handshake(),
    axl.CyclerCCD(),
    # Uncomment for expanded version of the tournament
    # RLWrapper(policy_net2),
    # axl.Alternator(),
    # axl.Inverse(),
    # axl.InversePunisher(),
    # axl.MetaWinnerStochastic(),
    # axl.DoubleCrosser(),
    # axl.DelayedAON1()
 ]


tournament = axl.Tournament(strategies, turns=100)
results = tournament.play()
scores_matrix = results.scores
average_scores = average_scores = [np.mean(score_row) for score_row in scores_matrix]

# Print strategies sorted by average score
print("\nΚατάταξη στρατηγικών βάσει μέσου σκορ:")
sorted_by_score = sorted(zip(results.players, average_scores), key=lambda x: -x[1])
for i, (player, score) in enumerate(sorted_by_score):
    print(f"{i+1}. {player}: {score:.2f}")
# Out:
# Playing matches: 100%|██████████| 91/91 [00:02<00:00, 37.81it/s]
# Analysing: 100%|██████████| 25/25 [00:01<00:00, 19.62it/s]
# Κατάταξη στρατηγικών βάσει μέσου σκορ:
# 1. RL Agent: 2933.80
# 2. Defector: 2884.40
# 3. BackStabber: (D, D): 2880.20
# 4. Tit For Tat: 2781.30
# 5. Calculator: 2772.60
# 6. Sneaky Tit For Tat: 2740.00
# 7. Math Constant Hunter: 2684.20
# 8. Stochastic Cooperator: 2663.00
# 9. Handshake: 2637.60
# 10. Suspicious Tit For Tat: 2617.60
# 11. First by Joss: 0.9: 2457.20
# 12. Cooperator: 2260.50
# 13. Cycler CCD: 2020.10

# %%
# Show the agent moves to be precise (log each round)
policy_net.load_state_dict(torch.load("dqn_policy.pth"))
policy_net.eval()

env = IPDEnv(axl.TitForTat())  # Choose opponent
state = env.reset()
done = False
round_num = 1
total_test_reward = 0

print("Round | Agent | Opponent")

while not done:
    with torch.no_grad():
        action = policy_net(state.unsqueeze(0)).argmax().item()

    next_state, reward, done = env.step(action)

    # Decode moves
    agent_move = 'C' if env.agent_history[-1] == 0 else 'D'
    opponent_move = 'C' if env.opp_history[-1] == 0 else 'D'

    print(f"{round_num:>5} |   {agent_move}   |    {opponent_move}")

    state = next_state
    round_num += 1
    total_test_reward += reward

print("Total reward:" , total_test_reward)
# Out:
# Round | Agent | Opponent
#     1 |   C   |    C
#     2 |   C   |    C
#     3 |   C   |    C
#     4 |   C   |    C
#     5 |   C   |    C
#     6 |   C   |    C
#     7 |   C   |    C
#     8 |   C   |    C
#     9 |   C   |    C
#    10 |   C   |    C
#    11 |   C   |    C
#    12 |   C   |    C
#    13 |   C   |    C
#    14 |   C   |    C
#    15 |   C   |    C
#    16 |   C   |    C
#    17 |   C   |    C
#    18 |   C   |    C
#    19 |   C   |    C
#    20 |   C   |    C
#    21 |   C   |    C
#    22 |   C   |    C
#    23 |   C   |    C
#    24 |   C   |    C
#    25 |   C   |    C
#    26 |   C   |    C
#    27 |   C   |    C
#    28 |   C   |    C
#    29 |   C   |    C
#    30 |   C   |    C
#    31 |   C   |    C
#    32 |   C   |    C
#    33 |   C   |    C
#    34 |   C   |    C
#    35 |   C   |    C
#    36 |   C   |    C
#    37 |   C   |    C
#    38 |   C   |    C
#    39 |   C   |    C
#    40 |   C   |    C
#    41 |   C   |    C
#    42 |   C   |    C
#    43 |   C   |    C
#    44 |   C   |    C
#    45 |   C   |    C
#    46 |   C   |    C
#    47 |   C   |    C
#    48 |   C   |    C
#    49 |   C   |    C
#    50 |   C   |    C
#    51 |   C   |    C
#    52 |   C   |    C
#    53 |   C   |    C
#    54 |   C   |    C
#    55 |   C   |    C
#    56 |   C   |    C
#    57 |   C   |    C
#    58 |   C   |    C
#    59 |   C   |    C
#    60 |   C   |    C
#    61 |   C   |    C
#    62 |   C   |    C
#    63 |   C   |    C
#    64 |   C   |    C
#    65 |   C   |    C
#    66 |   C   |    C
#    67 |   C   |    C
#    68 |   C   |    C
#    69 |   C   |    C
#    70 |   C   |    C
#    71 |   C   |    C
#    72 |   C   |    C
#    73 |   C   |    C
#    74 |   C   |    C
#    75 |   C   |    C
#    76 |   C   |    C
#    77 |   C   |    C
#    78 |   C   |    C
#    79 |   C   |    C
#    80 |   C   |    C
#    81 |   C   |    C
#    82 |   C   |    C
#    83 |   C   |    C
#    84 |   C   |    C
#    85 |   C   |    C
#    86 |   C   |    C
#    87 |   C   |    C
#    88 |   C   |    C
#    89 |   C   |    C
#    90 |   C   |    C
#    91 |   C   |    C
#    92 |   C   |    C
#    93 |   C   |    C
#    94 |   C   |    C
#    95 |   C   |    C
#    96 |   C   |    C
#    97 |   C   |    C
#    98 |   C   |    C
#    99 |   C   |    C
#   100 |   C   |    C
# Total reward: 300
