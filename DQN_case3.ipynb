# %%
# !pip install axelrod
# Out:
# Collecting axelrod
#   Downloading axelrod-4.13.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.1.1)
# Requirement already satisfied: dask>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (2024.12.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2025.3.2)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.0.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from axelrod) (6.0.2)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (1.15.3)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (0.12.1)
# Requirement already satisfied: tqdm>=4.39.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.7.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (1.1.21)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.9.2->axelrod) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->axelrod) (1.17.0)
# Downloading axelrod-4.13.1-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: axelrod
# Successfully installed axelrod-4.13.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from collections import deque
import axelrod as axl
from axelrod.action import Action
C, D = Action.C, Action.D

# %%
# Reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
# IPD Environment
class IPDEnv:
    def __init__(self, opponent, history_len=10, max_turns=100):
        self.opponent = opponent
        self.history_len = history_len
        self.max_turns = max_turns
        self.reset()

    def reset(self):
        self.agent = axl.Player()
        self.opponent.reset()
        self.agent_history = []
        self.opp_history = []
        self.turn = 0
        return self._get_state()

    def _get_state(self):
        padded_agent = [0] * (self.history_len - len(self.agent_history)) + self.agent_history[-self.history_len:]
        padded_opp = [0] * (self.history_len - len(self.opp_history)) + self.opp_history[-self.history_len:]
        return torch.tensor(padded_agent + padded_opp, dtype=torch.float32)

    def step(self, action):
        agent_action = C if action == 0 else D
        opp_action = self.opponent.strategy(self.agent)

        # Record moves in the agent's and oponnents history
        self.agent.history.append(agent_action, opp_action)
        self.opponent.history.append(opp_action, agent_action)

        # Also update the raw binary history for state vector
        self.agent_history.append(0 if agent_action == C else 1)
        self.opp_history.append(0 if opp_action == C else 1)

        payoff_matrix = {
            (C, C): (3, 3),
            (C, D): (0, 5),
            (D, C): (5, 0),
            (D, D): (1, 1)
        }

        reward, _ = payoff_matrix[(agent_action, opp_action)]
        self.turn += 1
        done = self.turn >= self.max_turns

        return self._get_state(), reward, done

# %%
# DQN Network and Replay Buffer
# Deeper NN
class DQN(nn.Module):
    def __init__(self, input_dim, hidden1=128, hidden2=64, output_dim=2):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.ReLU(),
            nn.Linear(hidden1, hidden2),
            nn.ReLU(),
            nn.Linear(hidden2, output_dim)
        )

    def forward(self, x):
        return self.net(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(state, dtype=torch.float32),
            torch.tensor(action, dtype=torch.int64),
            torch.tensor(reward, dtype=torch.float32),
            torch.tensor(next_state, dtype=torch.float32),
            torch.tensor(done, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)

# %%
# Training Setup
input_dim = 20
output_dim = 2
hidden1 = 128
hidden2 = 64
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
lr = 1e-3
batch_size = 64
num_episodes = 500

epsilon_decay = (epsilon_min / epsilon) ** (1 / (num_episodes * 0.9))
print(f"Epsilon decay: {epsilon_decay:.9f}")


policy_net = DQN(input_dim, hidden1=128, hidden2=64, output_dim=2)
target_net = DQN(input_dim, hidden1=128, hidden2=64, output_dim=2)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=lr)
replay_buffer = ReplayBuffer(10000)

def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.randint(0, 1)
    with torch.no_grad():
        return policy_net(state.unsqueeze(0)).argmax().item()
# Out:
# Epsilon decay: 0.993364927

# %%
# Opponent pool
opponent_pool = [
    # Group 1: Exploitable & Naive
    axl.CyclerCCCCCD(),
    axl.EasyGo(),
    axl.Alternator(),

    # Group 2: Punishing/Retaliatory & Reactive
    axl.Grudger(),
    axl.ForgivingTitForTat(),
    axl.HardTitForTat(),

    # Group 3: Stochastic & Noisy
    axl.Gambler(),
    axl.SoftJoss(),
    axl.StochasticWSLS(),

    # Group 4: Deceptive & Pattern-Based
    axl.WinStayLoseShift(),
    axl.TitFor2Tats(),
    axl.FoolMeOnce()
]

# Define rewards for plotting and evaluation
Total_reward = 0
avg_rewards = []


# Best till now
for episode in range(num_episodes):
    opponent = random.choice(opponent_pool)          # 🆕 random opponent
    env = IPDEnv(opponent)                           # 🆕 new environment with that opponent
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = select_action(state, epsilon)
        next_state, reward, done = env.step(action)
        replay_buffer.push(state.numpy(), action, reward, next_state.numpy(), done)
        state = next_state
        total_reward += reward

        if len(replay_buffer) >= batch_size:
            s, a, r, s2, d = replay_buffer.sample(batch_size)
            q_vals = policy_net(s).gather(1, a.unsqueeze(1)).squeeze()
            next_q_vals = target_net(s2).max(1)[0]
            target = r + gamma * next_q_vals * (1 - d)
            loss = nn.MSELoss()(q_vals, target.detach())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    if episode % 10 == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    avg_rewards.append(total_reward)
    print(f"Episode {episode},Opponent: {type(opponent).__name__}, Reward: {total_reward:.2f}, Epsilon: {epsilon:.2f}")


torch.save(policy_net.state_dict(), "dqn_policy.pth")

# Plot reward curve
plt.plot(avg_rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward per Episode")
plt.title("Learning Curve")
plt.grid(True)
plt.show()

pd.Series(avg_rewards).rolling(50).mean().plot()
# Out:
# Episode 0,Opponent: TitFor2Tats, Reward: 295.00, Epsilon: 0.99
# Episode 1,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.99
# Episode 2,Opponent: Grudger, Reward: 54.00, Epsilon: 0.98
# Episode 3,Opponent: CyclerCCCCCD, Reward: 341.00, Epsilon: 0.97
# Episode 4,Opponent: Grudger, Reward: 64.00, Epsilon: 0.97
# Episode 5,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.96
# Episode 6,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.95
# Episode 7,Opponent: WinStayLoseShift, Reward: 246.00, Epsilon: 0.95
# Episode 8,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.94
# Episode 9,Opponent: Gambler, Reward: 228.00, Epsilon: 0.94
# Episode 10,Opponent: FoolMeOnce, Reward: 61.00, Epsilon: 0.93
# Episode 11,Opponent: StochasticWSLS, Reward: 412.00, Epsilon: 0.92
# Episode 12,Opponent: CyclerCCCCCD, Reward: 345.00, Epsilon: 0.92
# Episode 13,Opponent: WinStayLoseShift, Reward: 213.00, Epsilon: 0.91
# Episode 14,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.90
# Episode 15,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.90
# Episode 16,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.89
# Episode 17,Opponent: Alternator, Reward: 219.00, Epsilon: 0.89
# Episode 18,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.88
# Episode 19,Opponent: Grudger, Reward: 53.00, Epsilon: 0.88
# Episode 20,Opponent: ForgivingTitForTat, Reward: 223.00, Epsilon: 0.87
# Episode 21,Opponent: WinStayLoseShift, Reward: 218.00, Epsilon: 0.86
# Episode 22,Opponent: EasyGo, Reward: 404.00, Epsilon: 0.86
# Episode 23,Opponent: TitFor2Tats, Reward: 296.00, Epsilon: 0.85
# Episode 24,Opponent: Gambler, Reward: 237.00, Epsilon: 0.85
# Episode 25,Opponent: Alternator, Reward: 240.00, Epsilon: 0.84
# Episode 26,Opponent: EasyGo, Reward: 402.00, Epsilon: 0.84
# Episode 27,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.83
# Episode 28,Opponent: Grudger, Reward: 62.00, Epsilon: 0.82
# Episode 29,Opponent: TitFor2Tats, Reward: 313.00, Epsilon: 0.82
# Episode 30,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.81
# Episode 31,Opponent: CyclerCCCCCD, Reward: 361.00, Epsilon: 0.81
# Episode 32,Opponent: CyclerCCCCCD, Reward: 353.00, Epsilon: 0.80
# Episode 33,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.80
# Episode 34,Opponent: SoftJoss, Reward: 416.00, Epsilon: 0.79
# Episode 35,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.79
# Episode 36,Opponent: EasyGo, Reward: 406.00, Epsilon: 0.78
# Episode 37,Opponent: HardTitForTat, Reward: 97.00, Epsilon: 0.78
# Episode 38,Opponent: Grudger, Reward: 62.00, Epsilon: 0.77
# Episode 39,Opponent: Gambler, Reward: 223.00, Epsilon: 0.77
# Episode 40,Opponent: CyclerCCCCCD, Reward: 362.00, Epsilon: 0.76
# Episode 41,Opponent: Grudger, Reward: 69.00, Epsilon: 0.76
# Episode 42,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.75
# Episode 43,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.75
# Episode 44,Opponent: ForgivingTitForTat, Reward: 227.00, Epsilon: 0.74
# Episode 45,Opponent: ForgivingTitForTat, Reward: 236.00, Epsilon: 0.74
# Episode 46,Opponent: CyclerCCCCCD, Reward: 374.00, Epsilon: 0.73
# Episode 47,Opponent: TitFor2Tats, Reward: 310.00, Epsilon: 0.73
# Episode 48,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.72
# Episode 49,Opponent: ForgivingTitForTat, Reward: 231.00, Epsilon: 0.72
# Episode 50,Opponent: ForgivingTitForTat, Reward: 223.00, Epsilon: 0.71
# Episode 51,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.71
# Episode 52,Opponent: Gambler, Reward: 250.00, Epsilon: 0.70
# Episode 53,Opponent: CyclerCCCCCD, Reward: 378.00, Epsilon: 0.70
# Episode 54,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.69
# Episode 55,Opponent: Gambler, Reward: 242.00, Epsilon: 0.69
# Episode 56,Opponent: Grudger, Reward: 65.00, Epsilon: 0.68
# Episode 57,Opponent: Alternator, Reward: 241.00, Epsilon: 0.68
# Episode 58,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.68
# Episode 59,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.67
# Episode 60,Opponent: CyclerCCCCCD, Reward: 370.00, Epsilon: 0.67
# Episode 61,Opponent: EasyGo, Reward: 444.00, Epsilon: 0.66
# Episode 62,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.66
# Episode 63,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.65
# Episode 64,Opponent: TitFor2Tats, Reward: 314.00, Epsilon: 0.65
# Episode 65,Opponent: ForgivingTitForTat, Reward: 225.00, Epsilon: 0.64
# Episode 66,Opponent: Gambler, Reward: 235.00, Epsilon: 0.64
# Episode 67,Opponent: ForgivingTitForTat, Reward: 238.00, Epsilon: 0.64
# Episode 68,Opponent: CyclerCCCCCD, Reward: 384.00, Epsilon: 0.63
# Episode 69,Opponent: CyclerCCCCCD, Reward: 393.00, Epsilon: 0.63
# Episode 70,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.62
# Episode 71,Opponent: FoolMeOnce, Reward: 70.00, Epsilon: 0.62
# Episode 72,Opponent: HardTitForTat, Reward: 80.00, Epsilon: 0.62
# Episode 73,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.61
# Episode 74,Opponent: StochasticWSLS, Reward: 448.00, Epsilon: 0.61
# Episode 75,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.60
# Episode 76,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.60
# Episode 77,Opponent: CyclerCCCCCD, Reward: 358.00, Epsilon: 0.59
# Episode 78,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.59
# Episode 79,Opponent: FoolMeOnce, Reward: 75.00, Epsilon: 0.59
# Episode 80,Opponent: Grudger, Reward: 71.00, Epsilon: 0.58
# Episode 81,Opponent: StochasticWSLS, Reward: 452.00, Epsilon: 0.58
# Episode 82,Opponent: HardTitForTat, Reward: 104.00, Epsilon: 0.58
# Episode 83,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.57
# Episode 84,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.57
# Episode 85,Opponent: HardTitForTat, Reward: 93.00, Epsilon: 0.56
# Episode 86,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.56
# Episode 87,Opponent: TitFor2Tats, Reward: 331.00, Epsilon: 0.56
# Episode 88,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.55
# Episode 89,Opponent: EasyGo, Reward: 448.00, Epsilon: 0.55
# Episode 90,Opponent: WinStayLoseShift, Reward: 267.00, Epsilon: 0.55
# Episode 91,Opponent: Grudger, Reward: 73.00, Epsilon: 0.54
# Episode 92,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.54
# Episode 93,Opponent: SoftJoss, Reward: 456.00, Epsilon: 0.53
# Episode 94,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.53
# Episode 95,Opponent: Grudger, Reward: 68.00, Epsilon: 0.53
# Episode 96,Opponent: SoftJoss, Reward: 444.00, Epsilon: 0.52
# Episode 97,Opponent: Gambler, Reward: 250.00, Epsilon: 0.52
# Episode 98,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.52
# Episode 99,Opponent: EasyGo, Reward: 447.00, Epsilon: 0.51
# Episode 100,Opponent: Grudger, Reward: 70.00, Epsilon: 0.51
# Episode 101,Opponent: Alternator, Reward: 243.00, Epsilon: 0.51
# Episode 102,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.50
# Episode 103,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.50
# Episode 104,Opponent: FoolMeOnce, Reward: 67.00, Epsilon: 0.50
# Episode 105,Opponent: Alternator, Reward: 253.00, Epsilon: 0.49
# Episode 106,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.49
# Episode 107,Opponent: Gambler, Reward: 246.00, Epsilon: 0.49
# Episode 108,Opponent: Gambler, Reward: 244.00, Epsilon: 0.48
# Episode 109,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.48
# Episode 110,Opponent: Grudger, Reward: 61.00, Epsilon: 0.48
# Episode 111,Opponent: ForgivingTitForTat, Reward: 246.00, Epsilon: 0.47
# Episode 112,Opponent: Alternator, Reward: 254.00, Epsilon: 0.47
# Episode 113,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.47
# Episode 114,Opponent: EasyGo, Reward: 444.00, Epsilon: 0.47
# Episode 115,Opponent: Alternator, Reward: 247.00, Epsilon: 0.46
# Episode 116,Opponent: SoftJoss, Reward: 450.00, Epsilon: 0.46
# Episode 117,Opponent: Alternator, Reward: 245.00, Epsilon: 0.46
# Episode 118,Opponent: Gambler, Reward: 245.00, Epsilon: 0.45
# Episode 119,Opponent: FoolMeOnce, Reward: 64.00, Epsilon: 0.45
# Episode 120,Opponent: WinStayLoseShift, Reward: 246.00, Epsilon: 0.45
# Episode 121,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.44
# Episode 122,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.44
# Episode 123,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.44
# Episode 124,Opponent: SoftJoss, Reward: 454.00, Epsilon: 0.44
# Episode 125,Opponent: CyclerCCCCCD, Reward: 378.00, Epsilon: 0.43
# Episode 126,Opponent: Alternator, Reward: 256.00, Epsilon: 0.43
# Episode 127,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.43
# Episode 128,Opponent: CyclerCCCCCD, Reward: 402.00, Epsilon: 0.42
# Episode 129,Opponent: EasyGo, Reward: 442.00, Epsilon: 0.42
# Episode 130,Opponent: Grudger, Reward: 55.00, Epsilon: 0.42
# Episode 131,Opponent: TitFor2Tats, Reward: 333.00, Epsilon: 0.42
# Episode 132,Opponent: FoolMeOnce, Reward: 70.00, Epsilon: 0.41
# Episode 133,Opponent: WinStayLoseShift, Reward: 224.00, Epsilon: 0.41
# Episode 134,Opponent: CyclerCCCCCD, Reward: 364.00, Epsilon: 0.41
# Episode 135,Opponent: Alternator, Reward: 247.00, Epsilon: 0.40
# Episode 136,Opponent: Gambler, Reward: 242.00, Epsilon: 0.40
# Episode 137,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.40
# Episode 138,Opponent: CyclerCCCCCD, Reward: 387.00, Epsilon: 0.40
# Episode 139,Opponent: FoolMeOnce, Reward: 79.00, Epsilon: 0.39
# Episode 140,Opponent: Gambler, Reward: 263.00, Epsilon: 0.39
# Episode 141,Opponent: Alternator, Reward: 238.00, Epsilon: 0.39
# Episode 142,Opponent: Alternator, Reward: 246.00, Epsilon: 0.39
# Episode 143,Opponent: TitFor2Tats, Reward: 342.00, Epsilon: 0.38
# Episode 144,Opponent: Gambler, Reward: 259.00, Epsilon: 0.38
# Episode 145,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.38
# Episode 146,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.38
# Episode 147,Opponent: FoolMeOnce, Reward: 61.00, Epsilon: 0.37
# Episode 148,Opponent: FoolMeOnce, Reward: 52.00, Epsilon: 0.37
# Episode 149,Opponent: EasyGo, Reward: 452.00, Epsilon: 0.37
# Episode 150,Opponent: Gambler, Reward: 252.00, Epsilon: 0.37
# Episode 151,Opponent: CyclerCCCCCD, Reward: 379.00, Epsilon: 0.36
# Episode 152,Opponent: FoolMeOnce, Reward: 84.00, Epsilon: 0.36
# Episode 153,Opponent: Grudger, Reward: 72.00, Epsilon: 0.36
# Episode 154,Opponent: EasyGo, Reward: 468.00, Epsilon: 0.36
# Episode 155,Opponent: StochasticWSLS, Reward: 462.00, Epsilon: 0.35
# Episode 156,Opponent: FoolMeOnce, Reward: 82.00, Epsilon: 0.35
# Episode 157,Opponent: TitFor2Tats, Reward: 319.00, Epsilon: 0.35
# Episode 158,Opponent: HardTitForTat, Reward: 84.00, Epsilon: 0.35
# Episode 159,Opponent: WinStayLoseShift, Reward: 269.00, Epsilon: 0.34
# Episode 160,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.34
# Episode 161,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.34
# Episode 162,Opponent: Alternator, Reward: 253.00, Epsilon: 0.34
# Episode 163,Opponent: HardTitForTat, Reward: 127.00, Epsilon: 0.34
# Episode 164,Opponent: Alternator, Reward: 260.00, Epsilon: 0.33
# Episode 165,Opponent: Grudger, Reward: 73.00, Epsilon: 0.33
# Episode 166,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.33
# Episode 167,Opponent: Grudger, Reward: 70.00, Epsilon: 0.33
# Episode 168,Opponent: ForgivingTitForTat, Reward: 257.00, Epsilon: 0.32
# Episode 169,Opponent: SoftJoss, Reward: 452.00, Epsilon: 0.32
# Episode 170,Opponent: Gambler, Reward: 268.00, Epsilon: 0.32
# Episode 171,Opponent: ForgivingTitForTat, Reward: 269.00, Epsilon: 0.32
# Episode 172,Opponent: FoolMeOnce, Reward: 92.00, Epsilon: 0.32
# Episode 173,Opponent: WinStayLoseShift, Reward: 272.00, Epsilon: 0.31
# Episode 174,Opponent: FoolMeOnce, Reward: 83.00, Epsilon: 0.31
# Episode 175,Opponent: TitFor2Tats, Reward: 358.00, Epsilon: 0.31
# Episode 176,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.31
# Episode 177,Opponent: CyclerCCCCCD, Reward: 370.00, Epsilon: 0.31
# Episode 178,Opponent: Gambler, Reward: 259.00, Epsilon: 0.30
# Episode 179,Opponent: WinStayLoseShift, Reward: 267.00, Epsilon: 0.30
# Episode 180,Opponent: Grudger, Reward: 81.00, Epsilon: 0.30
# Episode 181,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.30
# Episode 182,Opponent: WinStayLoseShift, Reward: 281.00, Epsilon: 0.30
# Episode 183,Opponent: Grudger, Reward: 92.00, Epsilon: 0.29
# Episode 184,Opponent: Alternator, Reward: 274.00, Epsilon: 0.29
# Episode 185,Opponent: SoftJoss, Reward: 474.00, Epsilon: 0.29
# Episode 186,Opponent: HardTitForTat, Reward: 84.00, Epsilon: 0.29
# Episode 187,Opponent: StochasticWSLS, Reward: 478.00, Epsilon: 0.29
# Episode 188,Opponent: Grudger, Reward: 89.00, Epsilon: 0.28
# Episode 189,Opponent: FoolMeOnce, Reward: 93.00, Epsilon: 0.28
# Episode 190,Opponent: HardTitForTat, Reward: 89.00, Epsilon: 0.28
# Episode 191,Opponent: EasyGo, Reward: 456.00, Epsilon: 0.28
# Episode 192,Opponent: EasyGo, Reward: 451.00, Epsilon: 0.28
# Episode 193,Opponent: Gambler, Reward: 261.00, Epsilon: 0.27
# Episode 194,Opponent: WinStayLoseShift, Reward: 246.00, Epsilon: 0.27
# Episode 195,Opponent: HardTitForTat, Reward: 96.00, Epsilon: 0.27
# Episode 196,Opponent: ForgivingTitForTat, Reward: 259.00, Epsilon: 0.27
# Episode 197,Opponent: HardTitForTat, Reward: 100.00, Epsilon: 0.27
# Episode 198,Opponent: ForgivingTitForTat, Reward: 266.00, Epsilon: 0.27
# Episode 199,Opponent: Grudger, Reward: 79.00, Epsilon: 0.26
# Episode 200,Opponent: WinStayLoseShift, Reward: 272.00, Epsilon: 0.26
# Episode 201,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.26
# Episode 202,Opponent: Gambler, Reward: 268.00, Epsilon: 0.26
# Episode 203,Opponent: Gambler, Reward: 258.00, Epsilon: 0.26
# Episode 204,Opponent: CyclerCCCCCD, Reward: 350.00, Epsilon: 0.26
# Episode 205,Opponent: Grudger, Reward: 83.00, Epsilon: 0.25
# Episode 206,Opponent: Gambler, Reward: 268.00, Epsilon: 0.25
# Episode 207,Opponent: Alternator, Reward: 245.00, Epsilon: 0.25
# Episode 208,Opponent: TitFor2Tats, Reward: 338.00, Epsilon: 0.25
# Episode 209,Opponent: StochasticWSLS, Reward: 420.00, Epsilon: 0.25
# Episode 210,Opponent: CyclerCCCCCD, Reward: 334.00, Epsilon: 0.25
# Episode 211,Opponent: CyclerCCCCCD, Reward: 381.00, Epsilon: 0.24
# Episode 212,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.24
# Episode 213,Opponent: Grudger, Reward: 93.00, Epsilon: 0.24
# Episode 214,Opponent: Grudger, Reward: 77.00, Epsilon: 0.24
# Episode 215,Opponent: WinStayLoseShift, Reward: 278.00, Epsilon: 0.24
# Episode 216,Opponent: ForgivingTitForTat, Reward: 259.00, Epsilon: 0.24
# Episode 217,Opponent: FoolMeOnce, Reward: 96.00, Epsilon: 0.23
# Episode 218,Opponent: CyclerCCCCCD, Reward: 372.00, Epsilon: 0.23
# Episode 219,Opponent: Gambler, Reward: 260.00, Epsilon: 0.23
# Episode 220,Opponent: Gambler, Reward: 261.00, Epsilon: 0.23
# Episode 221,Opponent: HardTitForTat, Reward: 105.00, Epsilon: 0.23
# Episode 222,Opponent: Alternator, Reward: 240.00, Epsilon: 0.23
# Episode 223,Opponent: Alternator, Reward: 232.00, Epsilon: 0.23
# Episode 224,Opponent: CyclerCCCCCD, Reward: 371.00, Epsilon: 0.22
# Episode 225,Opponent: StochasticWSLS, Reward: 400.00, Epsilon: 0.22
# Episode 226,Opponent: Gambler, Reward: 263.00, Epsilon: 0.22
# Episode 227,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.22
# Episode 228,Opponent: WinStayLoseShift, Reward: 269.00, Epsilon: 0.22
# Episode 229,Opponent: TitFor2Tats, Reward: 346.00, Epsilon: 0.22
# Episode 230,Opponent: FoolMeOnce, Reward: 77.00, Epsilon: 0.21
# Episode 231,Opponent: Grudger, Reward: 75.00, Epsilon: 0.21
# Episode 232,Opponent: CyclerCCCCCD, Reward: 407.00, Epsilon: 0.21
# Episode 233,Opponent: Gambler, Reward: 241.00, Epsilon: 0.21
# Episode 234,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.21
# Episode 235,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.21
# Episode 236,Opponent: EasyGo, Reward: 440.00, Epsilon: 0.21
# Episode 237,Opponent: WinStayLoseShift, Reward: 285.00, Epsilon: 0.21
# Episode 238,Opponent: WinStayLoseShift, Reward: 269.00, Epsilon: 0.20
# Episode 239,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.20
# Episode 240,Opponent: WinStayLoseShift, Reward: 288.00, Epsilon: 0.20
# Episode 241,Opponent: ForgivingTitForTat, Reward: 266.00, Epsilon: 0.20
# Episode 242,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.20
# Episode 243,Opponent: WinStayLoseShift, Reward: 272.00, Epsilon: 0.20
# Episode 244,Opponent: CyclerCCCCCD, Reward: 371.00, Epsilon: 0.20
# Episode 245,Opponent: ForgivingTitForTat, Reward: 260.00, Epsilon: 0.19
# Episode 246,Opponent: TitFor2Tats, Reward: 336.00, Epsilon: 0.19
# Episode 247,Opponent: WinStayLoseShift, Reward: 267.00, Epsilon: 0.19
# Episode 248,Opponent: CyclerCCCCCD, Reward: 397.00, Epsilon: 0.19
# Episode 249,Opponent: Gambler, Reward: 262.00, Epsilon: 0.19
# Episode 250,Opponent: CyclerCCCCCD, Reward: 362.00, Epsilon: 0.19
# Episode 251,Opponent: TitFor2Tats, Reward: 333.00, Epsilon: 0.19
# Episode 252,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.19
# Episode 253,Opponent: CyclerCCCCCD, Reward: 344.00, Epsilon: 0.18
# Episode 254,Opponent: Alternator, Reward: 236.00, Epsilon: 0.18
# Episode 255,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.18
# Episode 256,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.18
# Episode 257,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.18
# Episode 258,Opponent: CyclerCCCCCD, Reward: 356.00, Epsilon: 0.18
# Episode 259,Opponent: Grudger, Reward: 97.00, Epsilon: 0.18
# Episode 260,Opponent: ForgivingTitForTat, Reward: 275.00, Epsilon: 0.18
# Episode 261,Opponent: CyclerCCCCCD, Reward: 376.00, Epsilon: 0.17
# Episode 262,Opponent: Grudger, Reward: 66.00, Epsilon: 0.17
# Episode 263,Opponent: SoftJoss, Reward: 450.00, Epsilon: 0.17
# Episode 264,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.17
# Episode 265,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.17
# Episode 266,Opponent: ForgivingTitForTat, Reward: 262.00, Epsilon: 0.17
# Episode 267,Opponent: WinStayLoseShift, Reward: 267.00, Epsilon: 0.17
# Episode 268,Opponent: CyclerCCCCCD, Reward: 384.00, Epsilon: 0.17
# Episode 269,Opponent: ForgivingTitForTat, Reward: 263.00, Epsilon: 0.17
# Episode 270,Opponent: HardTitForTat, Reward: 148.00, Epsilon: 0.16
# Episode 271,Opponent: TitFor2Tats, Reward: 349.00, Epsilon: 0.16
# Episode 272,Opponent: WinStayLoseShift, Reward: 251.00, Epsilon: 0.16
# Episode 273,Opponent: FoolMeOnce, Reward: 144.00, Epsilon: 0.16
# Episode 274,Opponent: WinStayLoseShift, Reward: 234.00, Epsilon: 0.16
# Episode 275,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.16
# Episode 276,Opponent: Grudger, Reward: 26.00, Epsilon: 0.16
# Episode 277,Opponent: Alternator, Reward: 219.00, Epsilon: 0.16
# Episode 278,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.16
# Episode 279,Opponent: ForgivingTitForTat, Reward: 301.00, Epsilon: 0.16
# Episode 280,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.15
# Episode 281,Opponent: EasyGo, Reward: 477.00, Epsilon: 0.15
# Episode 282,Opponent: StochasticWSLS, Reward: 404.00, Epsilon: 0.15
# Episode 283,Opponent: EasyGo, Reward: 480.00, Epsilon: 0.15
# Episode 284,Opponent: Alternator, Reward: 265.00, Epsilon: 0.15
# Episode 285,Opponent: StochasticWSLS, Reward: 476.00, Epsilon: 0.15
# Episode 286,Opponent: FoolMeOnce, Reward: 52.00, Epsilon: 0.15
# Episode 287,Opponent: Gambler, Reward: 278.00, Epsilon: 0.15
# Episode 288,Opponent: CyclerCCCCCD, Reward: 411.00, Epsilon: 0.15
# Episode 289,Opponent: CyclerCCCCCD, Reward: 411.00, Epsilon: 0.15
# Episode 290,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.14
# Episode 291,Opponent: Alternator, Reward: 260.00, Epsilon: 0.14
# Episode 292,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.14
# Episode 293,Opponent: Alternator, Reward: 265.00, Epsilon: 0.14
# Episode 294,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.14
# Episode 295,Opponent: StochasticWSLS, Reward: 444.00, Epsilon: 0.14
# Episode 296,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.14
# Episode 297,Opponent: Alternator, Reward: 267.00, Epsilon: 0.14
# Episode 298,Opponent: WinStayLoseShift, Reward: 278.00, Epsilon: 0.14
# Episode 299,Opponent: Alternator, Reward: 282.00, Epsilon: 0.14
# Episode 300,Opponent: WinStayLoseShift, Reward: 281.00, Epsilon: 0.13
# Episode 301,Opponent: CyclerCCCCCD, Reward: 404.00, Epsilon: 0.13
# Episode 302,Opponent: CyclerCCCCCD, Reward: 367.00, Epsilon: 0.13
# Episode 303,Opponent: CyclerCCCCCD, Reward: 403.00, Epsilon: 0.13
# Episode 304,Opponent: ForgivingTitForTat, Reward: 290.00, Epsilon: 0.13
# Episode 305,Opponent: Gambler, Reward: 270.00, Epsilon: 0.13
# Episode 306,Opponent: FoolMeOnce, Reward: 97.00, Epsilon: 0.13
# Episode 307,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.13
# Episode 308,Opponent: FoolMeOnce, Reward: 79.00, Epsilon: 0.13
# Episode 309,Opponent: Gambler, Reward: 266.00, Epsilon: 0.13
# Episode 310,Opponent: TitFor2Tats, Reward: 350.00, Epsilon: 0.13
# Episode 311,Opponent: FoolMeOnce, Reward: 95.00, Epsilon: 0.13
# Episode 312,Opponent: ForgivingTitForTat, Reward: 285.00, Epsilon: 0.12
# Episode 313,Opponent: WinStayLoseShift, Reward: 263.00, Epsilon: 0.12
# Episode 314,Opponent: ForgivingTitForTat, Reward: 260.00, Epsilon: 0.12
# Episode 315,Opponent: Grudger, Reward: 64.00, Epsilon: 0.12
# Episode 316,Opponent: EasyGo, Reward: 463.00, Epsilon: 0.12
# Episode 317,Opponent: HardTitForTat, Reward: 216.00, Epsilon: 0.12
# Episode 318,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.12
# Episode 319,Opponent: TitFor2Tats, Reward: 355.00, Epsilon: 0.12
# Episode 320,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.12
# Episode 321,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.12
# Episode 322,Opponent: StochasticWSLS, Reward: 474.00, Epsilon: 0.12
# Episode 323,Opponent: Gambler, Reward: 233.00, Epsilon: 0.12
# Episode 324,Opponent: Grudger, Reward: 47.00, Epsilon: 0.11
# Episode 325,Opponent: Gambler, Reward: 237.00, Epsilon: 0.11
# Episode 326,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.11
# Episode 327,Opponent: HardTitForTat, Reward: 158.00, Epsilon: 0.11
# Episode 328,Opponent: Alternator, Reward: 260.00, Epsilon: 0.11
# Episode 329,Opponent: FoolMeOnce, Reward: 59.00, Epsilon: 0.11
# Episode 330,Opponent: ForgivingTitForTat, Reward: 250.00, Epsilon: 0.11
# Episode 331,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.11
# Episode 332,Opponent: SoftJoss, Reward: 484.00, Epsilon: 0.11
# Episode 333,Opponent: Gambler, Reward: 264.00, Epsilon: 0.11
# Episode 334,Opponent: FoolMeOnce, Reward: 155.00, Epsilon: 0.11
# Episode 335,Opponent: Alternator, Reward: 266.00, Epsilon: 0.11
# Episode 336,Opponent: ForgivingTitForTat, Reward: 287.00, Epsilon: 0.11
# Episode 337,Opponent: WinStayLoseShift, Reward: 284.00, Epsilon: 0.11
# Episode 338,Opponent: HardTitForTat, Reward: 209.00, Epsilon: 0.10
# Episode 339,Opponent: EasyGo, Reward: 471.00, Epsilon: 0.10
# Episode 340,Opponent: CyclerCCCCCD, Reward: 393.00, Epsilon: 0.10
# Episode 341,Opponent: EasyGo, Reward: 477.00, Epsilon: 0.10
# Episode 342,Opponent: ForgivingTitForTat, Reward: 279.00, Epsilon: 0.10
# Episode 343,Opponent: HardTitForTat, Reward: 233.00, Epsilon: 0.10
# Episode 344,Opponent: Grudger, Reward: 76.00, Epsilon: 0.10
# Episode 345,Opponent: Alternator, Reward: 257.00, Epsilon: 0.10
# Episode 346,Opponent: FoolMeOnce, Reward: 126.00, Epsilon: 0.10
# Episode 347,Opponent: FoolMeOnce, Reward: 99.00, Epsilon: 0.10
# Episode 348,Opponent: FoolMeOnce, Reward: 110.00, Epsilon: 0.10
# Episode 349,Opponent: HardTitForTat, Reward: 260.00, Epsilon: 0.10
# Episode 350,Opponent: Gambler, Reward: 294.00, Epsilon: 0.10
# Episode 351,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.10
# Episode 352,Opponent: Grudger, Reward: 97.00, Epsilon: 0.10
# Episode 353,Opponent: HardTitForTat, Reward: 186.00, Epsilon: 0.09
# Episode 354,Opponent: Alternator, Reward: 159.00, Epsilon: 0.09
# Episode 355,Opponent: EasyGo, Reward: 467.00, Epsilon: 0.09
# Episode 356,Opponent: ForgivingTitForTat, Reward: 289.00, Epsilon: 0.09
# Episode 357,Opponent: WinStayLoseShift, Reward: 299.00, Epsilon: 0.09
# Episode 358,Opponent: StochasticWSLS, Reward: 480.00, Epsilon: 0.09
# Episode 359,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.09
# Episode 360,Opponent: HardTitForTat, Reward: 261.00, Epsilon: 0.09
# Episode 361,Opponent: HardTitForTat, Reward: 202.00, Epsilon: 0.09
# Episode 362,Opponent: HardTitForTat, Reward: 207.00, Epsilon: 0.09
# Episode 363,Opponent: TitFor2Tats, Reward: 326.00, Epsilon: 0.09
# Episode 364,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.09
# Episode 365,Opponent: Gambler, Reward: 272.00, Epsilon: 0.09
# Episode 366,Opponent: StochasticWSLS, Reward: 380.00, Epsilon: 0.09
# Episode 367,Opponent: Alternator, Reward: 284.00, Epsilon: 0.09
# Episode 368,Opponent: SoftJoss, Reward: 452.00, Epsilon: 0.09
# Episode 369,Opponent: Grudger, Reward: 90.00, Epsilon: 0.09
# Episode 370,Opponent: FoolMeOnce, Reward: 108.00, Epsilon: 0.08
# Episode 371,Opponent: TitFor2Tats, Reward: 327.00, Epsilon: 0.08
# Episode 372,Opponent: Alternator, Reward: 271.00, Epsilon: 0.08
# Episode 373,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.08
# Episode 374,Opponent: TitFor2Tats, Reward: 339.00, Epsilon: 0.08
# Episode 375,Opponent: SoftJoss, Reward: 392.00, Epsilon: 0.08
# Episode 376,Opponent: TitFor2Tats, Reward: 310.00, Epsilon: 0.08
# Episode 377,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.08
# Episode 378,Opponent: Grudger, Reward: 73.00, Epsilon: 0.08
# Episode 379,Opponent: Gambler, Reward: 282.00, Epsilon: 0.08
# Episode 380,Opponent: ForgivingTitForTat, Reward: 284.00, Epsilon: 0.08
# Episode 381,Opponent: Gambler, Reward: 268.00, Epsilon: 0.08
# Episode 382,Opponent: SoftJoss, Reward: 414.00, Epsilon: 0.08
# Episode 383,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.08
# Episode 384,Opponent: EasyGo, Reward: 489.00, Epsilon: 0.08
# Episode 385,Opponent: ForgivingTitForTat, Reward: 265.00, Epsilon: 0.08
# Episode 386,Opponent: HardTitForTat, Reward: 283.00, Epsilon: 0.08
# Episode 387,Opponent: CyclerCCCCCD, Reward: 392.00, Epsilon: 0.08
# Episode 388,Opponent: Alternator, Reward: 273.00, Epsilon: 0.08
# Episode 389,Opponent: EasyGo, Reward: 481.00, Epsilon: 0.07
# Episode 390,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.07
# Episode 391,Opponent: SoftJoss, Reward: 444.00, Epsilon: 0.07
# Episode 392,Opponent: HardTitForTat, Reward: 267.00, Epsilon: 0.07
# Episode 393,Opponent: Gambler, Reward: 278.00, Epsilon: 0.07
# Episode 394,Opponent: FoolMeOnce, Reward: 71.00, Epsilon: 0.07
# Episode 395,Opponent: SoftJoss, Reward: 378.00, Epsilon: 0.07
# Episode 396,Opponent: EasyGo, Reward: 477.00, Epsilon: 0.07
# Episode 397,Opponent: ForgivingTitForTat, Reward: 308.00, Epsilon: 0.07
# Episode 398,Opponent: Gambler, Reward: 284.00, Epsilon: 0.07
# Episode 399,Opponent: Alternator, Reward: 263.00, Epsilon: 0.07
# Episode 400,Opponent: EasyGo, Reward: 473.00, Epsilon: 0.07
# Episode 401,Opponent: CyclerCCCCCD, Reward: 400.00, Epsilon: 0.07
# Episode 402,Opponent: FoolMeOnce, Reward: 82.00, Epsilon: 0.07
# Episode 403,Opponent: Alternator, Reward: 283.00, Epsilon: 0.07
# Episode 404,Opponent: CyclerCCCCCD, Reward: 393.00, Epsilon: 0.07
# Episode 405,Opponent: FoolMeOnce, Reward: 56.00, Epsilon: 0.07
# Episode 406,Opponent: CyclerCCCCCD, Reward: 402.00, Epsilon: 0.07
# Episode 407,Opponent: Grudger, Reward: 61.00, Epsilon: 0.07
# Episode 408,Opponent: Grudger, Reward: 45.00, Epsilon: 0.07
# Episode 409,Opponent: SoftJoss, Reward: 486.00, Epsilon: 0.07
# Episode 410,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.06
# Episode 411,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.06
# Episode 412,Opponent: StochasticWSLS, Reward: 496.00, Epsilon: 0.06
# Episode 413,Opponent: WinStayLoseShift, Reward: 279.00, Epsilon: 0.06
# Episode 414,Opponent: StochasticWSLS, Reward: 494.00, Epsilon: 0.06
# Episode 415,Opponent: ForgivingTitForTat, Reward: 257.00, Epsilon: 0.06
# Episode 416,Opponent: WinStayLoseShift, Reward: 284.00, Epsilon: 0.06
# Episode 417,Opponent: SoftJoss, Reward: 492.00, Epsilon: 0.06
# Episode 418,Opponent: SoftJoss, Reward: 488.00, Epsilon: 0.06
# Episode 419,Opponent: Gambler, Reward: 252.00, Epsilon: 0.06
# Episode 420,Opponent: TitFor2Tats, Reward: 339.00, Epsilon: 0.06
# Episode 421,Opponent: ForgivingTitForTat, Reward: 265.00, Epsilon: 0.06
# Episode 422,Opponent: CyclerCCCCCD, Reward: 386.00, Epsilon: 0.06
# Episode 423,Opponent: StochasticWSLS, Reward: 482.00, Epsilon: 0.06
# Episode 424,Opponent: HardTitForTat, Reward: 226.00, Epsilon: 0.06
# Episode 425,Opponent: Gambler, Reward: 283.00, Epsilon: 0.06
# Episode 426,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.06
# Episode 427,Opponent: HardTitForTat, Reward: 267.00, Epsilon: 0.06
# Episode 428,Opponent: Alternator, Reward: 281.00, Epsilon: 0.06
# Episode 429,Opponent: TitFor2Tats, Reward: 356.00, Epsilon: 0.06
# Episode 430,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.06
# Episode 431,Opponent: TitFor2Tats, Reward: 366.00, Epsilon: 0.06
# Episode 432,Opponent: CyclerCCCCCD, Reward: 384.00, Epsilon: 0.06
# Episode 433,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.06
# Episode 434,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.06
# Episode 435,Opponent: Gambler, Reward: 288.00, Epsilon: 0.05
# Episode 436,Opponent: EasyGo, Reward: 463.00, Epsilon: 0.05
# Episode 437,Opponent: SoftJoss, Reward: 412.00, Epsilon: 0.05
# Episode 438,Opponent: ForgivingTitForTat, Reward: 300.00, Epsilon: 0.05
# Episode 439,Opponent: StochasticWSLS, Reward: 308.00, Epsilon: 0.05
# Episode 440,Opponent: TitFor2Tats, Reward: 364.00, Epsilon: 0.05
# Episode 441,Opponent: Gambler, Reward: 272.00, Epsilon: 0.05
# Episode 442,Opponent: CyclerCCCCCD, Reward: 397.00, Epsilon: 0.05
# Episode 443,Opponent: StochasticWSLS, Reward: 478.00, Epsilon: 0.05
# Episode 444,Opponent: FoolMeOnce, Reward: 71.00, Epsilon: 0.05
# Episode 445,Opponent: Alternator, Reward: 281.00, Epsilon: 0.05
# Episode 446,Opponent: SoftJoss, Reward: 482.00, Epsilon: 0.05
# Episode 447,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.05
# Episode 448,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.05
# Episode 449,Opponent: SoftJoss, Reward: 472.00, Epsilon: 0.05
# Episode 450,Opponent: WinStayLoseShift, Reward: 285.00, Epsilon: 0.05
# Episode 451,Opponent: Gambler, Reward: 270.00, Epsilon: 0.05
# Episode 452,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.05
# Episode 453,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.05
# Episode 454,Opponent: ForgivingTitForTat, Reward: 275.00, Epsilon: 0.05
# Episode 455,Opponent: TitFor2Tats, Reward: 321.00, Epsilon: 0.05
# Episode 456,Opponent: CyclerCCCCCD, Reward: 380.00, Epsilon: 0.05
# Episode 457,Opponent: HardTitForTat, Reward: 256.00, Epsilon: 0.05
# Episode 458,Opponent: TitFor2Tats, Reward: 345.00, Epsilon: 0.05
# Episode 459,Opponent: EasyGo, Reward: 449.00, Epsilon: 0.05
# Episode 460,Opponent: Gambler, Reward: 293.00, Epsilon: 0.05
# Episode 461,Opponent: FoolMeOnce, Reward: 89.00, Epsilon: 0.05
# Episode 462,Opponent: ForgivingTitForTat, Reward: 260.00, Epsilon: 0.05
# Episode 463,Opponent: FoolMeOnce, Reward: 126.00, Epsilon: 0.05
# Episode 464,Opponent: CyclerCCCCCD, Reward: 394.00, Epsilon: 0.05
# Episode 465,Opponent: TitFor2Tats, Reward: 324.00, Epsilon: 0.05
# Episode 466,Opponent: Alternator, Reward: 290.00, Epsilon: 0.05
# Episode 467,Opponent: TitFor2Tats, Reward: 361.00, Epsilon: 0.05
# Episode 468,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.05
# Episode 469,Opponent: SoftJoss, Reward: 486.00, Epsilon: 0.05
# Episode 470,Opponent: Gambler, Reward: 261.00, Epsilon: 0.05
# Episode 471,Opponent: TitFor2Tats, Reward: 347.00, Epsilon: 0.05
# Episode 472,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.05
# Episode 473,Opponent: FoolMeOnce, Reward: 93.00, Epsilon: 0.05
# Episode 474,Opponent: CyclerCCCCCD, Reward: 400.00, Epsilon: 0.05
# Episode 475,Opponent: Gambler, Reward: 270.00, Epsilon: 0.05
# Episode 476,Opponent: TitFor2Tats, Reward: 361.00, Epsilon: 0.05
# Episode 477,Opponent: Grudger, Reward: 80.00, Epsilon: 0.05
# Episode 478,Opponent: CyclerCCCCCD, Reward: 382.00, Epsilon: 0.05
# Episode 479,Opponent: Grudger, Reward: 65.00, Epsilon: 0.05
# Episode 480,Opponent: ForgivingTitForTat, Reward: 269.00, Epsilon: 0.05
# Episode 481,Opponent: Grudger, Reward: 7.00, Epsilon: 0.05
# Episode 482,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.05
# Episode 483,Opponent: FoolMeOnce, Reward: 133.00, Epsilon: 0.05
# Episode 484,Opponent: EasyGo, Reward: 461.00, Epsilon: 0.05
# Episode 485,Opponent: WinStayLoseShift, Reward: 228.00, Epsilon: 0.05
# Episode 486,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.05
# Episode 487,Opponent: Grudger, Reward: 28.00, Epsilon: 0.05
# Episode 488,Opponent: Gambler, Reward: 289.00, Epsilon: 0.05
# Episode 489,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.05
# Episode 490,Opponent: Grudger, Reward: 23.00, Epsilon: 0.05
# Episode 491,Opponent: Grudger, Reward: 147.00, Epsilon: 0.05
# Episode 492,Opponent: SoftJoss, Reward: 486.00, Epsilon: 0.05
# Episode 493,Opponent: Alternator, Reward: 265.00, Epsilon: 0.05
# Episode 494,Opponent: EasyGo, Reward: 474.00, Epsilon: 0.05
# Episode 495,Opponent: Alternator, Reward: 232.00, Epsilon: 0.05
# Episode 496,Opponent: HardTitForTat, Reward: 219.00, Epsilon: 0.05
# Episode 497,Opponent: ForgivingTitForTat, Reward: 295.00, Epsilon: 0.05
# Episode 498,Opponent: CyclerCCCCCD, Reward: 378.00, Epsilon: 0.05
# Episode 499,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.05
# <Axes: >

# %%
# === RL Wrapper for Axelrod Tournament ===
import axelrod as axl
import torch
from axelrod.action import Action
import numpy as np
from collections import defaultdict
from statistics import mean

C, D = Action.C, Action.D

class RLWrapper(axl.Player):
    name = "RL Agent"

    def __init__(self, policy_net, history_len=10):
        super().__init__()
        self.policy_net = policy_net
        self.history_len = history_len

    def strategy(self, opponent):
        padded_self = [0] * (self.history_len - len(self.history)) + [
            0 if action == C else 1 for action in self.history[-self.history_len:]
        ]
        padded_opp = [0] * (self.history_len - len(opponent.history)) + [
            0 if action == C else 1 for action in opponent.history[-self.history_len:]
        ]
        state = torch.tensor(padded_self + padded_opp, dtype=torch.float32)
        with torch.no_grad():
            action_index = self.policy_net(state.unsqueeze(0)).argmax().item()
        return C if action_index == 0 else D

    def __repr__(self):
        return self.name


policy_net1 = DQN(input_dim=20, hidden1=128,hidden2=64, output_dim=2)
policy_net1.load_state_dict(torch.load("dqn_policy.pth"))
policy_net1.eval()

policy_net2 = DQN(input_dim=20, hidden1=128,hidden2=64, output_dim=2)
policy_net2.load_state_dict(torch.load("dqn_policy.pth"))
policy_net2.eval()

strategies = [
    axl.Defector(),
    axl.Cooperator(),
    axl.TitForTat(),
    axl.SuspiciousTitForTat(),
    RLWrapper(policy_net1),
    axl.FirstByJoss(),
    axl.StochasticCooperator(),
    axl.Calculator(),
    axl.BackStabber(),
    axl.MathConstantHunter(),
    axl.SneakyTitForTat(),
    axl.Handshake(),
    axl.CyclerCCD(),
    # Uncomment for expaned version of the tournament
    # RLWrapper(policy_net2),
    # axl.Alternator(),
    # axl.Inverse(),
    # axl.InversePunisher(),
    # axl.MetaWinnerStochastic(),
    # axl.DoubleCrosser(),
    # axl.DelayedAON1()
 ]


tournament = axl.Tournament(strategies, turns=100)
results = tournament.play()
scores_matrix = results.scores
average_scores = average_scores = [np.mean(score_row) for score_row in scores_matrix]

# Print strategies sorted by average score
print("\nΚατάταξη στρατηγικών βάσει μέσου σκορ:")
sorted_by_score = sorted(zip(results.players, average_scores), key=lambda x: -x[1])
for i, (player, score) in enumerate(sorted_by_score):
    print(f"{i+1}. {player}: {score:.2f}")
# Out:
# Playing matches: 100%|██████████| 91/91 [00:01<00:00, 50.74it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 115.12it/s]
# Κατάταξη στρατηγικών βάσει μέσου σκορ:
# 1. Defector: 3018.80
# 2. BackStabber: (D, D): 2893.80
# 3. Handshake: 2832.40
# 4. Calculator: 2818.50
# 5. Tit For Tat: 2772.30
# 6. RL Agent: 2754.20
# 7. Sneaky Tit For Tat: 2664.80
# 8. Math Constant Hunter: 2661.20
# 9. Suspicious Tit For Tat: 2616.50
# 10. Stochastic Cooperator: 2597.50
# 11. First by Joss: 0.9: 2533.10
# 12. Cooperator: 2268.00
# 13. Cycler CCD: 2083.30

# %%
# Show the agent moves to be precise (log each round)
policy_net.load_state_dict(torch.load("dqn_policy.pth"))
policy_net.eval()

env = IPDEnv(axl.Grudger())  # Choose opponent
state = env.reset()
done = False
round_num = 1
total_test_reward = 0

print("Round | Agent | Opponent")

while not done:
    with torch.no_grad():
        action = policy_net(state.unsqueeze(0)).argmax().item()

    next_state, reward, done = env.step(action)

    # Decode moves
    agent_move = 'C' if env.agent_history[-1] == 0 else 'D'
    opponent_move = 'C' if env.opp_history[-1] == 0 else 'D'

    print(f"{round_num:>5} |   {agent_move}   |    {opponent_move}")

    state = next_state
    round_num += 1
    total_test_reward += reward

print("Total reward:" , total_test_reward)
# Out:
# Round | Agent | Opponent
#     1 |   C   |    C
#     2 |   C   |    C
#     3 |   C   |    C
#     4 |   C   |    C
#     5 |   C   |    C
#     6 |   C   |    C
#     7 |   C   |    C
#     8 |   C   |    C
#     9 |   C   |    C
#    10 |   C   |    C
#    11 |   C   |    C
#    12 |   C   |    C
#    13 |   C   |    C
#    14 |   C   |    C
#    15 |   C   |    C
#    16 |   C   |    C
#    17 |   C   |    C
#    18 |   C   |    C
#    19 |   C   |    C
#    20 |   C   |    C
#    21 |   C   |    C
#    22 |   C   |    C
#    23 |   C   |    C
#    24 |   C   |    C
#    25 |   C   |    C
#    26 |   C   |    C
#    27 |   C   |    C
#    28 |   C   |    C
#    29 |   C   |    C
#    30 |   C   |    C
#    31 |   C   |    C
#    32 |   C   |    C
#    33 |   C   |    C
#    34 |   C   |    C
#    35 |   C   |    C
#    36 |   C   |    C
#    37 |   C   |    C
#    38 |   C   |    C
#    39 |   C   |    C
#    40 |   C   |    C
#    41 |   C   |    C
#    42 |   C   |    C
#    43 |   C   |    C
#    44 |   C   |    C
#    45 |   C   |    C
#    46 |   C   |    C
#    47 |   C   |    C
#    48 |   C   |    C
#    49 |   C   |    C
#    50 |   C   |    C
#    51 |   C   |    C
#    52 |   C   |    C
#    53 |   C   |    C
#    54 |   C   |    C
#    55 |   C   |    C
#    56 |   C   |    C
#    57 |   C   |    C
#    58 |   C   |    C
#    59 |   C   |    C
#    60 |   C   |    C
#    61 |   C   |    C
#    62 |   C   |    C
#    63 |   C   |    C
#    64 |   C   |    C
#    65 |   C   |    C
#    66 |   C   |    C
#    67 |   C   |    C
#    68 |   C   |    C
#    69 |   C   |    C
#    70 |   C   |    C
#    71 |   C   |    C
#    72 |   C   |    C
#    73 |   C   |    C
#    74 |   C   |    C
#    75 |   C   |    C
#    76 |   C   |    C
#    77 |   C   |    C
#    78 |   C   |    C
#    79 |   C   |    C
#    80 |   C   |    C
#    81 |   C   |    C
#    82 |   C   |    C
#    83 |   C   |    C
#    84 |   C   |    C
#    85 |   C   |    C
#    86 |   C   |    C
#    87 |   C   |    C
#    88 |   C   |    C
#    89 |   C   |    C
#    90 |   C   |    C
#    91 |   C   |    C
#    92 |   C   |    C
#    93 |   C   |    C
#    94 |   C   |    C
#    95 |   C   |    C
#    96 |   C   |    C
#    97 |   C   |    C
#    98 |   C   |    C
#    99 |   C   |    C
#   100 |   C   |    C
# Total reward: 300
