# %%
# !pip install axelrod
# Out:
# Collecting axelrod
#   Downloading axelrod-4.13.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.1.1)
# Requirement already satisfied: dask>=2.9.2 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (2024.12.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2025.3.2)
# Requirement already satisfied: matplotlib>=3.0.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.0.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (2.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from axelrod) (6.0.2)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from axelrod) (1.15.3)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.11/dist-packages (from axelrod) (0.12.1)
# Requirement already satisfied: tqdm>=4.39.0 in /usr/local/lib/python3.11/dist-packages (from axelrod) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.4.2)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (8.7.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.9.2->axelrod) (1.1.21)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.3->axelrod) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->axelrod) (2025.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.9.2->axelrod) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (3.21.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.9.2->dask[dataframe]>=2.9.2->axelrod) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->axelrod) (1.17.0)
# Downloading axelrod-4.13.1-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: axelrod
# Successfully installed axelrod-4.13.1

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from collections import deque
import axelrod as axl
from axelrod.action import Action
C, D = Action.C, Action.D

# %%
# Reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
# IPD Environment
class IPDEnv:
    def __init__(self, opponent, history_len=5, max_turns=100):
        self.opponent = opponent
        self.history_len = history_len
        self.max_turns = max_turns
        self.reset()

    def reset(self):
        self.agent = axl.Player()
        self.opponent.reset()
        self.agent_history = []
        self.opp_history = []
        self.turn = 0
        return self._get_state()

    def _get_state(self):
        padded_agent = [0] * (self.history_len - len(self.agent_history)) + self.agent_history[-self.history_len:]
        padded_opp = [0] * (self.history_len - len(self.opp_history)) + self.opp_history[-self.history_len:]
        return torch.tensor(padded_agent + padded_opp, dtype=torch.float32)

    def step(self, action):
        agent_action = C if action == 0 else D
        opp_action = self.opponent.strategy(self.agent)

        # Record moves in the agent's and oponnents history
        self.agent.history.append(agent_action, opp_action)
        self.opponent.history.append(opp_action, agent_action)

        # Also update the raw binary history for state vector
        self.agent_history.append(0 if agent_action == C else 1)
        self.opp_history.append(0 if opp_action == C else 1)

        payoff_matrix = {
            (C, C): (3, 3),
            (C, D): (0, 5),
            (D, C): (5, 0),
            (D, D): (1, 1)
        }

        reward, _ = payoff_matrix[(agent_action, opp_action)]
        self.turn += 1
        done = self.turn >= self.max_turns

        return self._get_state(), reward, done

# %%
# DQN Network and Replay Buffer
class DQN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.net(x)

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, next_state, done = map(np.stack, zip(*batch))
        return (
            torch.tensor(state, dtype=torch.float32),
            torch.tensor(action, dtype=torch.int64),
            torch.tensor(reward, dtype=torch.float32),
            torch.tensor(next_state, dtype=torch.float32),
            torch.tensor(done, dtype=torch.float32)
        )

    def __len__(self):
        return len(self.buffer)

# %%
# Training Setup
input_dim = 10
output_dim = 2
hidden_dim = 64
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
#epsilon_decay = 0.999430
lr = 1e-3
batch_size = 64
num_episodes = 3000

epsilon_decay = (epsilon_min / epsilon) ** (1 / (num_episodes * 0.85))
print(f"Epsilon decay: {epsilon_decay:.9f}")


policy_net = DQN(input_dim, hidden_dim, output_dim)
target_net = DQN(input_dim, hidden_dim, output_dim)
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=lr)
replay_buffer = ReplayBuffer(10000)

def select_action(state, epsilon):
    if random.random() < epsilon:
        return random.randint(0, 1)
    with torch.no_grad():
        return policy_net(state.unsqueeze(0)).argmax().item()
# Out:
# Epsilon decay: 0.998825893

# %%
# Opponent pool
opponent_pool = [
    # Group 1: Exploitable & Naive
    axl.CyclerCCCCCD(),
    axl.EasyGo(),
    axl.Alternator(),

    # Group 2: Punishing/Retaliatory & Reactive
    axl.Grudger(),
    axl.ForgivingTitForTat(),
    axl.HardTitForTat(),

    # Group 3: Stochastic & Noisy
    axl.Gambler(),
    axl.SoftJoss(),
    axl.StochasticWSLS(),

    # Group 4: Deceptive & Pattern-Based
    axl.WinStayLoseShift(),
    axl.TitFor2Tats(),
    axl.FoolMeOnce()
]

# Define rewards for plotting and evaluation
Total_reward = 0
avg_rewards = []


# Best till now
for episode in range(num_episodes):
    opponent = random.choice(opponent_pool)          # 🆕 random opponent
    env = IPDEnv(opponent)                           # 🆕 new environment with that opponent
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = select_action(state, epsilon)
        next_state, reward, done = env.step(action)
        replay_buffer.push(state.numpy(), action, reward, next_state.numpy(), done)
        state = next_state
        total_reward += reward

        if len(replay_buffer) >= batch_size:
            s, a, r, s2, d = replay_buffer.sample(batch_size)
            q_vals = policy_net(s).gather(1, a.unsqueeze(1)).squeeze()
            next_q_vals = target_net(s2).max(1)[0]
            target = r + gamma * next_q_vals * (1 - d)
            loss = nn.MSELoss()(q_vals, target.detach())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    if episode % 10 == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    avg_rewards.append(total_reward)
    print(f"Episode {episode},Opponent: {type(opponent).__name__}, Reward: {total_reward:.2f}, Epsilon: {epsilon:.2f}")


    if episode % 100 == 0:
        print(f"Episode {episode}, Avg Reward: {total_reward:.2f}, Epsilon: {epsilon:.2f}")



torch.save(policy_net.state_dict(), "dqn_policy.pth")

# Plot reward curve
plt.plot(avg_rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward per Episode")
plt.title("Learning Curve")
plt.grid(True)
plt.show()

pd.Series(avg_rewards).rolling(50).mean().plot()
# Out:
# Episode 0,Opponent: TitFor2Tats, Reward: 295.00, Epsilon: 1.00
# Episode 0, Avg Reward: 295.00, Epsilon: 1.00
# Episode 1,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 1.00
# Episode 2,Opponent: Grudger, Reward: 54.00, Epsilon: 1.00
# Episode 3,Opponent: CyclerCCCCCD, Reward: 341.00, Epsilon: 1.00
# Episode 4,Opponent: Grudger, Reward: 62.00, Epsilon: 0.99
# Episode 5,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.99
# Episode 6,Opponent: HardTitForTat, Reward: 98.00, Epsilon: 0.99
# Episode 7,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.99
# Episode 8,Opponent: EasyGo, Reward: 405.00, Epsilon: 0.99
# Episode 9,Opponent: Gambler, Reward: 238.00, Epsilon: 0.99
# Episode 10,Opponent: FoolMeOnce, Reward: 64.00, Epsilon: 0.99
# Episode 11,Opponent: EasyGo, Reward: 393.00, Epsilon: 0.99
# Episode 12,Opponent: CyclerCCCCCD, Reward: 336.00, Epsilon: 0.98
# Episode 13,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.98
# Episode 14,Opponent: Grudger, Reward: 58.00, Epsilon: 0.98
# Episode 15,Opponent: EasyGo, Reward: 398.00, Epsilon: 0.98
# Episode 16,Opponent: ForgivingTitForTat, Reward: 227.00, Epsilon: 0.98
# Episode 17,Opponent: TitFor2Tats, Reward: 312.00, Epsilon: 0.98
# Episode 18,Opponent: Gambler, Reward: 217.00, Epsilon: 0.98
# Episode 19,Opponent: SoftJoss, Reward: 414.00, Epsilon: 0.98
# Episode 20,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.98
# Episode 21,Opponent: Gambler, Reward: 232.00, Epsilon: 0.97
# Episode 22,Opponent: ForgivingTitForTat, Reward: 241.00, Epsilon: 0.97
# Episode 23,Opponent: SoftJoss, Reward: 402.00, Epsilon: 0.97
# Episode 24,Opponent: FoolMeOnce, Reward: 55.00, Epsilon: 0.97
# Episode 25,Opponent: ForgivingTitForTat, Reward: 210.00, Epsilon: 0.97
# Episode 26,Opponent: StochasticWSLS, Reward: 402.00, Epsilon: 0.97
# Episode 27,Opponent: FoolMeOnce, Reward: 53.00, Epsilon: 0.97
# Episode 28,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.97
# Episode 29,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.97
# Episode 30,Opponent: StochasticWSLS, Reward: 400.00, Epsilon: 0.96
# Episode 31,Opponent: EasyGo, Reward: 346.00, Epsilon: 0.96
# Episode 32,Opponent: FoolMeOnce, Reward: 69.00, Epsilon: 0.96
# Episode 33,Opponent: ForgivingTitForTat, Reward: 225.00, Epsilon: 0.96
# Episode 34,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.96
# Episode 35,Opponent: Alternator, Reward: 219.00, Epsilon: 0.96
# Episode 36,Opponent: Alternator, Reward: 223.00, Epsilon: 0.96
# Episode 37,Opponent: HardTitForTat, Reward: 86.00, Epsilon: 0.96
# Episode 38,Opponent: ForgivingTitForTat, Reward: 218.00, Epsilon: 0.96
# Episode 39,Opponent: StochasticWSLS, Reward: 404.00, Epsilon: 0.95
# Episode 40,Opponent: HardTitForTat, Reward: 114.00, Epsilon: 0.95
# Episode 41,Opponent: HardTitForTat, Reward: 77.00, Epsilon: 0.95
# Episode 42,Opponent: EasyGo, Reward: 384.00, Epsilon: 0.95
# Episode 43,Opponent: WinStayLoseShift, Reward: 219.00, Epsilon: 0.95
# Episode 44,Opponent: Gambler, Reward: 235.00, Epsilon: 0.95
# Episode 45,Opponent: StochasticWSLS, Reward: 388.00, Epsilon: 0.95
# Episode 46,Opponent: ForgivingTitForTat, Reward: 239.00, Epsilon: 0.95
# Episode 47,Opponent: WinStayLoseShift, Reward: 230.00, Epsilon: 0.95
# Episode 48,Opponent: Alternator, Reward: 219.00, Epsilon: 0.94
# Episode 49,Opponent: Gambler, Reward: 231.00, Epsilon: 0.94
# Episode 50,Opponent: FoolMeOnce, Reward: 74.00, Epsilon: 0.94
# Episode 51,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.94
# Episode 52,Opponent: ForgivingTitForTat, Reward: 235.00, Epsilon: 0.94
# Episode 53,Opponent: Grudger, Reward: 78.00, Epsilon: 0.94
# Episode 54,Opponent: StochasticWSLS, Reward: 424.00, Epsilon: 0.94
# Episode 55,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.94
# Episode 56,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.94
# Episode 57,Opponent: WinStayLoseShift, Reward: 231.00, Epsilon: 0.93
# Episode 58,Opponent: EasyGo, Reward: 405.00, Epsilon: 0.93
# Episode 59,Opponent: HardTitForTat, Reward: 79.00, Epsilon: 0.93
# Episode 60,Opponent: HardTitForTat, Reward: 98.00, Epsilon: 0.93
# Episode 61,Opponent: HardTitForTat, Reward: 115.00, Epsilon: 0.93
# Episode 62,Opponent: FoolMeOnce, Reward: 74.00, Epsilon: 0.93
# Episode 63,Opponent: Gambler, Reward: 231.00, Epsilon: 0.93
# Episode 64,Opponent: Gambler, Reward: 230.00, Epsilon: 0.93
# Episode 65,Opponent: WinStayLoseShift, Reward: 245.00, Epsilon: 0.93
# Episode 66,Opponent: WinStayLoseShift, Reward: 224.00, Epsilon: 0.92
# Episode 67,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.92
# Episode 68,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.92
# Episode 69,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.92
# Episode 70,Opponent: Alternator, Reward: 208.00, Epsilon: 0.92
# Episode 71,Opponent: Gambler, Reward: 242.00, Epsilon: 0.92
# Episode 72,Opponent: FoolMeOnce, Reward: 68.00, Epsilon: 0.92
# Episode 73,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.92
# Episode 74,Opponent: Alternator, Reward: 214.00, Epsilon: 0.92
# Episode 75,Opponent: HardTitForTat, Reward: 103.00, Epsilon: 0.91
# Episode 76,Opponent: ForgivingTitForTat, Reward: 239.00, Epsilon: 0.91
# Episode 77,Opponent: EasyGo, Reward: 389.00, Epsilon: 0.91
# Episode 78,Opponent: CyclerCCCCCD, Reward: 356.00, Epsilon: 0.91
# Episode 79,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.91
# Episode 80,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.91
# Episode 81,Opponent: Alternator, Reward: 211.00, Epsilon: 0.91
# Episode 82,Opponent: Alternator, Reward: 217.00, Epsilon: 0.91
# Episode 83,Opponent: HardTitForTat, Reward: 83.00, Epsilon: 0.91
# Episode 84,Opponent: Grudger, Reward: 55.00, Epsilon: 0.90
# Episode 85,Opponent: StochasticWSLS, Reward: 394.00, Epsilon: 0.90
# Episode 86,Opponent: SoftJoss, Reward: 384.00, Epsilon: 0.90
# Episode 87,Opponent: WinStayLoseShift, Reward: 215.00, Epsilon: 0.90
# Episode 88,Opponent: Alternator, Reward: 220.00, Epsilon: 0.90
# Episode 89,Opponent: HardTitForTat, Reward: 94.00, Epsilon: 0.90
# Episode 90,Opponent: Alternator, Reward: 224.00, Epsilon: 0.90
# Episode 91,Opponent: StochasticWSLS, Reward: 414.00, Epsilon: 0.90
# Episode 92,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.90
# Episode 93,Opponent: WinStayLoseShift, Reward: 230.00, Epsilon: 0.90
# Episode 94,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.89
# Episode 95,Opponent: SoftJoss, Reward: 420.00, Epsilon: 0.89
# Episode 96,Opponent: Grudger, Reward: 50.00, Epsilon: 0.89
# Episode 97,Opponent: HardTitForTat, Reward: 92.00, Epsilon: 0.89
# Episode 98,Opponent: FoolMeOnce, Reward: 67.00, Epsilon: 0.89
# Episode 99,Opponent: FoolMeOnce, Reward: 78.00, Epsilon: 0.89
# Episode 100,Opponent: Grudger, Reward: 45.00, Epsilon: 0.89
# Episode 100, Avg Reward: 45.00, Epsilon: 0.89
# Episode 101,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.89
# Episode 102,Opponent: HardTitForTat, Reward: 96.00, Epsilon: 0.89
# Episode 103,Opponent: Grudger, Reward: 56.00, Epsilon: 0.88
# Episode 104,Opponent: HardTitForTat, Reward: 109.00, Epsilon: 0.88
# Episode 105,Opponent: WinStayLoseShift, Reward: 222.00, Epsilon: 0.88
# Episode 106,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.88
# Episode 107,Opponent: ForgivingTitForTat, Reward: 241.00, Epsilon: 0.88
# Episode 108,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.88
# Episode 109,Opponent: Alternator, Reward: 235.00, Epsilon: 0.88
# Episode 110,Opponent: FoolMeOnce, Reward: 60.00, Epsilon: 0.88
# Episode 111,Opponent: FoolMeOnce, Reward: 60.00, Epsilon: 0.88
# Episode 112,Opponent: Alternator, Reward: 219.00, Epsilon: 0.88
# Episode 113,Opponent: TitFor2Tats, Reward: 304.00, Epsilon: 0.87
# Episode 114,Opponent: StochasticWSLS, Reward: 400.00, Epsilon: 0.87
# Episode 115,Opponent: Grudger, Reward: 52.00, Epsilon: 0.87
# Episode 116,Opponent: Gambler, Reward: 213.00, Epsilon: 0.87
# Episode 117,Opponent: TitFor2Tats, Reward: 309.00, Epsilon: 0.87
# Episode 118,Opponent: WinStayLoseShift, Reward: 218.00, Epsilon: 0.87
# Episode 119,Opponent: Gambler, Reward: 235.00, Epsilon: 0.87
# Episode 120,Opponent: Alternator, Reward: 221.00, Epsilon: 0.87
# Episode 121,Opponent: ForgivingTitForTat, Reward: 231.00, Epsilon: 0.87
# Episode 122,Opponent: Gambler, Reward: 223.00, Epsilon: 0.87
# Episode 123,Opponent: Alternator, Reward: 233.00, Epsilon: 0.86
# Episode 124,Opponent: FoolMeOnce, Reward: 55.00, Epsilon: 0.86
# Episode 125,Opponent: EasyGo, Reward: 396.00, Epsilon: 0.86
# Episode 126,Opponent: EasyGo, Reward: 417.00, Epsilon: 0.86
# Episode 127,Opponent: CyclerCCCCCD, Reward: 340.00, Epsilon: 0.86
# Episode 128,Opponent: Grudger, Reward: 54.00, Epsilon: 0.86
# Episode 129,Opponent: EasyGo, Reward: 400.00, Epsilon: 0.86
# Episode 130,Opponent: WinStayLoseShift, Reward: 210.00, Epsilon: 0.86
# Episode 131,Opponent: ForgivingTitForTat, Reward: 236.00, Epsilon: 0.86
# Episode 132,Opponent: TitFor2Tats, Reward: 311.00, Epsilon: 0.86
# Episode 133,Opponent: Gambler, Reward: 243.00, Epsilon: 0.85
# Episode 134,Opponent: TitFor2Tats, Reward: 307.00, Epsilon: 0.85
# Episode 135,Opponent: Grudger, Reward: 65.00, Epsilon: 0.85
# Episode 136,Opponent: Grudger, Reward: 57.00, Epsilon: 0.85
# Episode 137,Opponent: StochasticWSLS, Reward: 422.00, Epsilon: 0.85
# Episode 138,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.85
# Episode 139,Opponent: Alternator, Reward: 223.00, Epsilon: 0.85
# Episode 140,Opponent: FoolMeOnce, Reward: 64.00, Epsilon: 0.85
# Episode 141,Opponent: SoftJoss, Reward: 398.00, Epsilon: 0.85
# Episode 142,Opponent: ForgivingTitForTat, Reward: 237.00, Epsilon: 0.85
# Episode 143,Opponent: Alternator, Reward: 229.00, Epsilon: 0.84
# Episode 144,Opponent: Gambler, Reward: 236.00, Epsilon: 0.84
# Episode 145,Opponent: Grudger, Reward: 39.00, Epsilon: 0.84
# Episode 146,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.84
# Episode 147,Opponent: WinStayLoseShift, Reward: 231.00, Epsilon: 0.84
# Episode 148,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.84
# Episode 149,Opponent: WinStayLoseShift, Reward: 213.00, Epsilon: 0.84
# Episode 150,Opponent: HardTitForTat, Reward: 101.00, Epsilon: 0.84
# Episode 151,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.84
# Episode 152,Opponent: CyclerCCCCCD, Reward: 339.00, Epsilon: 0.84
# Episode 153,Opponent: CyclerCCCCCD, Reward: 361.00, Epsilon: 0.83
# Episode 154,Opponent: Grudger, Reward: 52.00, Epsilon: 0.83
# Episode 155,Opponent: TitFor2Tats, Reward: 298.00, Epsilon: 0.83
# Episode 156,Opponent: HardTitForTat, Reward: 133.00, Epsilon: 0.83
# Episode 157,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.83
# Episode 158,Opponent: HardTitForTat, Reward: 138.00, Epsilon: 0.83
# Episode 159,Opponent: StochasticWSLS, Reward: 420.00, Epsilon: 0.83
# Episode 160,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.83
# Episode 161,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.83
# Episode 162,Opponent: EasyGo, Reward: 431.00, Epsilon: 0.83
# Episode 163,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.82
# Episode 164,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.82
# Episode 165,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.82
# Episode 166,Opponent: Alternator, Reward: 247.00, Epsilon: 0.82
# Episode 167,Opponent: Gambler, Reward: 234.00, Epsilon: 0.82
# Episode 168,Opponent: EasyGo, Reward: 407.00, Epsilon: 0.82
# Episode 169,Opponent: SoftJoss, Reward: 412.00, Epsilon: 0.82
# Episode 170,Opponent: TitFor2Tats, Reward: 307.00, Epsilon: 0.82
# Episode 171,Opponent: Grudger, Reward: 55.00, Epsilon: 0.82
# Episode 172,Opponent: Gambler, Reward: 225.00, Epsilon: 0.82
# Episode 173,Opponent: ForgivingTitForTat, Reward: 220.00, Epsilon: 0.82
# Episode 174,Opponent: ForgivingTitForTat, Reward: 248.00, Epsilon: 0.81
# Episode 175,Opponent: ForgivingTitForTat, Reward: 232.00, Epsilon: 0.81
# Episode 176,Opponent: FoolMeOnce, Reward: 62.00, Epsilon: 0.81
# Episode 177,Opponent: TitFor2Tats, Reward: 310.00, Epsilon: 0.81
# Episode 178,Opponent: TitFor2Tats, Reward: 339.00, Epsilon: 0.81
# Episode 179,Opponent: ForgivingTitForTat, Reward: 239.00, Epsilon: 0.81
# Episode 180,Opponent: Gambler, Reward: 244.00, Epsilon: 0.81
# Episode 181,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.81
# Episode 182,Opponent: WinStayLoseShift, Reward: 245.00, Epsilon: 0.81
# Episode 183,Opponent: ForgivingTitForTat, Reward: 224.00, Epsilon: 0.81
# Episode 184,Opponent: SoftJoss, Reward: 406.00, Epsilon: 0.80
# Episode 185,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.80
# Episode 186,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.80
# Episode 187,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.80
# Episode 188,Opponent: EasyGo, Reward: 394.00, Epsilon: 0.80
# Episode 189,Opponent: Gambler, Reward: 237.00, Epsilon: 0.80
# Episode 190,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.80
# Episode 191,Opponent: HardTitForTat, Reward: 108.00, Epsilon: 0.80
# Episode 192,Opponent: HardTitForTat, Reward: 107.00, Epsilon: 0.80
# Episode 193,Opponent: EasyGo, Reward: 429.00, Epsilon: 0.80
# Episode 194,Opponent: HardTitForTat, Reward: 119.00, Epsilon: 0.80
# Episode 195,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.79
# Episode 196,Opponent: ForgivingTitForTat, Reward: 259.00, Epsilon: 0.79
# Episode 197,Opponent: FoolMeOnce, Reward: 71.00, Epsilon: 0.79
# Episode 198,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.79
# Episode 199,Opponent: HardTitForTat, Reward: 103.00, Epsilon: 0.79
# Episode 200,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.79
# Episode 200, Avg Reward: 432.00, Epsilon: 0.79
# Episode 201,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.79
# Episode 202,Opponent: Gambler, Reward: 238.00, Epsilon: 0.79
# Episode 203,Opponent: Grudger, Reward: 55.00, Epsilon: 0.79
# Episode 204,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.79
# Episode 205,Opponent: Alternator, Reward: 234.00, Epsilon: 0.79
# Episode 206,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.78
# Episode 207,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.78
# Episode 208,Opponent: HardTitForTat, Reward: 96.00, Epsilon: 0.78
# Episode 209,Opponent: TitFor2Tats, Reward: 318.00, Epsilon: 0.78
# Episode 210,Opponent: FoolMeOnce, Reward: 51.00, Epsilon: 0.78
# Episode 211,Opponent: StochasticWSLS, Reward: 426.00, Epsilon: 0.78
# Episode 212,Opponent: Grudger, Reward: 37.00, Epsilon: 0.78
# Episode 213,Opponent: Gambler, Reward: 240.00, Epsilon: 0.78
# Episode 214,Opponent: SoftJoss, Reward: 402.00, Epsilon: 0.78
# Episode 215,Opponent: HardTitForTat, Reward: 128.00, Epsilon: 0.78
# Episode 216,Opponent: HardTitForTat, Reward: 112.00, Epsilon: 0.77
# Episode 217,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.77
# Episode 218,Opponent: Grudger, Reward: 44.00, Epsilon: 0.77
# Episode 219,Opponent: EasyGo, Reward: 416.00, Epsilon: 0.77
# Episode 220,Opponent: HardTitForTat, Reward: 108.00, Epsilon: 0.77
# Episode 221,Opponent: HardTitForTat, Reward: 121.00, Epsilon: 0.77
# Episode 222,Opponent: HardTitForTat, Reward: 106.00, Epsilon: 0.77
# Episode 223,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.77
# Episode 224,Opponent: CyclerCCCCCD, Reward: 367.00, Epsilon: 0.77
# Episode 225,Opponent: FoolMeOnce, Reward: 65.00, Epsilon: 0.77
# Episode 226,Opponent: TitFor2Tats, Reward: 304.00, Epsilon: 0.77
# Episode 227,Opponent: TitFor2Tats, Reward: 309.00, Epsilon: 0.77
# Episode 228,Opponent: Grudger, Reward: 44.00, Epsilon: 0.76
# Episode 229,Opponent: EasyGo, Reward: 424.00, Epsilon: 0.76
# Episode 230,Opponent: EasyGo, Reward: 418.00, Epsilon: 0.76
# Episode 231,Opponent: ForgivingTitForTat, Reward: 237.00, Epsilon: 0.76
# Episode 232,Opponent: StochasticWSLS, Reward: 408.00, Epsilon: 0.76
# Episode 233,Opponent: Gambler, Reward: 224.00, Epsilon: 0.76
# Episode 234,Opponent: HardTitForTat, Reward: 94.00, Epsilon: 0.76
# Episode 235,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.76
# Episode 236,Opponent: HardTitForTat, Reward: 121.00, Epsilon: 0.76
# Episode 237,Opponent: SoftJoss, Reward: 444.00, Epsilon: 0.76
# Episode 238,Opponent: ForgivingTitForTat, Reward: 231.00, Epsilon: 0.76
# Episode 239,Opponent: CyclerCCCCCD, Reward: 372.00, Epsilon: 0.75
# Episode 240,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.75
# Episode 241,Opponent: Alternator, Reward: 236.00, Epsilon: 0.75
# Episode 242,Opponent: Grudger, Reward: 51.00, Epsilon: 0.75
# Episode 243,Opponent: Grudger, Reward: 52.00, Epsilon: 0.75
# Episode 244,Opponent: ForgivingTitForTat, Reward: 242.00, Epsilon: 0.75
# Episode 245,Opponent: FoolMeOnce, Reward: 45.00, Epsilon: 0.75
# Episode 246,Opponent: WinStayLoseShift, Reward: 201.00, Epsilon: 0.75
# Episode 247,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.75
# Episode 248,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.75
# Episode 249,Opponent: CyclerCCCCCD, Reward: 375.00, Epsilon: 0.75
# Episode 250,Opponent: Alternator, Reward: 228.00, Epsilon: 0.74
# Episode 251,Opponent: EasyGo, Reward: 415.00, Epsilon: 0.74
# Episode 252,Opponent: HardTitForTat, Reward: 138.00, Epsilon: 0.74
# Episode 253,Opponent: Grudger, Reward: 51.00, Epsilon: 0.74
# Episode 254,Opponent: Gambler, Reward: 232.00, Epsilon: 0.74
# Episode 255,Opponent: Gambler, Reward: 254.00, Epsilon: 0.74
# Episode 256,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.74
# Episode 257,Opponent: Grudger, Reward: 53.00, Epsilon: 0.74
# Episode 258,Opponent: WinStayLoseShift, Reward: 225.00, Epsilon: 0.74
# Episode 259,Opponent: WinStayLoseShift, Reward: 231.00, Epsilon: 0.74
# Episode 260,Opponent: CyclerCCCCCD, Reward: 351.00, Epsilon: 0.74
# Episode 261,Opponent: WinStayLoseShift, Reward: 270.00, Epsilon: 0.74
# Episode 262,Opponent: EasyGo, Reward: 417.00, Epsilon: 0.73
# Episode 263,Opponent: Alternator, Reward: 219.00, Epsilon: 0.73
# Episode 264,Opponent: SoftJoss, Reward: 410.00, Epsilon: 0.73
# Episode 265,Opponent: FoolMeOnce, Reward: 49.00, Epsilon: 0.73
# Episode 266,Opponent: StochasticWSLS, Reward: 426.00, Epsilon: 0.73
# Episode 267,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.73
# Episode 268,Opponent: ForgivingTitForTat, Reward: 246.00, Epsilon: 0.73
# Episode 269,Opponent: EasyGo, Reward: 418.00, Epsilon: 0.73
# Episode 270,Opponent: Alternator, Reward: 237.00, Epsilon: 0.73
# Episode 271,Opponent: EasyGo, Reward: 420.00, Epsilon: 0.73
# Episode 272,Opponent: EasyGo, Reward: 411.00, Epsilon: 0.73
# Episode 273,Opponent: Alternator, Reward: 233.00, Epsilon: 0.72
# Episode 274,Opponent: CyclerCCCCCD, Reward: 348.00, Epsilon: 0.72
# Episode 275,Opponent: FoolMeOnce, Reward: 49.00, Epsilon: 0.72
# Episode 276,Opponent: Alternator, Reward: 241.00, Epsilon: 0.72
# Episode 277,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.72
# Episode 278,Opponent: StochasticWSLS, Reward: 424.00, Epsilon: 0.72
# Episode 279,Opponent: StochasticWSLS, Reward: 434.00, Epsilon: 0.72
# Episode 280,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.72
# Episode 281,Opponent: Gambler, Reward: 241.00, Epsilon: 0.72
# Episode 282,Opponent: Alternator, Reward: 243.00, Epsilon: 0.72
# Episode 283,Opponent: EasyGo, Reward: 417.00, Epsilon: 0.72
# Episode 284,Opponent: Gambler, Reward: 241.00, Epsilon: 0.72
# Episode 285,Opponent: EasyGo, Reward: 424.00, Epsilon: 0.71
# Episode 286,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.71
# Episode 287,Opponent: TitFor2Tats, Reward: 321.00, Epsilon: 0.71
# Episode 288,Opponent: SoftJoss, Reward: 438.00, Epsilon: 0.71
# Episode 289,Opponent: Gambler, Reward: 240.00, Epsilon: 0.71
# Episode 290,Opponent: Gambler, Reward: 247.00, Epsilon: 0.71
# Episode 291,Opponent: Gambler, Reward: 248.00, Epsilon: 0.71
# Episode 292,Opponent: HardTitForTat, Reward: 104.00, Epsilon: 0.71
# Episode 293,Opponent: WinStayLoseShift, Reward: 252.00, Epsilon: 0.71
# Episode 294,Opponent: Alternator, Reward: 240.00, Epsilon: 0.71
# Episode 295,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.71
# Episode 296,Opponent: Alternator, Reward: 233.00, Epsilon: 0.71
# Episode 297,Opponent: Gambler, Reward: 246.00, Epsilon: 0.70
# Episode 298,Opponent: Alternator, Reward: 232.00, Epsilon: 0.70
# Episode 299,Opponent: TitFor2Tats, Reward: 318.00, Epsilon: 0.70
# Episode 300,Opponent: Gambler, Reward: 256.00, Epsilon: 0.70
# Episode 300, Avg Reward: 256.00, Epsilon: 0.70
# Episode 301,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.70
# Episode 302,Opponent: FoolMeOnce, Reward: 48.00, Epsilon: 0.70
# Episode 303,Opponent: EasyGo, Reward: 424.00, Epsilon: 0.70
# Episode 304,Opponent: ForgivingTitForTat, Reward: 243.00, Epsilon: 0.70
# Episode 305,Opponent: FoolMeOnce, Reward: 56.00, Epsilon: 0.70
# Episode 306,Opponent: CyclerCCCCCD, Reward: 367.00, Epsilon: 0.70
# Episode 307,Opponent: TitFor2Tats, Reward: 300.00, Epsilon: 0.70
# Episode 308,Opponent: Alternator, Reward: 245.00, Epsilon: 0.70
# Episode 309,Opponent: WinStayLoseShift, Reward: 212.00, Epsilon: 0.69
# Episode 310,Opponent: HardTitForTat, Reward: 126.00, Epsilon: 0.69
# Episode 311,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.69
# Episode 312,Opponent: HardTitForTat, Reward: 144.00, Epsilon: 0.69
# Episode 313,Opponent: TitFor2Tats, Reward: 298.00, Epsilon: 0.69
# Episode 314,Opponent: Grudger, Reward: 55.00, Epsilon: 0.69
# Episode 315,Opponent: StochasticWSLS, Reward: 418.00, Epsilon: 0.69
# Episode 316,Opponent: WinStayLoseShift, Reward: 257.00, Epsilon: 0.69
# Episode 317,Opponent: Grudger, Reward: 55.00, Epsilon: 0.69
# Episode 318,Opponent: HardTitForTat, Reward: 123.00, Epsilon: 0.69
# Episode 319,Opponent: EasyGo, Reward: 400.00, Epsilon: 0.69
# Episode 320,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.69
# Episode 321,Opponent: ForgivingTitForTat, Reward: 245.00, Epsilon: 0.69
# Episode 322,Opponent: Alternator, Reward: 241.00, Epsilon: 0.68
# Episode 323,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.68
# Episode 324,Opponent: Alternator, Reward: 237.00, Epsilon: 0.68
# Episode 325,Opponent: StochasticWSLS, Reward: 444.00, Epsilon: 0.68
# Episode 326,Opponent: Gambler, Reward: 248.00, Epsilon: 0.68
# Episode 327,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.68
# Episode 328,Opponent: ForgivingTitForTat, Reward: 246.00, Epsilon: 0.68
# Episode 329,Opponent: Grudger, Reward: 52.00, Epsilon: 0.68
# Episode 330,Opponent: FoolMeOnce, Reward: 60.00, Epsilon: 0.68
# Episode 331,Opponent: WinStayLoseShift, Reward: 224.00, Epsilon: 0.68
# Episode 332,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.68
# Episode 333,Opponent: HardTitForTat, Reward: 131.00, Epsilon: 0.68
# Episode 334,Opponent: WinStayLoseShift, Reward: 260.00, Epsilon: 0.67
# Episode 335,Opponent: TitFor2Tats, Reward: 326.00, Epsilon: 0.67
# Episode 336,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.67
# Episode 337,Opponent: TitFor2Tats, Reward: 326.00, Epsilon: 0.67
# Episode 338,Opponent: EasyGo, Reward: 397.00, Epsilon: 0.67
# Episode 339,Opponent: Gambler, Reward: 254.00, Epsilon: 0.67
# Episode 340,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.67
# Episode 341,Opponent: Alternator, Reward: 236.00, Epsilon: 0.67
# Episode 342,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.67
# Episode 343,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.67
# Episode 344,Opponent: CyclerCCCCCD, Reward: 351.00, Epsilon: 0.67
# Episode 345,Opponent: CyclerCCCCCD, Reward: 346.00, Epsilon: 0.67
# Episode 346,Opponent: Grudger, Reward: 54.00, Epsilon: 0.67
# Episode 347,Opponent: Grudger, Reward: 48.00, Epsilon: 0.66
# Episode 348,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.66
# Episode 349,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.66
# Episode 350,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.66
# Episode 351,Opponent: Alternator, Reward: 232.00, Epsilon: 0.66
# Episode 352,Opponent: CyclerCCCCCD, Reward: 359.00, Epsilon: 0.66
# Episode 353,Opponent: Grudger, Reward: 54.00, Epsilon: 0.66
# Episode 354,Opponent: FoolMeOnce, Reward: 60.00, Epsilon: 0.66
# Episode 355,Opponent: HardTitForTat, Reward: 102.00, Epsilon: 0.66
# Episode 356,Opponent: TitFor2Tats, Reward: 318.00, Epsilon: 0.66
# Episode 357,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.66
# Episode 358,Opponent: ForgivingTitForTat, Reward: 251.00, Epsilon: 0.66
# Episode 359,Opponent: TitFor2Tats, Reward: 303.00, Epsilon: 0.66
# Episode 360,Opponent: FoolMeOnce, Reward: 66.00, Epsilon: 0.65
# Episode 361,Opponent: Gambler, Reward: 251.00, Epsilon: 0.65
# Episode 362,Opponent: CyclerCCCCCD, Reward: 367.00, Epsilon: 0.65
# Episode 363,Opponent: Alternator, Reward: 232.00, Epsilon: 0.65
# Episode 364,Opponent: CyclerCCCCCD, Reward: 360.00, Epsilon: 0.65
# Episode 365,Opponent: Grudger, Reward: 58.00, Epsilon: 0.65
# Episode 366,Opponent: CyclerCCCCCD, Reward: 354.00, Epsilon: 0.65
# Episode 367,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.65
# Episode 368,Opponent: EasyGo, Reward: 428.00, Epsilon: 0.65
# Episode 369,Opponent: TitFor2Tats, Reward: 336.00, Epsilon: 0.65
# Episode 370,Opponent: FoolMeOnce, Reward: 63.00, Epsilon: 0.65
# Episode 371,Opponent: CyclerCCCCCD, Reward: 362.00, Epsilon: 0.65
# Episode 372,Opponent: HardTitForTat, Reward: 110.00, Epsilon: 0.65
# Episode 373,Opponent: Grudger, Reward: 58.00, Epsilon: 0.64
# Episode 374,Opponent: WinStayLoseShift, Reward: 242.00, Epsilon: 0.64
# Episode 375,Opponent: EasyGo, Reward: 438.00, Epsilon: 0.64
# Episode 376,Opponent: Grudger, Reward: 52.00, Epsilon: 0.64
# Episode 377,Opponent: WinStayLoseShift, Reward: 257.00, Epsilon: 0.64
# Episode 378,Opponent: ForgivingTitForTat, Reward: 234.00, Epsilon: 0.64
# Episode 379,Opponent: TitFor2Tats, Reward: 303.00, Epsilon: 0.64
# Episode 380,Opponent: WinStayLoseShift, Reward: 215.00, Epsilon: 0.64
# Episode 381,Opponent: Gambler, Reward: 252.00, Epsilon: 0.64
# Episode 382,Opponent: Gambler, Reward: 235.00, Epsilon: 0.64
# Episode 383,Opponent: ForgivingTitForTat, Reward: 246.00, Epsilon: 0.64
# Episode 384,Opponent: WinStayLoseShift, Reward: 249.00, Epsilon: 0.64
# Episode 385,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.64
# Episode 386,Opponent: EasyGo, Reward: 434.00, Epsilon: 0.63
# Episode 387,Opponent: HardTitForTat, Reward: 116.00, Epsilon: 0.63
# Episode 388,Opponent: EasyGo, Reward: 438.00, Epsilon: 0.63
# Episode 389,Opponent: Grudger, Reward: 57.00, Epsilon: 0.63
# Episode 390,Opponent: EasyGo, Reward: 458.00, Epsilon: 0.63
# Episode 391,Opponent: Gambler, Reward: 257.00, Epsilon: 0.63
# Episode 392,Opponent: Grudger, Reward: 49.00, Epsilon: 0.63
# Episode 393,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.63
# Episode 394,Opponent: Alternator, Reward: 244.00, Epsilon: 0.63
# Episode 395,Opponent: EasyGo, Reward: 430.00, Epsilon: 0.63
# Episode 396,Opponent: Alternator, Reward: 238.00, Epsilon: 0.63
# Episode 397,Opponent: ForgivingTitForTat, Reward: 241.00, Epsilon: 0.63
# Episode 398,Opponent: Gambler, Reward: 246.00, Epsilon: 0.63
# Episode 399,Opponent: EasyGo, Reward: 420.00, Epsilon: 0.63
# Episode 400,Opponent: EasyGo, Reward: 415.00, Epsilon: 0.62
# Episode 400, Avg Reward: 415.00, Epsilon: 0.62
# Episode 401,Opponent: WinStayLoseShift, Reward: 240.00, Epsilon: 0.62
# Episode 402,Opponent: CyclerCCCCCD, Reward: 353.00, Epsilon: 0.62
# Episode 403,Opponent: Alternator, Reward: 228.00, Epsilon: 0.62
# Episode 404,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.62
# Episode 405,Opponent: WinStayLoseShift, Reward: 227.00, Epsilon: 0.62
# Episode 406,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.62
# Episode 407,Opponent: SoftJoss, Reward: 422.00, Epsilon: 0.62
# Episode 408,Opponent: Gambler, Reward: 249.00, Epsilon: 0.62
# Episode 409,Opponent: CyclerCCCCCD, Reward: 361.00, Epsilon: 0.62
# Episode 410,Opponent: SoftJoss, Reward: 412.00, Epsilon: 0.62
# Episode 411,Opponent: FoolMeOnce, Reward: 72.00, Epsilon: 0.62
# Episode 412,Opponent: EasyGo, Reward: 422.00, Epsilon: 0.62
# Episode 413,Opponent: Alternator, Reward: 234.00, Epsilon: 0.61
# Episode 414,Opponent: Alternator, Reward: 249.00, Epsilon: 0.61
# Episode 415,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.61
# Episode 416,Opponent: EasyGo, Reward: 418.00, Epsilon: 0.61
# Episode 417,Opponent: StochasticWSLS, Reward: 438.00, Epsilon: 0.61
# Episode 418,Opponent: TitFor2Tats, Reward: 327.00, Epsilon: 0.61
# Episode 419,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.61
# Episode 420,Opponent: HardTitForTat, Reward: 116.00, Epsilon: 0.61
# Episode 421,Opponent: WinStayLoseShift, Reward: 237.00, Epsilon: 0.61
# Episode 422,Opponent: CyclerCCCCCD, Reward: 365.00, Epsilon: 0.61
# Episode 423,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.61
# Episode 424,Opponent: StochasticWSLS, Reward: 438.00, Epsilon: 0.61
# Episode 425,Opponent: StochasticWSLS, Reward: 422.00, Epsilon: 0.61
# Episode 426,Opponent: FoolMeOnce, Reward: 45.00, Epsilon: 0.61
# Episode 427,Opponent: Gambler, Reward: 245.00, Epsilon: 0.60
# Episode 428,Opponent: HardTitForTat, Reward: 108.00, Epsilon: 0.60
# Episode 429,Opponent: FoolMeOnce, Reward: 41.00, Epsilon: 0.60
# Episode 430,Opponent: StochasticWSLS, Reward: 446.00, Epsilon: 0.60
# Episode 431,Opponent: Grudger, Reward: 36.00, Epsilon: 0.60
# Episode 432,Opponent: CyclerCCCCCD, Reward: 351.00, Epsilon: 0.60
# Episode 433,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.60
# Episode 434,Opponent: HardTitForTat, Reward: 105.00, Epsilon: 0.60
# Episode 435,Opponent: WinStayLoseShift, Reward: 263.00, Epsilon: 0.60
# Episode 436,Opponent: Alternator, Reward: 247.00, Epsilon: 0.60
# Episode 437,Opponent: StochasticWSLS, Reward: 444.00, Epsilon: 0.60
# Episode 438,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.60
# Episode 439,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.60
# Episode 440,Opponent: Alternator, Reward: 233.00, Epsilon: 0.60
# Episode 441,Opponent: SoftJoss, Reward: 424.00, Epsilon: 0.59
# Episode 442,Opponent: WinStayLoseShift, Reward: 204.00, Epsilon: 0.59
# Episode 443,Opponent: ForgivingTitForTat, Reward: 245.00, Epsilon: 0.59
# Episode 444,Opponent: FoolMeOnce, Reward: 59.00, Epsilon: 0.59
# Episode 445,Opponent: ForgivingTitForTat, Reward: 262.00, Epsilon: 0.59
# Episode 446,Opponent: Alternator, Reward: 225.00, Epsilon: 0.59
# Episode 447,Opponent: CyclerCCCCCD, Reward: 363.00, Epsilon: 0.59
# Episode 448,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.59
# Episode 449,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.59
# Episode 450,Opponent: WinStayLoseShift, Reward: 224.00, Epsilon: 0.59
# Episode 451,Opponent: WinStayLoseShift, Reward: 228.00, Epsilon: 0.59
# Episode 452,Opponent: ForgivingTitForTat, Reward: 234.00, Epsilon: 0.59
# Episode 453,Opponent: Alternator, Reward: 242.00, Epsilon: 0.59
# Episode 454,Opponent: Alternator, Reward: 239.00, Epsilon: 0.59
# Episode 455,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.59
# Episode 456,Opponent: TitFor2Tats, Reward: 305.00, Epsilon: 0.58
# Episode 457,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.58
# Episode 458,Opponent: SoftJoss, Reward: 452.00, Epsilon: 0.58
# Episode 459,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.58
# Episode 460,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.58
# Episode 461,Opponent: Gambler, Reward: 235.00, Epsilon: 0.58
# Episode 462,Opponent: TitFor2Tats, Reward: 314.00, Epsilon: 0.58
# Episode 463,Opponent: Grudger, Reward: 45.00, Epsilon: 0.58
# Episode 464,Opponent: SoftJoss, Reward: 460.00, Epsilon: 0.58
# Episode 465,Opponent: WinStayLoseShift, Reward: 224.00, Epsilon: 0.58
# Episode 466,Opponent: FoolMeOnce, Reward: 40.00, Epsilon: 0.58
# Episode 467,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.58
# Episode 468,Opponent: ForgivingTitForTat, Reward: 240.00, Epsilon: 0.58
# Episode 469,Opponent: Alternator, Reward: 248.00, Epsilon: 0.58
# Episode 470,Opponent: Gambler, Reward: 242.00, Epsilon: 0.58
# Episode 471,Opponent: FoolMeOnce, Reward: 52.00, Epsilon: 0.57
# Episode 472,Opponent: StochasticWSLS, Reward: 442.00, Epsilon: 0.57
# Episode 473,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.57
# Episode 474,Opponent: WinStayLoseShift, Reward: 228.00, Epsilon: 0.57
# Episode 475,Opponent: Alternator, Reward: 240.00, Epsilon: 0.57
# Episode 476,Opponent: Gambler, Reward: 244.00, Epsilon: 0.57
# Episode 477,Opponent: CyclerCCCCCD, Reward: 349.00, Epsilon: 0.57
# Episode 478,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.57
# Episode 479,Opponent: WinStayLoseShift, Reward: 264.00, Epsilon: 0.57
# Episode 480,Opponent: Gambler, Reward: 239.00, Epsilon: 0.57
# Episode 481,Opponent: StochasticWSLS, Reward: 452.00, Epsilon: 0.57
# Episode 482,Opponent: HardTitForTat, Reward: 138.00, Epsilon: 0.57
# Episode 483,Opponent: Grudger, Reward: 51.00, Epsilon: 0.57
# Episode 484,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.57
# Episode 485,Opponent: FoolMeOnce, Reward: 62.00, Epsilon: 0.56
# Episode 486,Opponent: EasyGo, Reward: 437.00, Epsilon: 0.56
# Episode 487,Opponent: TitFor2Tats, Reward: 299.00, Epsilon: 0.56
# Episode 488,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.56
# Episode 489,Opponent: EasyGo, Reward: 439.00, Epsilon: 0.56
# Episode 490,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.56
# Episode 491,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.56
# Episode 492,Opponent: FoolMeOnce, Reward: 62.00, Epsilon: 0.56
# Episode 493,Opponent: Grudger, Reward: 53.00, Epsilon: 0.56
# Episode 494,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.56
# Episode 495,Opponent: EasyGo, Reward: 438.00, Epsilon: 0.56
# Episode 496,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.56
# Episode 497,Opponent: Gambler, Reward: 233.00, Epsilon: 0.56
# Episode 498,Opponent: HardTitForTat, Reward: 101.00, Epsilon: 0.56
# Episode 499,Opponent: StochasticWSLS, Reward: 432.00, Epsilon: 0.56
# Episode 500,Opponent: SoftJoss, Reward: 458.00, Epsilon: 0.56
# Episode 500, Avg Reward: 458.00, Epsilon: 0.56
# Episode 501,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.55
# Episode 502,Opponent: FoolMeOnce, Reward: 61.00, Epsilon: 0.55
# Episode 503,Opponent: FoolMeOnce, Reward: 73.00, Epsilon: 0.55
# Episode 504,Opponent: WinStayLoseShift, Reward: 252.00, Epsilon: 0.55
# Episode 505,Opponent: CyclerCCCCCD, Reward: 379.00, Epsilon: 0.55
# Episode 506,Opponent: WinStayLoseShift, Reward: 266.00, Epsilon: 0.55
# Episode 507,Opponent: StochasticWSLS, Reward: 446.00, Epsilon: 0.55
# Episode 508,Opponent: Grudger, Reward: 53.00, Epsilon: 0.55
# Episode 509,Opponent: SoftJoss, Reward: 446.00, Epsilon: 0.55
# Episode 510,Opponent: ForgivingTitForTat, Reward: 261.00, Epsilon: 0.55
# Episode 511,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.55
# Episode 512,Opponent: Alternator, Reward: 240.00, Epsilon: 0.55
# Episode 513,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.55
# Episode 514,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.55
# Episode 515,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.55
# Episode 516,Opponent: HardTitForTat, Reward: 126.00, Epsilon: 0.54
# Episode 517,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.54
# Episode 518,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.54
# Episode 519,Opponent: TitFor2Tats, Reward: 324.00, Epsilon: 0.54
# Episode 520,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.54
# Episode 521,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.54
# Episode 522,Opponent: ForgivingTitForTat, Reward: 256.00, Epsilon: 0.54
# Episode 523,Opponent: Gambler, Reward: 257.00, Epsilon: 0.54
# Episode 524,Opponent: TitFor2Tats, Reward: 315.00, Epsilon: 0.54
# Episode 525,Opponent: HardTitForTat, Reward: 120.00, Epsilon: 0.54
# Episode 526,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.54
# Episode 527,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.54
# Episode 528,Opponent: ForgivingTitForTat, Reward: 259.00, Epsilon: 0.54
# Episode 529,Opponent: EasyGo, Reward: 437.00, Epsilon: 0.54
# Episode 530,Opponent: Alternator, Reward: 239.00, Epsilon: 0.54
# Episode 531,Opponent: FoolMeOnce, Reward: 67.00, Epsilon: 0.54
# Episode 532,Opponent: Alternator, Reward: 238.00, Epsilon: 0.53
# Episode 533,Opponent: Gambler, Reward: 251.00, Epsilon: 0.53
# Episode 534,Opponent: EasyGo, Reward: 444.00, Epsilon: 0.53
# Episode 535,Opponent: ForgivingTitForTat, Reward: 247.00, Epsilon: 0.53
# Episode 536,Opponent: EasyGo, Reward: 438.00, Epsilon: 0.53
# Episode 537,Opponent: TitFor2Tats, Reward: 331.00, Epsilon: 0.53
# Episode 538,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.53
# Episode 539,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.53
# Episode 540,Opponent: Alternator, Reward: 232.00, Epsilon: 0.53
# Episode 541,Opponent: EasyGo, Reward: 448.00, Epsilon: 0.53
# Episode 542,Opponent: Gambler, Reward: 248.00, Epsilon: 0.53
# Episode 543,Opponent: FoolMeOnce, Reward: 64.00, Epsilon: 0.53
# Episode 544,Opponent: TitFor2Tats, Reward: 312.00, Epsilon: 0.53
# Episode 545,Opponent: WinStayLoseShift, Reward: 231.00, Epsilon: 0.53
# Episode 546,Opponent: SoftJoss, Reward: 448.00, Epsilon: 0.53
# Episode 547,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.53
# Episode 548,Opponent: Alternator, Reward: 243.00, Epsilon: 0.52
# Episode 549,Opponent: Grudger, Reward: 54.00, Epsilon: 0.52
# Episode 550,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.52
# Episode 551,Opponent: StochasticWSLS, Reward: 462.00, Epsilon: 0.52
# Episode 552,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.52
# Episode 553,Opponent: HardTitForTat, Reward: 124.00, Epsilon: 0.52
# Episode 554,Opponent: HardTitForTat, Reward: 120.00, Epsilon: 0.52
# Episode 555,Opponent: TitFor2Tats, Reward: 313.00, Epsilon: 0.52
# Episode 556,Opponent: CyclerCCCCCD, Reward: 363.00, Epsilon: 0.52
# Episode 557,Opponent: Grudger, Reward: 52.00, Epsilon: 0.52
# Episode 558,Opponent: StochasticWSLS, Reward: 456.00, Epsilon: 0.52
# Episode 559,Opponent: Alternator, Reward: 229.00, Epsilon: 0.52
# Episode 560,Opponent: HardTitForTat, Reward: 168.00, Epsilon: 0.52
# Episode 561,Opponent: StochasticWSLS, Reward: 454.00, Epsilon: 0.52
# Episode 562,Opponent: CyclerCCCCCD, Reward: 352.00, Epsilon: 0.52
# Episode 563,Opponent: HardTitForTat, Reward: 96.00, Epsilon: 0.52
# Episode 564,Opponent: Gambler, Reward: 250.00, Epsilon: 0.51
# Episode 565,Opponent: Grudger, Reward: 37.00, Epsilon: 0.51
# Episode 566,Opponent: HardTitForTat, Reward: 141.00, Epsilon: 0.51
# Episode 567,Opponent: WinStayLoseShift, Reward: 225.00, Epsilon: 0.51
# Episode 568,Opponent: StochasticWSLS, Reward: 412.00, Epsilon: 0.51
# Episode 569,Opponent: HardTitForTat, Reward: 132.00, Epsilon: 0.51
# Episode 570,Opponent: StochasticWSLS, Reward: 426.00, Epsilon: 0.51
# Episode 571,Opponent: Grudger, Reward: 65.00, Epsilon: 0.51
# Episode 572,Opponent: Alternator, Reward: 243.00, Epsilon: 0.51
# Episode 573,Opponent: FoolMeOnce, Reward: 37.00, Epsilon: 0.51
# Episode 574,Opponent: ForgivingTitForTat, Reward: 252.00, Epsilon: 0.51
# Episode 575,Opponent: Alternator, Reward: 246.00, Epsilon: 0.51
# Episode 576,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.51
# Episode 577,Opponent: StochasticWSLS, Reward: 462.00, Epsilon: 0.51
# Episode 578,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.51
# Episode 579,Opponent: FoolMeOnce, Reward: 47.00, Epsilon: 0.51
# Episode 580,Opponent: ForgivingTitForTat, Reward: 255.00, Epsilon: 0.51
# Episode 581,Opponent: Alternator, Reward: 236.00, Epsilon: 0.50
# Episode 582,Opponent: Grudger, Reward: 41.00, Epsilon: 0.50
# Episode 583,Opponent: FoolMeOnce, Reward: 45.00, Epsilon: 0.50
# Episode 584,Opponent: StochasticWSLS, Reward: 458.00, Epsilon: 0.50
# Episode 585,Opponent: TitFor2Tats, Reward: 318.00, Epsilon: 0.50
# Episode 586,Opponent: StochasticWSLS, Reward: 444.00, Epsilon: 0.50
# Episode 587,Opponent: EasyGo, Reward: 458.00, Epsilon: 0.50
# Episode 588,Opponent: SoftJoss, Reward: 450.00, Epsilon: 0.50
# Episode 589,Opponent: SoftJoss, Reward: 434.00, Epsilon: 0.50
# Episode 590,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.50
# Episode 591,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.50
# Episode 592,Opponent: TitFor2Tats, Reward: 307.00, Epsilon: 0.50
# Episode 593,Opponent: Alternator, Reward: 228.00, Epsilon: 0.50
# Episode 594,Opponent: WinStayLoseShift, Reward: 252.00, Epsilon: 0.50
# Episode 595,Opponent: FoolMeOnce, Reward: 37.00, Epsilon: 0.50
# Episode 596,Opponent: WinStayLoseShift, Reward: 221.00, Epsilon: 0.50
# Episode 597,Opponent: HardTitForTat, Reward: 189.00, Epsilon: 0.50
# Episode 598,Opponent: HardTitForTat, Reward: 147.00, Epsilon: 0.49
# Episode 599,Opponent: ForgivingTitForTat, Reward: 263.00, Epsilon: 0.49
# Episode 600,Opponent: TitFor2Tats, Reward: 317.00, Epsilon: 0.49
# Episode 600, Avg Reward: 317.00, Epsilon: 0.49
# Episode 601,Opponent: Gambler, Reward: 240.00, Epsilon: 0.49
# Episode 602,Opponent: Alternator, Reward: 229.00, Epsilon: 0.49
# Episode 603,Opponent: Alternator, Reward: 221.00, Epsilon: 0.49
# Episode 604,Opponent: FoolMeOnce, Reward: 35.00, Epsilon: 0.49
# Episode 605,Opponent: Gambler, Reward: 259.00, Epsilon: 0.49
# Episode 606,Opponent: TitFor2Tats, Reward: 320.00, Epsilon: 0.49
# Episode 607,Opponent: Gambler, Reward: 254.00, Epsilon: 0.49
# Episode 608,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.49
# Episode 609,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.49
# Episode 610,Opponent: Grudger, Reward: 34.00, Epsilon: 0.49
# Episode 611,Opponent: ForgivingTitForTat, Reward: 263.00, Epsilon: 0.49
# Episode 612,Opponent: Alternator, Reward: 237.00, Epsilon: 0.49
# Episode 613,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.49
# Episode 614,Opponent: StochasticWSLS, Reward: 420.00, Epsilon: 0.49
# Episode 615,Opponent: HardTitForTat, Reward: 133.00, Epsilon: 0.48
# Episode 616,Opponent: Alternator, Reward: 220.00, Epsilon: 0.48
# Episode 617,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.48
# Episode 618,Opponent: HardTitForTat, Reward: 142.00, Epsilon: 0.48
# Episode 619,Opponent: SoftJoss, Reward: 464.00, Epsilon: 0.48
# Episode 620,Opponent: CyclerCCCCCD, Reward: 367.00, Epsilon: 0.48
# Episode 621,Opponent: WinStayLoseShift, Reward: 221.00, Epsilon: 0.48
# Episode 622,Opponent: HardTitForTat, Reward: 121.00, Epsilon: 0.48
# Episode 623,Opponent: HardTitForTat, Reward: 146.00, Epsilon: 0.48
# Episode 624,Opponent: Grudger, Reward: 29.00, Epsilon: 0.48
# Episode 625,Opponent: Gambler, Reward: 267.00, Epsilon: 0.48
# Episode 626,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.48
# Episode 627,Opponent: TitFor2Tats, Reward: 312.00, Epsilon: 0.48
# Episode 628,Opponent: EasyGo, Reward: 432.00, Epsilon: 0.48
# Episode 629,Opponent: FoolMeOnce, Reward: 47.00, Epsilon: 0.48
# Episode 630,Opponent: EasyGo, Reward: 436.00, Epsilon: 0.48
# Episode 631,Opponent: SoftJoss, Reward: 428.00, Epsilon: 0.48
# Episode 632,Opponent: Grudger, Reward: 48.00, Epsilon: 0.48
# Episode 633,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.47
# Episode 634,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.47
# Episode 635,Opponent: EasyGo, Reward: 435.00, Epsilon: 0.47
# Episode 636,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.47
# Episode 637,Opponent: Grudger, Reward: 41.00, Epsilon: 0.47
# Episode 638,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.47
# Episode 639,Opponent: CyclerCCCCCD, Reward: 369.00, Epsilon: 0.47
# Episode 640,Opponent: TitFor2Tats, Reward: 313.00, Epsilon: 0.47
# Episode 641,Opponent: WinStayLoseShift, Reward: 251.00, Epsilon: 0.47
# Episode 642,Opponent: TitFor2Tats, Reward: 328.00, Epsilon: 0.47
# Episode 643,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.47
# Episode 644,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.47
# Episode 645,Opponent: Alternator, Reward: 242.00, Epsilon: 0.47
# Episode 646,Opponent: Gambler, Reward: 253.00, Epsilon: 0.47
# Episode 647,Opponent: HardTitForTat, Reward: 157.00, Epsilon: 0.47
# Episode 648,Opponent: CyclerCCCCCD, Reward: 390.00, Epsilon: 0.47
# Episode 649,Opponent: TitFor2Tats, Reward: 323.00, Epsilon: 0.47
# Episode 650,Opponent: Gambler, Reward: 246.00, Epsilon: 0.47
# Episode 651,Opponent: ForgivingTitForTat, Reward: 245.00, Epsilon: 0.46
# Episode 652,Opponent: FoolMeOnce, Reward: 52.00, Epsilon: 0.46
# Episode 653,Opponent: CyclerCCCCCD, Reward: 371.00, Epsilon: 0.46
# Episode 654,Opponent: Gambler, Reward: 252.00, Epsilon: 0.46
# Episode 655,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.46
# Episode 656,Opponent: EasyGo, Reward: 426.00, Epsilon: 0.46
# Episode 657,Opponent: Grudger, Reward: 46.00, Epsilon: 0.46
# Episode 658,Opponent: Alternator, Reward: 233.00, Epsilon: 0.46
# Episode 659,Opponent: ForgivingTitForTat, Reward: 264.00, Epsilon: 0.46
# Episode 660,Opponent: Grudger, Reward: 41.00, Epsilon: 0.46
# Episode 661,Opponent: Grudger, Reward: 39.00, Epsilon: 0.46
# Episode 662,Opponent: CyclerCCCCCD, Reward: 364.00, Epsilon: 0.46
# Episode 663,Opponent: Gambler, Reward: 260.00, Epsilon: 0.46
# Episode 664,Opponent: CyclerCCCCCD, Reward: 358.00, Epsilon: 0.46
# Episode 665,Opponent: EasyGo, Reward: 418.00, Epsilon: 0.46
# Episode 666,Opponent: Alternator, Reward: 231.00, Epsilon: 0.46
# Episode 667,Opponent: Alternator, Reward: 238.00, Epsilon: 0.46
# Episode 668,Opponent: HardTitForTat, Reward: 167.00, Epsilon: 0.46
# Episode 669,Opponent: TitFor2Tats, Reward: 334.00, Epsilon: 0.46
# Episode 670,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.45
# Episode 671,Opponent: Grudger, Reward: 38.00, Epsilon: 0.45
# Episode 672,Opponent: Alternator, Reward: 235.00, Epsilon: 0.45
# Episode 673,Opponent: HardTitForTat, Reward: 143.00, Epsilon: 0.45
# Episode 674,Opponent: HardTitForTat, Reward: 149.00, Epsilon: 0.45
# Episode 675,Opponent: SoftJoss, Reward: 418.00, Epsilon: 0.45
# Episode 676,Opponent: StochasticWSLS, Reward: 430.00, Epsilon: 0.45
# Episode 677,Opponent: FoolMeOnce, Reward: 46.00, Epsilon: 0.45
# Episode 678,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.45
# Episode 679,Opponent: StochasticWSLS, Reward: 436.00, Epsilon: 0.45
# Episode 680,Opponent: Grudger, Reward: 41.00, Epsilon: 0.45
# Episode 681,Opponent: Alternator, Reward: 235.00, Epsilon: 0.45
# Episode 682,Opponent: WinStayLoseShift, Reward: 228.00, Epsilon: 0.45
# Episode 683,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.45
# Episode 684,Opponent: TitFor2Tats, Reward: 337.00, Epsilon: 0.45
# Episode 685,Opponent: ForgivingTitForTat, Reward: 244.00, Epsilon: 0.45
# Episode 686,Opponent: HardTitForTat, Reward: 110.00, Epsilon: 0.45
# Episode 687,Opponent: Grudger, Reward: 45.00, Epsilon: 0.45
# Episode 688,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.45
# Episode 689,Opponent: FoolMeOnce, Reward: 57.00, Epsilon: 0.44
# Episode 690,Opponent: FoolMeOnce, Reward: 54.00, Epsilon: 0.44
# Episode 691,Opponent: Grudger, Reward: 45.00, Epsilon: 0.44
# Episode 692,Opponent: TitFor2Tats, Reward: 314.00, Epsilon: 0.44
# Episode 693,Opponent: StochasticWSLS, Reward: 438.00, Epsilon: 0.44
# Episode 694,Opponent: HardTitForTat, Reward: 139.00, Epsilon: 0.44
# Episode 695,Opponent: CyclerCCCCCD, Reward: 365.00, Epsilon: 0.44
# Episode 696,Opponent: TitFor2Tats, Reward: 322.00, Epsilon: 0.44
# Episode 697,Opponent: CyclerCCCCCD, Reward: 354.00, Epsilon: 0.44
# Episode 698,Opponent: ForgivingTitForTat, Reward: 250.00, Epsilon: 0.44
# Episode 699,Opponent: TitFor2Tats, Reward: 336.00, Epsilon: 0.44
# Episode 700,Opponent: SoftJoss, Reward: 440.00, Epsilon: 0.44
# Episode 700, Avg Reward: 440.00, Epsilon: 0.44
# Episode 701,Opponent: FoolMeOnce, Reward: 55.00, Epsilon: 0.44
# Episode 702,Opponent: Grudger, Reward: 44.00, Epsilon: 0.44
# Episode 703,Opponent: HardTitForTat, Reward: 143.00, Epsilon: 0.44
# Episode 704,Opponent: Grudger, Reward: 48.00, Epsilon: 0.44
# Episode 705,Opponent: HardTitForTat, Reward: 131.00, Epsilon: 0.44
# Episode 706,Opponent: EasyGo, Reward: 406.00, Epsilon: 0.44
# Episode 707,Opponent: StochasticWSLS, Reward: 426.00, Epsilon: 0.44
# Episode 708,Opponent: CyclerCCCCCD, Reward: 340.00, Epsilon: 0.43
# Episode 709,Opponent: CyclerCCCCCD, Reward: 357.00, Epsilon: 0.43
# Episode 710,Opponent: WinStayLoseShift, Reward: 243.00, Epsilon: 0.43
# Episode 711,Opponent: HardTitForTat, Reward: 132.00, Epsilon: 0.43
# Episode 712,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.43
# Episode 713,Opponent: Alternator, Reward: 244.00, Epsilon: 0.43
# Episode 714,Opponent: ForgivingTitForTat, Reward: 253.00, Epsilon: 0.43
# Episode 715,Opponent: FoolMeOnce, Reward: 37.00, Epsilon: 0.43
# Episode 716,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.43
# Episode 717,Opponent: HardTitForTat, Reward: 158.00, Epsilon: 0.43
# Episode 718,Opponent: ForgivingTitForTat, Reward: 254.00, Epsilon: 0.43
# Episode 719,Opponent: Gambler, Reward: 255.00, Epsilon: 0.43
# Episode 720,Opponent: WinStayLoseShift, Reward: 239.00, Epsilon: 0.43
# Episode 721,Opponent: CyclerCCCCCD, Reward: 379.00, Epsilon: 0.43
# Episode 722,Opponent: Gambler, Reward: 255.00, Epsilon: 0.43
# Episode 723,Opponent: StochasticWSLS, Reward: 448.00, Epsilon: 0.43
# Episode 724,Opponent: StochasticWSLS, Reward: 454.00, Epsilon: 0.43
# Episode 725,Opponent: SoftJoss, Reward: 458.00, Epsilon: 0.43
# Episode 726,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.43
# Episode 727,Opponent: EasyGo, Reward: 446.00, Epsilon: 0.43
# Episode 728,Opponent: StochasticWSLS, Reward: 448.00, Epsilon: 0.42
# Episode 729,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.42
# Episode 730,Opponent: WinStayLoseShift, Reward: 248.00, Epsilon: 0.42
# Episode 731,Opponent: Gambler, Reward: 248.00, Epsilon: 0.42
# Episode 732,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.42
# Episode 733,Opponent: EasyGo, Reward: 440.00, Epsilon: 0.42
# Episode 734,Opponent: Gambler, Reward: 252.00, Epsilon: 0.42
# ...
# Episode 2762,Opponent: StochasticWSLS, Reward: 424.00, Epsilon: 0.05
# Episode 2763,Opponent: SoftJoss, Reward: 348.00, Epsilon: 0.05
# Episode 2764,Opponent: HardTitForTat, Reward: 285.00, Epsilon: 0.05
# Episode 2765,Opponent: EasyGo, Reward: 453.00, Epsilon: 0.05
# Episode 2766,Opponent: CyclerCCCCCD, Reward: 372.00, Epsilon: 0.05
# Episode 2767,Opponent: TitFor2Tats, Reward: 309.00, Epsilon: 0.05
# Episode 2768,Opponent: SoftJoss, Reward: 476.00, Epsilon: 0.05
# Episode 2769,Opponent: HardTitForTat, Reward: 300.00, Epsilon: 0.05
# Episode 2770,Opponent: CyclerCCCCCD, Reward: 361.00, Epsilon: 0.05
# Episode 2771,Opponent: Alternator, Reward: 209.00, Epsilon: 0.05
# Episode 2772,Opponent: Alternator, Reward: 216.00, Epsilon: 0.05
# Episode 2773,Opponent: ForgivingTitForTat, Reward: 314.00, Epsilon: 0.05
# Episode 2774,Opponent: ForgivingTitForTat, Reward: 301.00, Epsilon: 0.05
# Episode 2775,Opponent: StochasticWSLS, Reward: 440.00, Epsilon: 0.05
# Episode 2776,Opponent: EasyGo, Reward: 485.00, Epsilon: 0.05
# Episode 2777,Opponent: Alternator, Reward: 222.00, Epsilon: 0.05
# Episode 2778,Opponent: StochasticWSLS, Reward: 416.00, Epsilon: 0.05
# Episode 2779,Opponent: TitFor2Tats, Reward: 304.00, Epsilon: 0.05
# Episode 2780,Opponent: WinStayLoseShift, Reward: 288.00, Epsilon: 0.05
# Episode 2781,Opponent: ForgivingTitForTat, Reward: 290.00, Epsilon: 0.05
# Episode 2782,Opponent: Grudger, Reward: 108.00, Epsilon: 0.05
# Episode 2783,Opponent: Gambler, Reward: 288.00, Epsilon: 0.05
# Episode 2784,Opponent: TitFor2Tats, Reward: 294.00, Epsilon: 0.05
# Episode 2785,Opponent: Alternator, Reward: 238.00, Epsilon: 0.05
# Episode 2786,Opponent: Grudger, Reward: 197.00, Epsilon: 0.05
# Episode 2787,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.05
# Episode 2788,Opponent: CyclerCCCCCD, Reward: 424.00, Epsilon: 0.05
# Episode 2789,Opponent: FoolMeOnce, Reward: 213.00, Epsilon: 0.05
# Episode 2790,Opponent: WinStayLoseShift, Reward: 276.00, Epsilon: 0.05
# Episode 2791,Opponent: StochasticWSLS, Reward: 490.00, Epsilon: 0.05
# Episode 2792,Opponent: TitFor2Tats, Reward: 304.00, Epsilon: 0.05
# Episode 2793,Opponent: TitFor2Tats, Reward: 308.00, Epsilon: 0.05
# Episode 2794,Opponent: Alternator, Reward: 231.00, Epsilon: 0.05
# Episode 2795,Opponent: Grudger, Reward: 300.00, Epsilon: 0.05
# Episode 2796,Opponent: Grudger, Reward: 93.00, Epsilon: 0.05
# Episode 2797,Opponent: TitFor2Tats, Reward: 306.00, Epsilon: 0.05
# Episode 2798,Opponent: Grudger, Reward: 83.00, Epsilon: 0.05
# Episode 2799,Opponent: SoftJoss, Reward: 430.00, Epsilon: 0.05
# Episode 2800,Opponent: CyclerCCCCCD, Reward: 383.00, Epsilon: 0.05
# Episode 2800, Avg Reward: 383.00, Epsilon: 0.05
# Episode 2801,Opponent: Alternator, Reward: 182.00, Epsilon: 0.05
# Episode 2802,Opponent: Alternator, Reward: 232.00, Epsilon: 0.05
# Episode 2803,Opponent: Grudger, Reward: 90.00, Epsilon: 0.05
# Episode 2804,Opponent: TitFor2Tats, Reward: 310.00, Epsilon: 0.05
# Episode 2805,Opponent: Alternator, Reward: 186.00, Epsilon: 0.05
# Episode 2806,Opponent: HardTitForTat, Reward: 286.00, Epsilon: 0.05
# Episode 2807,Opponent: Gambler, Reward: 296.00, Epsilon: 0.05
# Episode 2808,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.05
# Episode 2809,Opponent: WinStayLoseShift, Reward: 275.00, Epsilon: 0.05
# Episode 2810,Opponent: WinStayLoseShift, Reward: 294.00, Epsilon: 0.05
# Episode 2811,Opponent: SoftJoss, Reward: 336.00, Epsilon: 0.05
# Episode 2812,Opponent: Grudger, Reward: 134.00, Epsilon: 0.05
# Episode 2813,Opponent: SoftJoss, Reward: 442.00, Epsilon: 0.05
# Episode 2814,Opponent: Gambler, Reward: 295.00, Epsilon: 0.05
# Episode 2815,Opponent: ForgivingTitForTat, Reward: 312.00, Epsilon: 0.05
# Episode 2816,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.05
# Episode 2817,Opponent: CyclerCCCCCD, Reward: 394.00, Epsilon: 0.05
# Episode 2818,Opponent: Gambler, Reward: 297.00, Epsilon: 0.05
# Episode 2819,Opponent: HardTitForTat, Reward: 241.00, Epsilon: 0.05
# Episode 2820,Opponent: ForgivingTitForTat, Reward: 303.00, Epsilon: 0.05
# Episode 2821,Opponent: SoftJoss, Reward: 378.00, Epsilon: 0.05
# Episode 2822,Opponent: EasyGo, Reward: 433.00, Epsilon: 0.05
# Episode 2823,Opponent: HardTitForTat, Reward: 244.00, Epsilon: 0.05
# Episode 2824,Opponent: Alternator, Reward: 240.00, Epsilon: 0.05
# Episode 2825,Opponent: HardTitForTat, Reward: 272.00, Epsilon: 0.05
# Episode 2826,Opponent: CyclerCCCCCD, Reward: 388.00, Epsilon: 0.05
# Episode 2827,Opponent: CyclerCCCCCD, Reward: 392.00, Epsilon: 0.05
# Episode 2828,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.05
# Episode 2829,Opponent: Grudger, Reward: 253.00, Epsilon: 0.05
# Episode 2830,Opponent: EasyGo, Reward: 427.00, Epsilon: 0.05
# Episode 2831,Opponent: FoolMeOnce, Reward: 46.00, Epsilon: 0.05
# Episode 2832,Opponent: Grudger, Reward: 32.00, Epsilon: 0.05
# Episode 2833,Opponent: Gambler, Reward: 293.00, Epsilon: 0.05
# Episode 2834,Opponent: Grudger, Reward: 92.00, Epsilon: 0.05
# Episode 2835,Opponent: CyclerCCCCCD, Reward: 374.00, Epsilon: 0.05
# Episode 2836,Opponent: Alternator, Reward: 234.00, Epsilon: 0.05
# Episode 2837,Opponent: StochasticWSLS, Reward: 396.00, Epsilon: 0.05
# Episode 2838,Opponent: FoolMeOnce, Reward: 148.00, Epsilon: 0.05
# Episode 2839,Opponent: CyclerCCCCCD, Reward: 395.00, Epsilon: 0.05
# Episode 2840,Opponent: StochasticWSLS, Reward: 450.00, Epsilon: 0.05
# Episode 2841,Opponent: StochasticWSLS, Reward: 300.00, Epsilon: 0.05
# Episode 2842,Opponent: SoftJoss, Reward: 414.00, Epsilon: 0.05
# Episode 2843,Opponent: Gambler, Reward: 293.00, Epsilon: 0.05
# Episode 2844,Opponent: StochasticWSLS, Reward: 428.00, Epsilon: 0.05
# Episode 2845,Opponent: HardTitForTat, Reward: 286.00, Epsilon: 0.05
# Episode 2846,Opponent: EasyGo, Reward: 471.00, Epsilon: 0.05
# Episode 2847,Opponent: HardTitForTat, Reward: 244.00, Epsilon: 0.05
# Episode 2848,Opponent: FoolMeOnce, Reward: 179.00, Epsilon: 0.05
# Episode 2849,Opponent: StochasticWSLS, Reward: 358.00, Epsilon: 0.05
# Episode 2850,Opponent: TitFor2Tats, Reward: 344.00, Epsilon: 0.05
# Episode 2851,Opponent: FoolMeOnce, Reward: 65.00, Epsilon: 0.05
# Episode 2852,Opponent: CyclerCCCCCD, Reward: 368.00, Epsilon: 0.05
# Episode 2853,Opponent: SoftJoss, Reward: 426.00, Epsilon: 0.05
# Episode 2854,Opponent: TitFor2Tats, Reward: 313.00, Epsilon: 0.05
# Episode 2855,Opponent: ForgivingTitForTat, Reward: 299.00, Epsilon: 0.05
# Episode 2856,Opponent: Grudger, Reward: 266.00, Epsilon: 0.05
# Episode 2857,Opponent: HardTitForTat, Reward: 274.00, Epsilon: 0.05
# Episode 2858,Opponent: Grudger, Reward: 40.00, Epsilon: 0.05
# Episode 2859,Opponent: EasyGo, Reward: 411.00, Epsilon: 0.05
# Episode 2860,Opponent: EasyGo, Reward: 397.00, Epsilon: 0.05
# Episode 2861,Opponent: Gambler, Reward: 294.00, Epsilon: 0.05
# Episode 2862,Opponent: Grudger, Reward: 302.00, Epsilon: 0.05
# Episode 2863,Opponent: Gambler, Reward: 296.00, Epsilon: 0.05
# Episode 2864,Opponent: FoolMeOnce, Reward: 99.00, Epsilon: 0.05
# Episode 2865,Opponent: ForgivingTitForTat, Reward: 316.00, Epsilon: 0.05
# Episode 2866,Opponent: Gambler, Reward: 294.00, Epsilon: 0.05
# Episode 2867,Opponent: TitFor2Tats, Reward: 300.00, Epsilon: 0.05
# Episode 2868,Opponent: StochasticWSLS, Reward: 330.00, Epsilon: 0.05
# Episode 2869,Opponent: SoftJoss, Reward: 368.00, Epsilon: 0.05
# Episode 2870,Opponent: ForgivingTitForTat, Reward: 292.00, Epsilon: 0.05
# Episode 2871,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.05
# Episode 2872,Opponent: ForgivingTitForTat, Reward: 300.00, Epsilon: 0.05
# Episode 2873,Opponent: Gambler, Reward: 291.00, Epsilon: 0.05
# Episode 2874,Opponent: Alternator, Reward: 235.00, Epsilon: 0.05
# Episode 2875,Opponent: CyclerCCCCCD, Reward: 366.00, Epsilon: 0.05
# Episode 2876,Opponent: SoftJoss, Reward: 300.00, Epsilon: 0.05
# Episode 2877,Opponent: CyclerCCCCCD, Reward: 379.00, Epsilon: 0.05
# Episode 2878,Opponent: HardTitForTat, Reward: 147.00, Epsilon: 0.05
# Episode 2879,Opponent: HardTitForTat, Reward: 256.00, Epsilon: 0.05
# Episode 2880,Opponent: WinStayLoseShift, Reward: 263.00, Epsilon: 0.05
# Episode 2881,Opponent: Grudger, Reward: 289.00, Epsilon: 0.05
# Episode 2882,Opponent: ForgivingTitForTat, Reward: 304.00, Epsilon: 0.05
# Episode 2883,Opponent: Alternator, Reward: 269.00, Epsilon: 0.05
# Episode 2884,Opponent: EasyGo, Reward: 393.00, Epsilon: 0.05
# Episode 2885,Opponent: Gambler, Reward: 296.00, Epsilon: 0.05
# Episode 2886,Opponent: CyclerCCCCCD, Reward: 356.00, Epsilon: 0.05
# Episode 2887,Opponent: SoftJoss, Reward: 384.00, Epsilon: 0.05
# Episode 2888,Opponent: ForgivingTitForTat, Reward: 296.00, Epsilon: 0.05
# Episode 2889,Opponent: TitFor2Tats, Reward: 347.00, Epsilon: 0.05
# Episode 2890,Opponent: ForgivingTitForTat, Reward: 293.00, Epsilon: 0.05
# Episode 2891,Opponent: ForgivingTitForTat, Reward: 312.00, Epsilon: 0.05
# Episode 2892,Opponent: TitFor2Tats, Reward: 356.00, Epsilon: 0.05
# Episode 2893,Opponent: WinStayLoseShift, Reward: 254.00, Epsilon: 0.05
# Episode 2894,Opponent: WinStayLoseShift, Reward: 285.00, Epsilon: 0.05
# Episode 2895,Opponent: FoolMeOnce, Reward: 108.00, Epsilon: 0.05
# Episode 2896,Opponent: WinStayLoseShift, Reward: 258.00, Epsilon: 0.05
# Episode 2897,Opponent: StochasticWSLS, Reward: 350.00, Epsilon: 0.05
# Episode 2898,Opponent: EasyGo, Reward: 431.00, Epsilon: 0.05
# Episode 2899,Opponent: HardTitForTat, Reward: 232.00, Epsilon: 0.05
# Episode 2900,Opponent: Alternator, Reward: 230.00, Epsilon: 0.05
# Episode 2900, Avg Reward: 230.00, Epsilon: 0.05
# Episode 2901,Opponent: WinStayLoseShift, Reward: 276.00, Epsilon: 0.05
# Episode 2902,Opponent: WinStayLoseShift, Reward: 257.00, Epsilon: 0.05
# Episode 2903,Opponent: Alternator, Reward: 268.00, Epsilon: 0.05
# Episode 2904,Opponent: WinStayLoseShift, Reward: 261.00, Epsilon: 0.05
# Episode 2905,Opponent: SoftJoss, Reward: 464.00, Epsilon: 0.05
# Episode 2906,Opponent: HardTitForTat, Reward: 228.00, Epsilon: 0.05
# Episode 2907,Opponent: Alternator, Reward: 285.00, Epsilon: 0.05
# Episode 2908,Opponent: WinStayLoseShift, Reward: 300.00, Epsilon: 0.05
# Episode 2909,Opponent: WinStayLoseShift, Reward: 246.00, Epsilon: 0.05
# Episode 2910,Opponent: SoftJoss, Reward: 396.00, Epsilon: 0.05
# Episode 2911,Opponent: ForgivingTitForTat, Reward: 310.00, Epsilon: 0.05
# Episode 2912,Opponent: Alternator, Reward: 274.00, Epsilon: 0.05
# Episode 2913,Opponent: FoolMeOnce, Reward: 97.00, Epsilon: 0.05
# Episode 2914,Opponent: Gambler, Reward: 284.00, Epsilon: 0.05
# Episode 2915,Opponent: HardTitForTat, Reward: 268.00, Epsilon: 0.05
# Episode 2916,Opponent: HardTitForTat, Reward: 267.00, Epsilon: 0.05
# Episode 2917,Opponent: TitFor2Tats, Reward: 314.00, Epsilon: 0.05
# Episode 2918,Opponent: WinStayLoseShift, Reward: 279.00, Epsilon: 0.05
# Episode 2919,Opponent: SoftJoss, Reward: 310.00, Epsilon: 0.05
# Episode 2920,Opponent: HardTitForTat, Reward: 268.00, Epsilon: 0.05
# Episode 2921,Opponent: CyclerCCCCCD, Reward: 419.00, Epsilon: 0.05
# Episode 2922,Opponent: Gambler, Reward: 288.00, Epsilon: 0.05
# Episode 2923,Opponent: WinStayLoseShift, Reward: 278.00, Epsilon: 0.05
# Episode 2924,Opponent: Gambler, Reward: 292.00, Epsilon: 0.05
# Episode 2925,Opponent: CyclerCCCCCD, Reward: 419.00, Epsilon: 0.05
# Episode 2926,Opponent: CyclerCCCCCD, Reward: 425.00, Epsilon: 0.05
# Episode 2927,Opponent: TitFor2Tats, Reward: 328.00, Epsilon: 0.05
# Episode 2928,Opponent: CyclerCCCCCD, Reward: 419.00, Epsilon: 0.05
# Episode 2929,Opponent: FoolMeOnce, Reward: 300.00, Epsilon: 0.05
# Episode 2930,Opponent: SoftJoss, Reward: 462.00, Epsilon: 0.05
# Episode 2931,Opponent: WinStayLoseShift, Reward: 255.00, Epsilon: 0.05
# Episode 2932,Opponent: WinStayLoseShift, Reward: 266.00, Epsilon: 0.05
# Episode 2933,Opponent: EasyGo, Reward: 489.00, Epsilon: 0.05
# Episode 2934,Opponent: TitFor2Tats, Reward: 305.00, Epsilon: 0.05
# Episode 2935,Opponent: HardTitForTat, Reward: 254.00, Epsilon: 0.05
# Episode 2936,Opponent: HardTitForTat, Reward: 268.00, Epsilon: 0.05
# Episode 2937,Opponent: Alternator, Reward: 255.00, Epsilon: 0.05
# Episode 2938,Opponent: SoftJoss, Reward: 350.00, Epsilon: 0.05
# Episode 2939,Opponent: FoolMeOnce, Reward: 56.00, Epsilon: 0.05
# Episode 2940,Opponent: CyclerCCCCCD, Reward: 387.00, Epsilon: 0.05
# Episode 2941,Opponent: EasyGo, Reward: 477.00, Epsilon: 0.05
# Episode 2942,Opponent: Alternator, Reward: 291.00, Epsilon: 0.05
# Episode 2943,Opponent: ForgivingTitForTat, Reward: 278.00, Epsilon: 0.05
# Episode 2944,Opponent: CyclerCCCCCD, Reward: 423.00, Epsilon: 0.05
# Episode 2945,Opponent: FoolMeOnce, Reward: 87.00, Epsilon: 0.05
# Episode 2946,Opponent: FoolMeOnce, Reward: 186.00, Epsilon: 0.05
# Episode 2947,Opponent: FoolMeOnce, Reward: 58.00, Epsilon: 0.05
# Episode 2948,Opponent: Alternator, Reward: 215.00, Epsilon: 0.05
# Episode 2949,Opponent: FoolMeOnce, Reward: 90.00, Epsilon: 0.05
# Episode 2950,Opponent: TitFor2Tats, Reward: 316.00, Epsilon: 0.05
# Episode 2951,Opponent: FoolMeOnce, Reward: 84.00, Epsilon: 0.05
# Episode 2952,Opponent: Gambler, Reward: 291.00, Epsilon: 0.05
# Episode 2953,Opponent: ForgivingTitForTat, Reward: 308.00, Epsilon: 0.05
# Episode 2954,Opponent: WinStayLoseShift, Reward: 297.00, Epsilon: 0.05
# Episode 2955,Opponent: FoolMeOnce, Reward: 152.00, Epsilon: 0.05
# Episode 2956,Opponent: WinStayLoseShift, Reward: 273.00, Epsilon: 0.05
# Episode 2957,Opponent: SoftJoss, Reward: 302.00, Epsilon: 0.05
# Episode 2958,Opponent: TitFor2Tats, Reward: 300.00, Epsilon: 0.05
# Episode 2959,Opponent: StochasticWSLS, Reward: 320.00, Epsilon: 0.05
# Episode 2960,Opponent: FoolMeOnce, Reward: 76.00, Epsilon: 0.05
# Episode 2961,Opponent: FoolMeOnce, Reward: 186.00, Epsilon: 0.05
# Episode 2962,Opponent: HardTitForTat, Reward: 236.00, Epsilon: 0.05
# Episode 2963,Opponent: Grudger, Reward: 135.00, Epsilon: 0.05
# Episode 2964,Opponent: Gambler, Reward: 296.00, Epsilon: 0.05
# Episode 2965,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.05
# Episode 2966,Opponent: SoftJoss, Reward: 318.00, Epsilon: 0.05
# Episode 2967,Opponent: Gambler, Reward: 300.00, Epsilon: 0.05
# Episode 2968,Opponent: HardTitForTat, Reward: 267.00, Epsilon: 0.05
# Episode 2969,Opponent: Grudger, Reward: 71.00, Epsilon: 0.05
# Episode 2970,Opponent: WinStayLoseShift, Reward: 282.00, Epsilon: 0.05
# Episode 2971,Opponent: TitFor2Tats, Reward: 301.00, Epsilon: 0.05
# Episode 2972,Opponent: EasyGo, Reward: 483.00, Epsilon: 0.05
# Episode 2973,Opponent: StochasticWSLS, Reward: 466.00, Epsilon: 0.05
# Episode 2974,Opponent: TitFor2Tats, Reward: 329.00, Epsilon: 0.05
# Episode 2975,Opponent: StochasticWSLS, Reward: 410.00, Epsilon: 0.05
# Episode 2976,Opponent: SoftJoss, Reward: 432.00, Epsilon: 0.05
# Episode 2977,Opponent: FoolMeOnce, Reward: 176.00, Epsilon: 0.05
# Episode 2978,Opponent: Grudger, Reward: 58.00, Epsilon: 0.05
# Episode 2979,Opponent: Gambler, Reward: 292.00, Epsilon: 0.05
# Episode 2980,Opponent: CyclerCCCCCD, Reward: 419.00, Epsilon: 0.05
# Episode 2981,Opponent: SoftJoss, Reward: 470.00, Epsilon: 0.05
# Episode 2982,Opponent: StochasticWSLS, Reward: 474.00, Epsilon: 0.05
# Episode 2983,Opponent: EasyGo, Reward: 487.00, Epsilon: 0.05
# Episode 2984,Opponent: WinStayLoseShift, Reward: 291.00, Epsilon: 0.05
# Episode 2985,Opponent: SoftJoss, Reward: 454.00, Epsilon: 0.05
# Episode 2986,Opponent: CyclerCCCCCD, Reward: 401.00, Epsilon: 0.05
# Episode 2987,Opponent: SoftJoss, Reward: 436.00, Epsilon: 0.05
# Episode 2988,Opponent: Grudger, Reward: 89.00, Epsilon: 0.05
# Episode 2989,Opponent: SoftJoss, Reward: 362.00, Epsilon: 0.05
# Episode 2990,Opponent: Grudger, Reward: 79.00, Epsilon: 0.05
# Episode 2991,Opponent: ForgivingTitForTat, Reward: 299.00, Epsilon: 0.05
# Episode 2992,Opponent: EasyGo, Reward: 489.00, Epsilon: 0.05
# Episode 2993,Opponent: CyclerCCCCCD, Reward: 425.00, Epsilon: 0.05
# Episode 2994,Opponent: SoftJoss, Reward: 300.00, Epsilon: 0.05
# Episode 2995,Opponent: StochasticWSLS, Reward: 496.00, Epsilon: 0.05
# Episode 2996,Opponent: WinStayLoseShift, Reward: 288.00, Epsilon: 0.05
# Episode 2997,Opponent: Grudger, Reward: 180.00, Epsilon: 0.05
# Episode 2998,Opponent: Gambler, Reward: 300.00, Epsilon: 0.05
# Episode 2999,Opponent: SoftJoss, Reward: 464.00, Epsilon: 0.05
# Evaluation vs All-C: Total Reward = 300
# Evaluation vs All-D: Total Reward = 35
# Evaluation vs TitForTat: Total Reward = 300
# Evaluation vs Grim: Total Reward = 300
# Total reward: 935

# %%
# === RL Wrapper for Simple Axelrod Tournament ===
import axelrod as axl
import torch
from axelrod.action import Action
import numpy as np
from collections import defaultdict
from statistics import mean

C, D = Action.C, Action.D

class RLWrapper(axl.Player):
    name = "RL Agent"

    def __init__(self, policy_net, history_len=5):
        super().__init__()
        self.policy_net = policy_net
        self.history_len = history_len

    def strategy(self, opponent):
        padded_self = [0] * (self.history_len - len(self.history)) + [
            0 if action == C else 1 for action in self.history[-self.history_len:]
        ]
        padded_opp = [0] * (self.history_len - len(opponent.history)) + [
            0 if action == C else 1 for action in opponent.history[-self.history_len:]
        ]
        state = torch.tensor(padded_self + padded_opp, dtype=torch.float32)
        with torch.no_grad():
            action_index = self.policy_net(state.unsqueeze(0)).argmax().item()
        return C if action_index == 0 else D

    def __repr__(self):
        return self.name


policy_net1 = DQN(input_dim=10, hidden_dim=64, output_dim=2)
policy_net1.load_state_dict(torch.load("dqn_policy.pth"))
policy_net1.eval()

policy_net2 = DQN(input_dim=10, hidden_dim=64, output_dim=2)
policy_net2.load_state_dict(torch.load("dqn_policy.pth"))
policy_net2.eval()

strategies = [
    axl.Defector(),
    axl.Cooperator(),
    axl.TitForTat(),
    axl.SuspiciousTitForTat(),
    RLWrapper(policy_net2),
    axl.FirstByJoss(),
    axl.StochasticCooperator(),
    axl.Calculator(),
    axl.BackStabber(),
    axl.MathConstantHunter(),
    axl.SneakyTitForTat(),
    axl.Handshake(),
    axl.CyclerCCD(),
    # Extended tournament also includes the following
    # RLWrapper(policy_net1),
    # axl.Alternator(),
    # axl.Inverse(),
    # axl.InversePunisher(),
    # axl.MetaWinnerStochastic(),
    # axl.DoubleCrosser(),
    # axl.DelayedAON1()
 ]


tournament = axl.Tournament(strategies, turns=100)
results = tournament.play()
scores_matrix = results.scores
average_scores = average_scores = [np.mean(score_row) for score_row in scores_matrix]

# Print strategies sorted by average score
print("\nΚατάταξη στρατηγικών βάσει μέσου σκορ:")
sorted_by_score = sorted(zip(results.players, average_scores), key=lambda x: -x[1])
for i, (player, score) in enumerate(sorted_by_score):
    print(f"{i+1}. {player}: {score:.2f}")
# Out:
# Playing matches: 100%|██████████| 210/210 [00:43<00:00,  4.78it/s]
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 121.17it/s]
# Κατάταξη στρατηγικών βάσει μέσου σκορ:
# 1. DoubleCrosser: (D, D): 4839.80
# 2. RL Agent: 4835.10
# 3. RL Agent: 4789.30
# 4. BackStabber: (D, D): 4776.00
# 5. Tit For Tat: 4594.80
# 6. Math Constant Hunter: 4537.20
# 7. Inverse Punisher: 4536.60
# 8. Delayed AON1: 4498.60
# 9. Inverse: 4497.30
# 10. Defector: 4305.60
# 11. Sneaky Tit For Tat: 4147.50
# 12. Meta Winner Stochastic: 68 players: 4112.60
# 13. Stochastic Cooperator: 4110.80
# 14. Calculator: 4046.70
# 15. Suspicious Tit For Tat: 4006.60
# 16. Handshake: 3975.20
# 17. Cooperator: 3927.00
# 18. First by Joss: 0.9: 3886.10
# 19. Alternator: 3439.40
# 20. Cycler CCD: 2800.10

# %%
# Show the agent moves to be precise (log each round)
policy_net.load_state_dict(torch.load("dqn_policy.pth"))
policy_net.eval()

env = IPDEnv(axl.Defector())  # Choose opponent
state = env.reset()
done = False
round_num = 1
total_test_reward = 0

print("Round | Agent | Opponent")

while not done:
    with torch.no_grad():
        action = policy_net(state.unsqueeze(0)).argmax().item()

    next_state, reward, done = env.step(action)

    # Decode moves
    agent_move = 'C' if env.agent_history[-1] == 0 else 'D'
    opponent_move = 'C' if env.opp_history[-1] == 0 else 'D'

    print(f"{round_num:>5} |   {agent_move}   |    {opponent_move}")

    state = next_state
    round_num += 1
    total_test_reward += reward

print("Total reward:" , total_test_reward)
# Out:
# Round | Agent | Opponent
#     1 |   C   |    D
#     2 |   D   |    D
#     3 |   D   |    D
#     4 |   D   |    D
#     5 |   C   |    D
#     6 |   D   |    D
#     7 |   C   |    D
#     8 |   C   |    D
#     9 |   C   |    D
#    10 |   D   |    D
#    11 |   D   |    D
#    12 |   D   |    D
#    13 |   D   |    D
#    14 |   D   |    D
#    15 |   C   |    D
#    16 |   C   |    D
#    17 |   C   |    D
#    18 |   C   |    D
#    19 |   C   |    D
#    20 |   D   |    D
#    21 |   D   |    D
#    22 |   D   |    D
#    23 |   D   |    D
#    24 |   D   |    D
#    25 |   C   |    D
#    26 |   C   |    D
#    27 |   C   |    D
#    28 |   C   |    D
#    29 |   C   |    D
#    30 |   D   |    D
#    31 |   D   |    D
#    32 |   D   |    D
#    33 |   D   |    D
#    34 |   D   |    D
#    35 |   C   |    D
#    36 |   C   |    D
#    37 |   C   |    D
#    38 |   C   |    D
#    39 |   C   |    D
#    40 |   D   |    D
#    41 |   D   |    D
#    42 |   D   |    D
#    43 |   D   |    D
#    44 |   D   |    D
#    45 |   C   |    D
#    46 |   C   |    D
#    47 |   C   |    D
#    48 |   C   |    D
#    49 |   C   |    D
#    50 |   D   |    D
#    51 |   D   |    D
#    52 |   D   |    D
#    53 |   D   |    D
#    54 |   D   |    D
#    55 |   C   |    D
#    56 |   C   |    D
#    57 |   C   |    D
#    58 |   C   |    D
#    59 |   C   |    D
#    60 |   D   |    D
#    61 |   D   |    D
#    62 |   D   |    D
#    63 |   D   |    D
#    64 |   D   |    D
#    65 |   C   |    D
#    66 |   C   |    D
#    67 |   C   |    D
#    68 |   C   |    D
#    69 |   C   |    D
#    70 |   D   |    D
#    71 |   D   |    D
#    72 |   D   |    D
#    73 |   D   |    D
#    74 |   D   |    D
#    75 |   C   |    D
#    76 |   C   |    D
#    77 |   C   |    D
#    78 |   C   |    D
#    79 |   C   |    D
#    80 |   D   |    D
#    81 |   D   |    D
#    82 |   D   |    D
#    83 |   D   |    D
#    84 |   D   |    D
#    85 |   C   |    D
#    86 |   C   |    D
#    87 |   C   |    D
#    88 |   C   |    D
#    89 |   C   |    D
#    90 |   D   |    D
#    91 |   D   |    D
#    92 |   D   |    D
#    93 |   D   |    D
#    94 |   D   |    D
#    95 |   C   |    D
#    96 |   C   |    D
#    97 |   C   |    D
#    98 |   C   |    D
#    99 |   C   |    D
#   100 |   D   |    D
# Total reward: 50
